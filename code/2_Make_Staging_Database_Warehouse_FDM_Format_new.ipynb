# %%
#2_Make_Staging_Database_Warehouse_FDM_Format 

library(bigrquery)
library(lubridate) 

project_id = "yhcr-prd-phm-bia-core"
targetdb <-'yhcr-prd-phm-bia-core.CB_STAGING_DATABASE_WAREHOUSE_FDM_Format'
demodb <-'yhcr-prd-phm-bia-core.CB_STAGING_DATABASE_FDM_Format.src_DemoGraphics_MASTER'
sourcedb <-'yhcr-prd-phm-bia-core.CB_MYSPACE_PAA'

targetdb <-gsub(" ",'',targetdb)
sourcedb <-gsub(" ",'',sourcedb)
  demodb <-gsub(" ",'',demodb)


print (sourcedb) 
print (targetdb)
print (demodb)

#example script

eric <- paste("Started at "  ,Sys.time() + hours(1) ,sep = "")
print(eric)
# Out:
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union
# [1] "yhcr-prd-phm-bia-core.CB_MYSPACE_PAA"
# [1] "yhcr-prd-phm-bia-core.CB_STAGING_DATABASE_WAREHOUSE_FDM_Format"
# [1] "yhcr-prd-phm-bia-core.CB_STAGING_DATABASE_FDM_Format.src_DemoGraphics_MASTER"
# [1] "Started at 2024-05-29 07:44:54.142547"

# %%
sql3 <-paste('drop table if exists ', targetdb,'.tbl_ae; ', sep = "") 

tb3 <- bq_project_query(project_id, sql3)

sql4 <-paste('CREATE  TABLE ', targetdb,'.tbl_ae 
as 
select 
dem.person_id,
cast(arrival_date_time as datetime) as tbl_ae_start_date,
cast(departure_date_time as datetime) as tbl_ae_end_date,
  identifier ,
  src.digest ,
  nhs_number_status_indicator as digest_number_status_indicator ,
  postcode ,
  organisation_code_of_provider ,
  gender ,
  birth_year ,
  birth_month ,
  death_year ,
  death_month ,
  age_at_attendance_date ,
  age_in_days ,
  language_code ,
  language_description ,
  patient_group_ae ,
  patient_group_ae_description ,
  arrival_date_time ,
  departure_date_time ,
  visit_duration ,
  arrival_mode ,
  arrival_mode_description ,
  initial_assessment_triage_category ,
  department_type ,
  attendance_disposal ,
  attendance_disposal_description ,
  source_of_referral ,
  source_of_referral_description ,
  purchaser ,
  activity_treatment_function_code ,
  hrg_code ,
  investigation_1 ,
  investigation_2 ,
  investigation_3 ,
  investigation_4 ,
  investigation_5 ,
  investigation_6 ,
  investigation_7 ,
  investigation_8 ,
  investigation_9 ,
  investigation_10 ,
  investigation_11 ,
  investigation_12 ,
  treatment_1 ,
  treatment_2 ,
  treatment_3 ,
  treatment_4 ,
  treatment_5 ,
  treatment_6 ,
  treatment_7 ,
  treatment_8 ,
  treatment_9 ,
  treatment_10 ,
  treatment_11 ,
  treatment_12 ,
  diagnosis_1 ,
  diagnosis_2 ,
  diagnosis_3 ,
  diagnosis_4 ,
  diagnosis_5 ,
  diagnosis_6 ,
  diagnosis_7 ,
  diagnosis_8 ,
  diagnosis_9 ,
  diagnosis_10 ,
  diagnosis_11 ,
  diagnosis_12 STRING
from ', sourcedb,'.tbl_ae src 
 left join ', demodb,' dem
on src.digest = dem.digest ', sep = "") 

tb4 <- bq_project_query(project_id, sql4)

sql5 <-paste('update ', targetdb,'.tbl_ae
set tbl_ae_end_date = tbl_ae_start_date
where tbl_ae_end_date is null and tbl_ae_start_date is not null ; ', sep = "") 
tb5 <- bq_project_query(project_id, sql5)

print (' tbl_ae done ')
# Out:
# [1] " tbl_ae done "

# %%
sql6 <-paste('drop table if exists ', targetdb,'.tbl_ae_nautilus; ', sep = "") 
tb6 <- bq_project_query(project_id, sql6)


sql7 <-paste('CREATE  TABLE ', targetdb,'.tbl_ae_nautilus
as 
SELECT 
dem.person_id,
cast(left(injury_dt_tm,19) as datetime)  as tbl_ae_nautilus_start_date,
cast(left(injury_dt_tm,19) as datetime)  as tbl_ae_nautilus_end_date,
src.digest,
encntr_id,
src.person_id as nautilus_person_id,
birth_year,
birth_month,
postcode,
death_year,
death_month,
fin_number,
source_of_referral_cd,
source_of_referral_description,
source_of_referral,
referring_organisation,
attendance_category_cd,
attendance_category_description,
attendance_category,
accomodation_status,
overseas_visitor_status_cd,
overseas_visitor_status_description,
overseas_visitor_status,
arrival_mode_cd,
arrival_mode_description,
arrival_mode,
incident_type_cd,
incident_type_description,
incident_type,
dept_type_cd,
dept_type_description,
dept_type,
site_code_of_treatment_cd,
site_code_of_treatment,
reg_stream,
department_or_ward_cd,
presentation,
incident_location_cd,
incident_location_description,
incident_location,
ambulance_geo_cd,
ambulance_call_sign_cd,
ambulance_call_id,
road_traffic_acc_addr_txt,
road_traffic_acc_police_ident,
active_status_cd,
encntr_status_cd,
discharge_method,
discharge_method_code,
outcome,
last_location_cd,
last_location_description,
last_location,
org_alias,
ccg_name,
ccg_code,
ec_discharge_follow_up,
discharge_method_snmd,
outcome_snmd,
acuity_level,
patient_information_given,
treatment_function_cd,
treatment_function_description,
treatment_fucntion,
injury_dt_tm,
injury_lattitude,
injury_longitude,
injury_intent,
injury_activity_status,
injury_activity_type,
injury_mechanism,
alcohol_drug_involvement,
tracking_id,
tracking_locator_id,
max_tracking_id,
max_tracking_locator_id
 FROM ', sourcedb,'.tbl_ae_nautilus src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "") 
tb7 <- bq_project_query(project_id, sql7)

sql8 <-paste('update ', targetdb,'.tbl_ae_nautilus
set tbl_ae_nautilus_end_date = tbl_ae_nautilus_start_date
where tbl_ae_nautilus_end_date is null and tbl_ae_nautilus_start_date is not null ; ', sep = "") 
tb8 <- bq_project_query(project_id, sql8)

print (' tbl_ae_nautilus done ')
# Out:
# [1] " tbl_ae_nautilus done "

# %%
sql9 <-paste('drop table if exists ', targetdb,'.tbl_ae_investigation_nautilus; ', sep = "") 
tb9 <- bq_project_query(project_id, sql9) 

sql10 <-paste('CREATE  TABLE ', targetdb,'.tbl_ae_investigation_nautilus
as select 
dem.person_id,
cast(left(orig_order_dt_tm,19)  as datetime) as tbl_ae_investigation_nautilus_start_date,
cast(left(orig_order_dt_tm,19)   as datetime) as tbl_ae_investigation_nautilus_end_date,
  order_id ,
  encntr_id ,
  src.digest ,
  investigation_cd ,
  investigation_description ,
  investigation ,
  investigation_type_cd ,
  investigation_type_description ,
  cast(left(orig_order_dt_tm,19) as datetime) as orig_order_dt_tm  ,
  order_status_cd ,
  order_status_description ,
  order_mnemonic ,
  synonym_id ,
  cast(left(current_start_dt_tm,19) as datetime)  as current_start_dt_tm ,
  cast(left(projected_stop_dt_tm,19) as datetime) as projected_stop_dt_tm ,
  hna_order_mnemonic ,
  cast(left(valid_dose_dt_tm,19) as datetime) as valid_dose_dt_tm
from  ', sourcedb,'.tbl_ae_investigation_nautilus src
 left join  ', demodb,' dem
on src.digest= dem.digest; ', sep = "")
tb10 <- bq_project_query(project_id, sql10)

sql11 <-paste('update ', targetdb,'.tbl_ae_investigation_nautilus
set tbl_ae_investigation_nautilus_end_date = tbl_ae_investigation_nautilus_start_date
where tbl_ae_investigation_nautilus_end_date is null and tbl_ae_investigation_nautilus_start_date is not null ; ', sep = "") 
tb11 <- bq_project_query(project_id, sql11)

print (' tbl_ae_investigation_nautilus done ')
# Out:
# [1] " tbl_ae_investigation_nautilus done "

# %%
sql12 <-paste('drop table if exists ', targetdb,'.tbl_ae_timings_nautilus; ', sep = "") 
tb12 <- bq_project_query(project_id, sql12)

sql13 <-paste('CREATE  TABLE ', targetdb,'.tbl_ae_timings_nautilus
as select dem.person_id,
cast(left(arrival_dt_tm,19) as datetime) as tbl_ae_timings_nautilus_start_date,
cast(left(departure_dt_tm,19) as datetime) as tbl_ae_timings_nautilus_end_date,
src.digest,
  encntr_id ,
  arrival_dt_tm ,
  triage_start_dt_tm ,
  triage_end_dt_tm ,
  assessment_dt_tm ,
  clinician_assign_dt_tm ,
  clinician_seen_dt_tm ,
  referred_to_service_referral_dt_tm ,
  referred_to_service_seen_dt_tm ,
  decision_to_admit_dt_tm ,
  ready_to_transfer_dt_tm ,
  clinically_ready_dt_tm ,
  expected_treatment_dt_tm ,
  treatment_allocation_dt_tm ,
  treatment_seen_dt_tm ,
  checkout_dt_tm ,
  conclusion_dt_tm ,
  departure_dt_tm STRING
from ', sourcedb,'.tbl_ae_timings_nautilus src
 left join  ', demodb,' dem
on src.digest= dem.digest; ', sep = "") 
tb13 <- bq_project_query(project_id, sql13) 

sql14 <-paste('update ', targetdb,'.tbl_ae_timings_nautilus
set tbl_ae_timings_nautilus_end_date = tbl_ae_timings_nautilus_start_date
where tbl_ae_timings_nautilus_end_date is null and tbl_ae_timings_nautilus_start_date is not null ; ', sep = "") 

tb14 <- bq_project_query(project_id, sql14)


sql15 <-paste('delete from ', sourcedb,'.tbl_ae_timings_nautilus
where encntr_id is null; ', sep = "") 
tb15 <- bq_project_query(project_id, sql15) 

print(' tbl_ae_timings_nautilus done ')
# Out:
# [1] " tbl_ae_timings_nautilus done "

# %%
 sql16 <-paste('drop table if exists  ', targetdb,'.tbl_ae_treatment_nautilus; ', sep = "") 
tb16 <- bq_project_query(project_id, sql16)


sql17 <-paste('CREATE  TABLE ', targetdb,'.tbl_ae_treatment_nautilus
as select dem.person_id,
cast(left(performed_dt_tm,19) as datetime)as  tbl_ae_treatment_nautilus_start_date,
cast(left(performed_dt_tm, 19) as datetime) as tbl_ae_treatment_nautilus_end_date,
  src.digest,
  encntr_id ,
  src.person_id as person_id_nautilus ,
  clinical_event_id ,
  event_id ,
  parent_event_id ,
  event_title_text ,
  event_tag ,
  treatment_cd ,
  treatment_description ,
  treatment ,
  treatment_sequence_nbr ,
  performed_prsnl_id ,
  performed_by_person ,
  cast(left(performed_dt_tm,19) as datetime) as performed_dt_tm ,
  cast(left(valid_from_dt_tm,19) as datetime) as valid_from_dt_tm ,
  cast(left(valid_until_dt_tm,19) as datetime) as valid_until_dt_tm
from ', sourcedb,'.tbl_ae_treatment_nautilus src
 left join  ', demodb,' dem
on src.digest= dem.digest; ', sep = "") 
tb17 <- bq_project_query(project_id, sql17)


sql18 <-paste('update ', targetdb,'.tbl_ae_treatment_nautilus
set tbl_ae_treatment_nautilus_end_date = tbl_ae_treatment_nautilus_start_date
where tbl_ae_treatment_nautilus_end_date is null and tbl_ae_treatment_nautilus_start_date is not null ; ', sep = "") 
tb18 <- bq_project_query(project_id, sql18)

print (' tbl_ae_treatment_nautilus done ')
# Out:
# [1] " tbl_ae_treatment_nautilus done "

# %%
sql19 <-paste('drop table if exists  ', targetdb,'.tbl_apc_finished_susplus; ', sep = "") 
tb19 <- bq_project_query(project_id, sql19)

sql20 <-paste('CREATE  TABLE ', targetdb,'.tbl_apc_finished_susplus
as 
select 
dem.person_id,
cast(left(start_date_hospital_provider_spell,4) ||"-"||substring(start_date_hospital_provider_spell,5,2)||"-"||substring(start_date_hospital_provider_spell,7,2) || " " || start_time_hospital_provider_spell as datetime)  as tbl_apc_finished_susplus_start_date,
cast(left(discharge_date_from_hospital_provider_spell,4) ||"-"||substring(discharge_date_from_hospital_provider_spell,5,2)||"-"||substring(discharge_date_from_hospital_provider_spell,7,2) || " " || discharge_time_hospital_provider_spell as datetime)  as tbl_apc_finished_susplus_end_date,
  identifier ,
  src.digest ,
  generated_record_identifier ,
  pbr_spell_id ,
  reason_for_access ,
  cds_type ,
  protocol_identifier ,
  update_type ,
  bulk_replacement_cds_group ,
  test_indicator ,
  applicable_date_time ,
  census_date ,
  extract_date_time ,
  report_period_start_date ,
  report_period_end_date ,
  organisation_code_sender_of_transaction ,
  organisation_code_type_of_sender ,
  submission_date ,
  cds_interchange_id ,
  organisation_code_local_patient_identifier ,
  organisation_code_type_local_patient_identifier ,
  birth_year ,
  birth_month ,
  birth_weight ,
  live_or_still_birth ,
  carer_support_indicator ,
  legal_status_classification_on_admission_psychiatric_census_only ,
  marital_status_psychiatric_census_only ,
  digest_number_trace_status ,
  withheld_identity_reason ,
  sex ,
  pregnancy_total_previous_pregnancies ,
  postcode ,
  organisation_code_residence_responsibility ,
  pct_of_residence ,
  organisation_code_type_pct_of_residence ,
  osv_classification_at_cds_activity_date ,
  overseas_visitor_status_classification_1 ,
  overseas_visitor_status_start_date_1 ,
  overseas_visitor_status_end_date_1 ,
  overseas_visitor_status_classification_2 ,
  overseas_visitor_status_start_date_2 ,
  overseas_visitor_status_end_date_2 ,
  overseas_visitor_status_classification_3 ,
  overseas_visitor_status_start_date_3 ,
  overseas_visitor_status_end_date_3 ,
  overseas_visitor_status_classification_4 ,
  overseas_visitor_status_start_date_4 ,
  overseas_visitor_status_end_date_4 ,
  overseas_visitor_status_classification_5 ,
  overseas_visitor_status_start_date_5 ,
  overseas_visitor_status_end_date_5 ,
  hospital_provider_spell_number ,
  administrative_category ,
  patient_classification ,
  admission_method_hospital_provider_spell ,
  discharge_destination_hospital_provider_spell ,
  discharge_method_hospital_provider_spell ,
  source_of_admission_hospital_provider_spell ,
  start_date_hospital_provider_spell ,
  start_time_hospital_provider_spell ,
  discharge_date_from_hospital_provider_spell ,
  discharge_time_hospital_provider_spell ,
  discharge_to_hospital_at_home_service_indicator ,
  episode_number ,
  first_regular_day_night_admission ,
  last_episode_in_spell_indicator ,
  neonatal_level_of_care ,
  operation_status ,
  psychiatric_patient_status ,
  start_date_consultant_episode ,
  start_time_episode ,
  end_date_consultant_episode ,
  end_time_episode ,
  length_of_stay_adjustment_rehabilitation ,
  length_of_stay_adjustment_specialist_palliative_care ,
  commissioning_serial_number ,
  nhs_service_agreement_line_number ,
  provider_reference_number ,
  commissioner_reference_number ,
  organisation_code_code_of_provider ,
  organisation_code_type_of_provider ,
  organisation_code_code_of_commissioner ,
  organisation_code_type_of_commissioner ,
  consultant_code ,
  main_specialty_code ,
  treatment_function_code ,
  local_sub_specialty_code ,
  multiprofessional_or_multidisciplinary_ind_code ,
  rehabilitation_assessment_team_type ,
  diagnosis_scheme_in_use_icd ,
  diagnosis_primary_icd ,
  present_on_admission_indicator_diag_1 ,
  diagnosis_1st_secondary_icd ,
  present_on_admission_indicator_diag_2 ,
  diagnosis_2nd_secondary_icd ,
  present_on_admission_indicator_diag_3 ,
  diagnosis_3rd_secondary_icd ,
  present_on_admission_indicator_diag_4 ,
  diagnosis_4th_secondary_icd ,
  present_on_admission_indicator_diag_5 ,
  diagnosis_5th_secondary_icd ,
  present_on_admission_indicator_diag_6 ,
  diagnosis_6th_secondary_icd ,
  present_on_admission_indicator_diag_7 ,
  diagnosis_7th_secondary_icd ,
  present_on_admission_indicator_diag_8 ,
  diagnosis_8th_secondary_icd ,
  present_on_admission_indicator_diag_9 ,
  diagnosis_9th_secondary_icd ,
  present_on_admission_indicator_diag_10 ,
  diagnosis_10th_secondary_icd ,
  present_on_admission_indicator_diag_11 ,
  diagnosis_11th_secondary_icd ,
  present_on_admission_indicator_diag_12 ,
  diagnosis_12th_secondary_icd ,
  present_on_admission_indicator_diag_13 ,
  diagnosis_13th_secondary_icd ,
  present_on_admission_indicator_diag_14 ,
  diagnosis_14th_secondary_icd ,
  present_on_admission_indicator_diag_15 ,
  diagnosis_15th_secondary_icd ,
  present_on_admission_indicator_diag_16 ,
  diagnosis_16th_secondary_icd ,
  present_on_admission_indicator_diag_17 ,
  diagnosis_17th_secondary_icd ,
  present_on_admission_indicator_diag_18 ,
  diagnosis_18th_secondary_icd ,
  present_on_admission_indicator_diag_19 ,
  diagnosis_19th_secondary_icd ,
  present_on_admission_indicator_diag_20 ,
  diagnosis_20th_secondary_icd ,
  present_on_admission_indicator_diag_21 ,
  diagnosis_21st_secondary_icd ,
  present_on_admission_indicator_diag_22 ,
  diagnosis_22nd_secondary_icd ,
  present_on_admission_indicator_diag_23 ,
  diagnosis_23rd_secondary_icd ,
  present_on_admission_indicator_diag_24 ,
  diagnosis_scheme_in_use_read ,
  diagnosis_primary_read ,
  diagnosis_1st_secondary_read ,
  diagnosis_2nd_secondary_read ,
  diagnosis_3rd_secondary_read ,
  diagnosis_4th_secondary_read ,
  diagnosis_5th_secondary_read ,
  diagnosis_6th_secondary_read ,
  diagnosis_7th_secondary_read ,
  diagnosis_8th_secondary_read ,
  diagnosis_9th_secondary_read ,
  diagnosis_10th_secondary_read ,
  diagnosis_11th_secondary_read ,
  diagnosis_12th_secondary_read ,
  diagnosis_13th_secondary_read ,
  diagnosis_14th_secondary_read ,
  diagnosis_15th_secondary_read ,
  diagnosis_16th_secondary_read ,
  diagnosis_17th_secondary_read ,
  diagnosis_18th_secondary_read ,
  diagnosis_19th_secondary_read ,
  diagnosis_20th_secondary_read ,
  diagnosis_21st_secondary_read ,
  diagnosis_22nd_secondary_read ,
  diagnosis_23rd_secondary_read ,
  procedure_scheme_in_use_opcs ,
  primary_procedure_opcs ,
  primary_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_1 ,
  professional_registration_issuer_code_opcs_1 ,
  responsible_anaesthetist_code_opcs_1 ,
  responsible_anaesthetist_reg_body_opcs_1 ,
  a2nd_procedure_opcs ,
  a2nd_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_2 ,
  professional_registration_issuer_code_opcs_2 ,
  responsible_anaesthetist_code_opcs_2 ,
  responsible_anaesthetist_reg_body_opcs_2 ,
  a3rd_procedure_opcs ,
  a3rd_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_3 ,
  professional_registration_issuer_code_opcs_3 ,
  responsible_anaesthetist_code_opcs_3 ,
  responsible_anaesthetist_reg_body_opcs_3 ,
  a4th_procedure_opcs ,
  a4th_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_4 ,
  professional_registration_issuer_code_opcs_4 ,
  responsible_anaesthetist_code_opcs_4 ,
  responsible_anaesthetist_reg_body_opcs_4 ,
  a5th_procedure_opcs ,
  a5th_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_5 ,
  professional_registration_issuer_code_opcs_5 ,
  responsible_anaesthetist_code_opcs_5 ,
  responsible_anaesthetist_reg_body_opcs_5 ,
  a6th_procedure_opcs ,
  a6th_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_6 ,
  professional_registration_issuer_code_opcs_6 ,
  responsible_anaesthetist_code_opcs_6 ,
  responsible_anaesthetist_reg_body_opcs_6 ,
  a7th_procedure_opcs ,
  a7th_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_7 ,
  professional_registration_issuer_code_opcs_7 ,
  responsible_anaesthetist_code_opcs_7 ,
  responsible_anaesthetist_reg_body_opcs_7 ,
  a8th_procedure_opcs ,
  a8th_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_8 ,
  professional_registration_issuer_code_opcs_8 ,
  responsible_anaesthetist_code_opcs_8 ,
  responsible_anaesthetist_reg_body_opcs_8 ,
  a9th_procedure_opcs ,
  a9th_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_9 ,
  professional_registration_issuer_code_opcs_9 ,
  responsible_anaesthetist_code_opcs_9 ,
  responsible_anaesthetist_reg_body_opcs_9 ,
  a10th_procedure_opcs ,
  a10th_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_10 ,
  professional_registration_issuer_code_opcs_10 ,
  responsible_anaesthetist_code_opcs_10 ,
  responsible_anaesthetist_reg_body_opcs_10 ,
  a11th_procedure_opcs ,
  a11th_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_11 ,
  professional_registration_issuer_code_opcs_11 ,
  responsible_anaesthetist_code_opcs_11 ,
  responsible_anaesthetist_reg_body_opcs_11 ,
  a12th_procedure_opcs ,
  a12th_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_12 ,
  professional_registration_issuer_code_opcs_12 ,
  responsible_anaesthetist_code_opcs_12 ,
  responsible_anaesthetist_reg_body_opcs_12 ,
  a13th_procedure_opcs ,
  a13th_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_13 ,
  professional_registration_issuer_code_opcs_13 ,
  responsible_anaesthetist_code_opcs_13 ,
  responsible_anaesthetist_reg_body_opcs_13 ,
  a14th_procedure_opcs ,
  a14th_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_14 ,
  professional_registration_issuer_code_opcs_14 ,
  responsible_anaesthetist_code_opcs_14 ,
  responsible_anaesthetist_reg_body_opcs_14 ,
  a15th_procedure_opcs ,
  a15th_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_15 ,
  professional_registration_issuer_code_opcs_15 ,
  responsible_anaesthetist_code_opcs_15 ,
  responsible_anaesthetist_reg_body_opcs_15 ,
  a16th_procedure_opcs ,
  a16th_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_16 ,
  professional_registration_issuer_code_opcs_16 ,
  responsible_anaesthetist_code_opcs_16 ,
  responsible_anaesthetist_reg_body_opcs_16 ,
  a17th_procedure_opcs ,
  a17th_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_17 ,
  professional_registration_issuer_code_opcs_17 ,
  responsible_anaesthetist_code_opcs_17 ,
  responsible_anaesthetist_reg_body_opcs_17 ,
  a18th_procedure_opcs ,
  a18th_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_18 ,
  professional_registration_issuer_code_opcs_18 ,
  responsible_anaesthetist_code_opcs_18 ,
  responsible_anaesthetist_reg_body_opcs_18 ,
  a19th_procedure_opcs ,
  a19th_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_19 ,
  professional_registration_issuer_code_opcs_19 ,
  responsible_anaesthetist_code_opcs_19 ,
  responsible_anaesthetist_reg_body_opcs_19 ,
  a20th_procedure_opcs ,
  a20th_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_20 ,
  professional_registration_issuer_code_opcs_20 ,
  responsible_anaesthetist_code_opcs_20 ,
  responsible_anaesthetist_reg_body_opcs_20 ,
  a21st_procedure_opcs ,
  a21st_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_21 ,
  professional_registration_issuer_code_opcs_21 ,
  responsible_anaesthetist_code_opcs_21 ,
  responsible_anaesthetist_reg_body_opcs_21 ,
  a22nd_procedure_opcs ,
  a22nd_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_22 ,
  professional_registration_issuer_code_opcs_22 ,
  responsible_anaesthetist_code_opcs_22 ,
  responsible_anaesthetist_reg_body_opcs_22 ,
  a23rd_procedure_opcs ,
  a23rd_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_23 ,
  professional_registration_issuer_code_opcs_23 ,
  responsible_anaesthetist_code_opcs_23 ,
  responsible_anaesthetist_reg_body_opcs_23 ,
  a24th_procedure_opcs ,
  a24th_procedure_date_opcs ,
  main_operating_healthcare_professional_code_opcs_24 ,
  professional_registration_issuer_code_opcs_24 ,
  responsible_anaesthetist_code_opcs_24 ,
  responsible_anaesthetist_reg_body_opcs_24 ,
  procedure_scheme_in_use_read ,
  primary_procedure_read ,
  primary_procedure_date_read ,
  a2nd_procedure_read ,
  a2nd_procedure_date_read ,
  a3rd_procedure_read ,
  a3rd_procedure_date_read ,
  a4th_procedure_read ,
  a4th_procedure_date_read ,
  a5th_procedure_read ,
  a5th_procedure_date_read ,
  a6th_procedure_read ,
  a6th_procedure_date_read ,
  a7th_procedure_read ,
  a7th_procedure_date_read ,
  a8th_procedure_read ,
  a8th_procedure_date_read ,
  a9th_procedure_read ,
  a9th_procedure_date_read ,
  a10th_procedure_read ,
  a10th_procedure_date_read ,
  a11th_procedure_read ,
  a11th_procedure_date_read ,
  a12th_procedure_read ,
  a12th_procedure_date_read ,
  a13th_procedure_read ,
  a13th_procedure_date_read ,
  a14th_procedure_read ,
  a14th_procedure_date_read ,
  a15th_procedure_read ,
  a15th_procedure_date_read ,
  a16th_procedure_read ,
  a16th_procedure_date_read ,
  a17th_procedure_read ,
  a17th_procedure_date_read ,
  a18th_procedure_read ,
  a18th_procedure_date_read ,
  a19th_procedure_read ,
  a19th_procedure_date_read ,
  a20th_procedure_read ,
  a20th_procedure_date_read ,
  a21st_procedure_read ,
  a21st_procedure_date_read ,
  a22nd_procedure_read ,
  a22nd_procedure_date_read ,
  a23rd_procedure_read ,
  a23rd_procedure_date_read ,
  a24th_procedure_read ,
  a24th_procedure_date_read ,
  ward_code_at_episode_start_date ,
  ward_security_level_at_episode_start_date ,
  location_class_at_episode_start_date ,
  site_code_of_treatment_at_episode_start_date ,
  organisation_code_type_site_code_of_treatment_at_start_of_episode ,
  intended_clinical_care_intensityat_start_of_episode ,
  ward_day_period_availability ,
  ward_night_period_availability ,
  ward_code_1 ,
  ward_security_level_1 ,
  location_class_1 ,
  site_code_of_treatment_1 ,
  organisation_code_type_site_code_of_treatment_1 ,
  intended_clinical_care_intensity_1 ,
  age_group_intended_1 ,
  ward_day_period_availability_1 ,
  ward_night_period_availability_1 ,
  start_date_1 ,
  start_time_ward_stay_1 ,
  end_date_1 ,
  end_time_ward_stay_1 ,
  ward_code_2 ,
  ward_security_level_2 ,
  location_class_2 ,
  site_code_of_treatment_2 ,
  organisation_code_type_site_code_of_treatment_2 ,
  intended_clinical_care_intensity_2 ,
  age_group_intended_2 ,
  ward_day_period_availability_2 ,
  ward_night_period_availability_2 ,
  start_date_2 ,
  start_time_ward_stay_2 ,
  end_date_2 ,
  end_time_ward_stay_2 ,
  ward_code_3 ,
  ward_security_level_3 ,
  location_class_3 ,
  site_code_of_treatment_3 ,
  organisation_code_type_site_code_of_treatment_3 ,
  intended_clinical_care_intensity_3 ,
  age_group_intended_3 ,
  ward_day_period_availability_3 ,
  ward_night_period_availability_3 ,
  start_date_3 ,
  start_time_ward_stay_3 ,
  end_date_3 ,
  end_time_ward_stay_3 ,
  ward_code_4 ,
  ward_security_level_4 ,
  location_class_4 ,
  site_code_of_treatment_4 ,
  organisation_code_type_site_code_of_treatment_4 ,
  intended_clinical_care_intensity_4 ,
  age_group_intended_4 ,
  ward_day_period_availability_4 ,
  ward_night_period_availability_4 ,
  start_date_4 ,
  start_time_ward_stay_4 ,
  end_date_4 ,
  end_time_ward_stay_4 ,
  ward_code_5 ,
  ward_security_level_5 ,
  location_class_5 ,
  site_code_of_treatment_5 ,
  organisation_code_type_site_code_of_treatment_5 ,
  intended_clinical_care_intensity_5 ,
  age_group_intended_5 ,
  ward_day_period_availability_5 ,
  ward_night_period_availability_5 ,
  start_date_5 ,
  start_time_ward_stay_5 ,
  end_date_5 ,
  end_time_ward_stay_5 ,
  ward_code_6 ,
  ward_security_level_6 ,
  location_class_6 ,
  site_code_of_treatment_6 ,
  organisation_code_type_site_code_of_treatment_6 ,
  intended_clinical_care_intensity_6 ,
  age_group_intended_6 ,
  ward_day_period_availability_6 ,
  ward_night_period_availability_6 ,
  start_date_6 ,
  start_time_ward_stay_6 ,
  end_date_6 ,
  end_time_ward_stay_6 ,
  ward_code_7 ,
  ward_security_level_7 ,
  location_class_7 ,
  site_code_of_treatment_7 ,
  organisation_code_type_site_code_of_treatment_7 ,
  intended_clinical_care_intensity_7 ,
  age_group_intended_7 ,
  ward_day_period_availability_7 ,
  ward_night_period_availability_7 ,
  start_date_7 ,
  start_time_ward_stay_7 ,
  end_date_7 ,
  end_time_ward_stay_7 ,
  ward_code_8 ,
  ward_security_level_8 ,
  location_class_8 ,
  site_code_of_treatment_8 ,
  organisation_code_type_site_code_of_treatment_8 ,
  intended_clinical_care_intensity_8 ,
  age_group_intended_8 ,
  ward_day_period_availability_8 ,
  ward_night_period_availability_8 ,
  start_date_8 ,
  start_time_ward_stay_8 ,
  end_date_8 ,
  end_time_ward_stay_8 ,
  ward_code_9 ,
  ward_security_level_9 ,
  location_class_9 ,
  site_code_of_treatment_9 ,
  organisation_code_type_site_code_of_treatment_9 ,
  intended_clinical_care_intensity_9 ,
  age_group_intended_9 ,
  ward_day_period_availability_9 ,
  ward_night_period_availability_9 ,
  start_date_9 ,
  start_time_ward_stay_9 ,
  end_date_9 ,
  end_time_ward_stay_9 ,
  ward_code_10 ,
  ward_security_level_10 ,
  location_class_10 ,
  site_code_of_treatment_10 ,
  organisation_code_type_site_code_of_treatment_10 ,
  intended_clinical_care_intensity_10 ,
  age_group_intended_10 ,
  ward_day_period_availability_10 ,
  ward_night_period_availability_10 ,
  start_date_10 ,
  start_time_ward_stay_10 ,
  end_date_10 ,
  end_time_ward_stay_10 ,
  ward_code_11 ,
  ward_security_level_11 ,
  location_class_11 ,
  site_code_of_treatment_11 ,
  organisation_code_type_site_code_of_treatment_11 ,
  intended_clinical_care_intensity_11 ,
  age_group_intended_11 ,
  ward_day_period_availability_11 ,
  ward_night_period_availability_11 ,
  start_date_11 ,
  start_time_ward_stay_11 ,
  end_date_11 ,
  end_time_ward_stay_11 ,
  ward_code_12 ,
  ward_security_level_12 ,
  location_class_12 ,
  site_code_of_treatment_12 ,
  organisation_code_type_site_code_of_treatment_12 ,
  intended_clinical_care_intensity_12 ,
  age_group_intended_12 ,
  ward_day_period_availability_12 ,
  ward_night_period_availability_12 ,
  start_date_12 ,
  start_time_ward_stay_12 ,
  end_date_12 ,
  end_time_ward_stay_12 ,
  ward_code_13 ,
  ward_security_level_13 ,
  location_class_13 ,
  site_code_of_treatment_13 ,
  organisation_code_type_site_code_of_treatment_13 ,
  intended_clinical_care_intensity_13 ,
  age_group_intended_13 ,
  ward_day_period_availability_13 ,
  ward_night_period_availability_13 ,
  start_date_13 ,
  start_time_ward_stay_13 ,
  end_date_13 ,
  end_time_ward_stay_13 ,
  ward_code_14 ,
  ward_security_level_14 ,
  location_class_14 ,
  site_code_of_treatment_14 ,
  organisation_code_type_site_code_of_treatment_14 ,
  intended_clinical_care_intensity_14 ,
  age_group_intended_14 ,
  ward_day_period_availability_14 ,
  ward_night_period_availability_14 ,
  start_date_14 ,
  start_time_ward_stay_14 ,
  end_date_14 ,
  end_time_ward_stay_14 ,
  ward_code_15 ,
  ward_security_level_15 ,
  location_class_15 ,
  site_code_of_treatment_15 ,
  organisation_code_type_site_code_of_treatment_15 ,
  intended_clinical_care_intensity_15 ,
  age_group_intended_15 ,
  ward_day_period_availability_15 ,
  ward_night_period_availability_15 ,
  start_date_15 ,
  start_time_ward_stay_15 ,
  end_date_15 ,
  end_time_ward_stay_15 ,
  ward_code_16 ,
  ward_security_level_16 ,
  location_class_16 ,
  site_code_of_treatment_16 ,
  organisation_code_type_site_code_of_treatment_16 ,
  intended_clinical_care_intensity_16 ,
  age_group_intended_16 ,
  ward_day_period_availability_16 ,
  ward_night_period_availability_16 ,
  start_date_16 ,
  start_time_ward_stay_16 ,
  end_date_16 ,
  end_time_ward_stay_16 ,
  ward_code_17 ,
  ward_security_level_17 ,
  location_class_17 ,
  site_code_of_treatment_17 ,
  organisation_code_type_site_code_of_treatment_17 ,
  intended_clinical_care_intensity_17 ,
  age_group_intended_17 ,
  ward_day_period_availability_17 ,
  ward_night_period_availability_17 ,
  start_date_17 ,
  start_time_ward_stay_17 ,
  end_date_17 ,
  end_time_ward_stay_17 ,
  ward_code_18 ,
  ward_security_level_18 ,
  location_class_18 ,
  site_code_of_treatment_18 ,
  organisation_code_type_site_code_of_treatment_18 ,
  intended_clinical_care_intensity_18 ,
  age_group_intended_18 ,
  ward_day_period_availability_18 ,
  ward_night_period_availability_18 ,
  start_date_18 ,
  start_time_ward_stay_18 ,
  end_date_18 ,
  end_time_ward_stay_18 ,
  ward_code_19 ,
  ward_security_level_19 ,
  location_class_19 ,
  site_code_of_treatment_19 ,
  organisation_code_type_site_code_of_treatment_19 ,
  intended_clinical_care_intensity_19 ,
  age_group_intended_19 ,
  ward_day_period_availability_19 ,
  ward_night_period_availability_19 ,
  start_date_19 ,
  start_time_ward_stay_19 ,
  end_date_19 ,
  end_time_ward_stay_19 ,
  ward_code_20 ,
  ward_security_level_20 ,
  location_class_20 ,
  site_code_of_treatment_20 ,
  organisation_code_type_site_code_of_treatment_20 ,
  intended_clinical_care_intensity_20 ,
  age_group_intended_20 ,
  ward_day_period_availability_20 ,
  ward_night_period_availability_20 ,
  start_date_20 ,
  start_time_ward_stay_20 ,
  end_date_20 ,
  end_time_ward_stay_20 ,
  ward_code_21 ,
  ward_security_level_21 ,
  location_class_21 ,
  site_code_of_treatment_21 ,
  organisation_code_type_site_code_of_treatment_21 ,
  intended_clinical_care_intensity_21 ,
  age_group_intended_21 ,
  ward_day_period_availability_21 ,
  ward_night_period_availability_21 ,
  start_date_21 ,
  start_time_ward_stay_21 ,
  end_date_21 ,
  end_time_ward_stay_21 ,
  ward_code_22 ,
  ward_security_level_22 ,
  location_class_22 ,
  site_code_of_treatment_22 ,
  organisation_code_type_site_code_of_treatment_22 ,
  intended_clinical_care_intensity_22 ,
  age_group_intended_22 ,
  ward_day_period_availability_22 ,
  ward_night_period_availability_22 ,
  start_date_22 ,
  start_time_ward_stay_22 ,
  end_date_22 ,
  end_time_ward_stay_22 ,
  ward_code_23 ,
  ward_security_level_23 ,
  location_class_23 ,
  site_code_of_treatment_23 ,
  organisation_code_type_site_code_of_treatment_23 ,
  intended_clinical_care_intensity_23 ,
  age_group_intended_23 ,
  ward_day_period_availability_23 ,
  ward_night_period_availability_23 ,
  start_date_23 ,
  start_time_ward_stay_23 ,
  end_date_23 ,
  end_time_ward_stay_23 ,
  ward_code_24 ,
  ward_security_level_24 ,
  location_class_24 ,
  site_code_of_treatment_24 ,
  organisation_code_type_site_code_of_treatment_24 ,
  intended_clinical_care_intensity_24 ,
  age_group_intended_24 ,
  ward_day_period_availability_24 ,
  ward_night_period_availability_24 ,
  start_date_24 ,
  start_time_ward_stay_24 ,
  end_date_24 ,
  end_time_ward_stay_24 ,
  ward_code_at_episode_end_date ,
  ward_security_level_at_episode_end_date ,
  location_class_at_episode_end_date ,
  site_code_of_treatment_at_episode_end_date ,
  organisation_code_type_site_code_of_treatment_at_episode_end_date ,
  intended_clinical_care_intensity_at_episode_end_date ,
  age_group_intended_at_episode_end_date ,
  ward_day_period_availability_at_episode_end_date ,
  ward_night_period_availability_at_episode_end_date ,
  general_medical_practitioner_code_of_registered_gmp ,
  practice_code_of_registered_gp ,
  organisation_code_type_of_registered_gp ,
  referrer_code ,
  referring_organisation_code ,
  organisation_code_type_of_referrer ,
  direct_access_referral_indicator ,
  ambulance_incident_number ,
  organisation_code_conveying_ambulance_trust ,
  duration_of_elective_wait ,
  intended_management ,
  decided_to_admit_date_for_this_provider ,
  waiting_time_measurement_type ,
  location_type_code_at_start_of_episode ,
  hrg_code ,
  hrg_version_number ,
  procedure_scheme_in_use ,
  dominant_grouping_variable_procedure ,
  fce_hrg ,
  episode_hrg_version_number ,
  spell_core_hrg ,
  spell_hrg_version_number ,
  number_of_babies ,
  first_antenatal_assessment_date ,
  gmp_code_of_gmp_responsible_for_antenatal_care ,
  code_of_gp_practice_registered_gmp_antenatal_care ,
  organisation_code_type_gp_practice_registered_gmp_antenatal_care ,
  location_class_of_delivery_place_intended ,
  location_type_of_delivery_place_intended ,
  delivery_place_change_reason ,
  delivery_place_type_intended ,
  anaesthetic_given_during_labour_delivery ,
  anaesthetic_given_post_delivery ,
  gestation_length_labour_onset ,
  labour_delivery_onset_method ,
  delivery_date ,
  birth_order_baby_1 ,
  delivery_method_baby_1 ,
  gestation_length_assessment_baby_1 ,
  resuscitation_method_baby_1 ,
  status_of_person_conducting_delivery_baby_1 ,
  organisation_code_type_local_patient_id_baby_1 ,
  digest_number_status_indicator_baby_1 ,
  birth_weight_baby_1 ,
  live_or_still_birth_baby_1 ,
  sex_baby_1 ,
  birth_location_type_1 ,
  location_class_delivery_place_actual_1 ,
  delivery_place_type_actual_1 ,
  birth_order_baby_2 ,
  delivery_method_baby_2 ,
  gestation_length_assessment_baby_2 ,
  resuscitation_method_baby_2 ,
  status_of_person_conducting_delivery_baby_2 ,
  organisation_code_local_patient_id_baby_2 ,
  organisation_code_type_local_patient_id_baby_2 ,
  digest_number_status_indicator_baby_2 ,
  birth_weight_baby_2 ,
  live_or_still_birth_baby_2 ,
  sex_baby_2 ,
  birth_location_type_2 ,
  location_class_delivery_place_actual_2 ,
  delivery_place_type_actual_2 ,
  birth_order_baby_3 ,
  delivery_method_baby_3 ,
  gestation_length_assessment_baby_3 ,
  resuscitation_method_baby_3 ,
  status_of_person_conducting_delivery_baby_3 ,
  organisation_code_local_patient_id_baby_3 ,
  organisation_code_type_local_patient_id_baby_3 ,
  digest_number_status_indicator_baby_3 ,
  birth_weight_baby_3 ,
  live_or_still_birth_baby_3 ,
  birth_location_type_3 ,
  location_class_delivery_place_actual_3 ,
  delivery_place_type_actual_3 ,
  birth_order_baby_4 ,
  delivery_method_baby_4 ,
  gestation_length_assessment_baby_4 ,
  resuscitation_method_baby_4 ,
  status_of_person_conducting_delivery_baby_4 ,
  organisation_code_local_patient_id_baby_4 ,
  organisation_code_type_local_patient_id_baby_4 ,
  digest_number_status_indicator_baby_4 ,
  birth_weight_baby_4 ,
  live_or_still_birth_baby_4 ,
  birth_location_type_4 ,
  location_class_delivery_place_actual_4 ,
  delivery_place_type_actual_4 ,
  birth_order_baby_5 ,
  delivery_method_baby_5 ,
  gestation_length_assessment_baby_5 ,
  resuscitation_method_baby_5 ,
  status_of_person_conducting_delivery_baby_5 ,
  organisation_code_local_patient_id_baby_5 ,
  organisation_code_type_local_patient_id_baby_5 ,
  digest_number_status_indicator_baby_5 ,
  birth_weight_baby_5 ,
  live_or_still_birth_baby_5 ,
  birth_location_type_5 ,
  location_class_delivery_place_actual_5 ,
  delivery_place_type_actual_5 ,
  birth_order_baby_6 ,
  delivery_method_baby_6 ,
  gestation_length_assessment_baby_6 ,
  resuscitation_method_baby_6 ,
  status_of_person_conducting_delivery_baby_6 ,
  organisation_code_local_patient_id_baby_6 ,
  organisation_code_type_local_patient_id_baby_6 ,
  digest_number_status_indicator_baby_6 ,
  birth_weight_baby_6 ,
  live_or_still_birth_baby_6 ,
  birth_location_type_6 ,
  location_class_delivery_place_actual_6 ,
  delivery_place_type_actual_6 ,
  birth_order_baby_7 ,
  delivery_method_baby_7 ,
  gestation_length_assessment_baby_7 ,
  resuscitation_method_baby_7 ,
  status_of_person_conducting_delivery_baby_7 ,
  organisation_code_local_patient_id_baby_7 ,
  organisation_code_type_local_patient_id_baby_7 ,
  digest_number_status_indicator_baby_7 ,
  birth_weight_baby_7 ,
  live_or_still_birth_baby_7 ,
  birth_location_type_7 ,
  location_class_delivery_place_actual_7 ,
  delivery_place_type_actual_7 ,
  birth_order_baby_8 ,
  delivery_method_baby_8 ,
  gestation_length_assessment_baby_8 ,
  resuscitation_method_baby_8 ,
  status_of_person_conducting_delivery_baby_8 ,
  organisation_code_local_patient_id_baby_8 ,
  organisation_code_type_local_patient_id_baby_8 ,
  digest_number_status_indicator_baby_8 ,
  birth_weight_baby_8 ,
  live_or_still_birth_baby_8 ,
  birth_location_type_8 ,
  location_class_delivery_place_actual_8 ,
  delivery_place_type_actual_8 ,
  birth_order_baby_9 ,
  delivery_method_baby_9 ,
  gestation_length_assessment_baby_9 ,
  resuscitation_method_baby_9 ,
  status_of_person_conducting_delivery_baby_9 ,
  organisation_code_local_patient_id_baby_9 ,
  organisation_code_type_local_patient_id_baby_9 ,
  digest_number_status_indicator_baby_9 ,
  birth_weight_baby_9 ,
  live_or_still_birth_baby_9 ,
  birth_location_type_9 ,
  location_class_delivery_place_actual_9 ,
  delivery_place_type_actual_9 ,
  gestation_length_assessment_baby ,
  organisation_code_local_patient_identifier_mother ,
  organisation_code_type_mother ,
  digest_number_status_indicator_mother ,
  postcode_of_mother ,
  organisation_code_pct_of_residence_mother ,
  organisation_code_type_pct_of_residence_mother ,
  unique_booking_reference_number_converted ,
  patient_pathway_identifier ,
  organisation_code_patient_pathway_identifier_issuer ,
  referral_to_treatment_period_status ,
  referral_to_treatment_period_start_date ,
  referral_to_treatment_period_end_date ,
  lead_care_activity_indicator ,
  nhs_service_agreement_change_date ,
  cds_activity_date ,
  admin_category_at_start ,
  hospital_provider_spell_discharge_ready_date ,
  location_type ,
  xml_version ,
  referral_to_treatment_length_derived ,
  age_range_patient_derived_from_dob ,
  age_range_mother_derived_from_dob ,
  area_code_derived_from_postcode_ ,
  cds_group ,
  finished_indicator ,
  pct_derived_from_gp ,
  pct_type_derived_from_gp ,
  gp_practice_derived ,
  gp_practice_mother_derived ,
  pct_derived_from_derived_gp_practice ,
  pct_mother_derived_from_derived_gp_practice ,
  sha_from_gp_practice ,
  sha_type_from_gp_practice ,
  hospital_spell_duration ,
  month_of_birth ,
  home_birth_or_delivery ,
  electoral_ward_from_postcode ,
  pct_from_postcode ,
  pct_type_from_postcode ,
  sha_from_postcode ,
  sha_type_from_postcode ,
  area_code_from_provider_postcode ,
  year_of_birth_mother ,
  month_of_birth_mother ,
  a2001_census_area ,
  country ,
  county_code ,
  a1991_census_ed ,
  ed_district_code ,
  electoral_ward_code ,
  gor_code ,
  local_unitary_authority ,
  old_sha_code ,
  a1998_electoral_area ,
  prime_recipient ,
  copy_recipients ,
  critical_care_local_identifier_1 ,
  critical_care_start_date_1 
from ', sourcedb,'.tbl_apc_finished_susplus src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "") 
tb20 <- bq_project_query(project_id, sql20)

sql21 <-paste('update ', targetdb,'.tbl_apc_finished_susplus
set tbl_apc_finished_susplus_end_date = tbl_apc_finished_susplus_start_date
where tbl_apc_finished_susplus_end_date is null and tbl_apc_finished_susplus_start_date is not null ; ', sep = "") 
tb21 <- bq_project_query(project_id, sql21)

print(' tbl_apc_finished_susplus done' ) 

 sql22 <-paste('drop table if exists ', targetdb,'.tbl_autism_amalgamated_ptl_oct2022; ', sep = "") 
tb22 <- bq_project_query(project_id, sql22)


sql23 <-paste('CREATE  TABLE ', targetdb,'.tbl_autism_amalgamated_ptl_oct2022
as 
select distinct 
dem.person_id,
cast(substring( referral_date,7,4) || "-" || substring( referral_date,4,2) || "-" || substring(referral_date,1,2)  as date) as tbl_autism_amalgamated_ptl_oct2022_start_date ,
cast(substring( referral_date,7,4) || "-" || substring( referral_date,4,2) || "-" || substring(referral_date,1,2)  as date) as tbl_autism_amalgamated_ptl_oct2022_end_date,
  date ,
  trust ,
  department ,
  gender_assigned_at_birth ,
  year_of_birth ,
  month_of_birth ,
  age_will_update_automatically ,
  ethnicity ,
  src.digest ,
  gp ,
  ccg ,
  pathway_allocated ,
  asd_adhd ,
  lac ,
  ehcp ,
  started_assessment ,
  started_october_2022 ,
  first_contact_autism_assessment_dd_mm_yyyy ,
  school_info_dd_mm_yyyy ,
  school_obs_dd_mm_yyyy ,
  ados_dd_mm_yyyy ,
  salt_dd_mm_yyyy ,
  qb_dd_mm_yyyy ,
  cognitive_assessment ,
  mdt_dd_mm_yyyy ,
  feedback_given_dd_mm_yyyy ,
  jac_report_circulated_dd_mm_yyyy ,
  referral_date ,
  referral_source ,
  breach_date_13_weeks_to_first_contact ,
  weeks_waiting_until_case_closed_will_update_automatically ,
  diagnosis ,
  date_closed_dd_mm_yyyy_when_closed_from_neuro ,
  outsourced_yn 
from ', sourcedb,'.tbl_autism_amalgamated_ptl_oct2022 src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "") 
tb23 <- bq_project_query(project_id, sql23)


sql24 <-paste('update ', targetdb,'.tbl_autism_amalgamated_ptl_oct2022
set tbl_autism_amalgamated_ptl_oct2022_end_date = tbl_autism_amalgamated_ptl_oct2022_start_date
where tbl_autism_amalgamated_ptl_oct2022_end_date is null and tbl_autism_amalgamated_ptl_oct2022_start_date is not null ; ', sep = "") 
tb24 <- bq_project_query(project_id, sql24)

print('tbl_autism_amalgamated_ptl_oct2022 done') 

 sql25 <-paste('drop table if exists ', targetdb,'.tbl_critical_care_ICNARC_observation; ', sep = "") 
tb25 <- bq_project_query(project_id, sql25)

sql26 <-paste('CREATE  TABLE ', targetdb,'.tbl_critical_care_ICNARC_observation
as 
select 
dem.person_id,
cast(date_daily as date) as tbl_critical_care_ICNARC_observation_start_date,
cast(date_daily as date) as tbl_critical_care_ICNARC_observation_end_date,
  src.digest ,
  l_central_temp ,
  h_central_temp ,
  l_noncentral_temp ,
  h_noncentral_temp ,
  l_systolic_bp ,
  p_diastolic_bp_for_lsysbp ,
  h_systolic_bp ,
  p_diastolic_bp_for_hsysbp ,
  l_diastolic_bp ,
  p_systolic_bp_for_ldiabp ,
  h_diastolic_bp ,
  p_systolic_bp_for_hdiabp ,
  l_heart_rate ,
  h_heart_rate ,
  l_nonvent_resprate ,
  h_nonvent_resprate ,
  l_vent_resprate ,
  h_vent_resprate ,
  pao2_artbg_lpao2 ,
  assoc_fio2_artbg_lpao2 ,
  assoc_paco2_artbg_lpao2 ,
  assoc_ph_hplus_artbg_lpao2 ,
  assoc_intustat_artbg_lpao2 ,
  fio2_intubartbg_hfio2 ,
  assoc_pao2_intuartbg_hfio2 ,
  assoc_paco2_intuartbg_hfio2 ,
  assoc_ph_hplus_intuartbg_hfio2 ,
  ph_hplus_artbg_lph_hplus ,
  assoc_paco2_artbg_lph_hplus ,
  ph_hplus_artbg_hph_hplus ,
  assoc_paco2_artbg_hph_hplus ,
  cpap_during_fst24hrs ,
  l_serum_bicarbonate ,
  h_serum_bicarbonate ,
  l_serum_sodium ,
  h_serum_sodium ,
  l_serum_potassium ,
  h_serum_potassium ,
  h_serum_urea ,
  l_serum_creatinine ,
  h_serum_creatinine ,
  urine_output ,
  l_serum_glucose ,
  h_serum_glucose ,
  h_serum_bilirubin ,
  transaminase_ast ,
  l_serum_calcium ,
  h_serum_calcium ,
  l_ionserum_calcium ,
  h_ionserum_calcium ,
  l_serum_albumin ,
  h_serum_albumin ,
  l_haematocrit ,
  h_haematocrit ,
  l_haemoglobin ,
  h_haemoglobin ,
  l_white_blood_cellcount ,
  h_white_blood_cellcount ,
  l_platelet_count ,
  h_prothrombin_time ,
  h_partial_thromboplastin_time ,
  morphology ,
  pupillary_reactions ,
  sedatorparalysedandsedat_fst24 ,
  presedation_gcs_docum ,
  presedation_total_gcs ,
  expected_neurological_status ,
  l_total_gcs ,
  assoc_eye_ltotalgcs ,
  assoc_motor_ltotalgcs ,
  assoc_verbal_ltotalgcs ,
  assoc_intubstatus_ltotalgcs ,
  mean_arterial_bp ,
  date_daily ,
  day_study_count ,
  transaminase_alt ,
  day_in_unit ,
  physio_completed ,
  blood_taken ,
  bed_id ,
  carelevel_acp ,
  advance_resp ,
  basic_resp ,
  circulatory ,
  neurological ,
  renal ,
  acptotalorgsupp ,
  nurseshift ,
  day_id ,
  ain_id ,
  sco_id ,
  plan ,
  ward_round_summary ,
  sepsis_screened ,
  sepsis_positiveresult ,
  advcardio ,
  basiccardio ,
  derma ,
  liver ,
  gastrointest ,
  ccmdstotalorgsupp ,
  ephys ,
  p_serum_bicarbonate ,
  m_serum_bicarbonate ,
  pre_serum_yes ,
  p_serum_sodium ,
  m_serum_sodium ,
  pre_sodium_yes ,
  p_serum_potasium ,
  m_serum_potasium ,
  pre_potasium_yes ,
  bicarbonate_data ,
  sodium_data ,
  potasium_data ,
  m_blood_gases ,
  h_blood_lactate ,
  p_blood_lactate ,
  m_blood_lactate ,
  pre_blood_lactate ,
  p_urea ,
  m_urea ,
  pre_urea ,
  h_urea ,
  pre_serum_creat ,
  m_creat ,
  p_creat ,
  m_urine ,
  pre_haemoglobin ,
  m_haemoglobin ,
  p_haemoglobin ,
  pre_platelet ,
  p_platelet ,
  m_platelet ,
  pre_bloodcount ,
  p_bloodcount ,
  m_bloodcount ,
  mrsa ,
  cdiff ,
  amuai ,
  nuaib ,
  mouaib ,
  carelevel_ccmds ,
  ephys_4_superquery ,
  missing_gcs ,
  m_glucose ,
  p_serum_glucose ,
  pre_serum_glucose ,
  anclwbc ,
  anchwbc ,
  ancpwbc ,
  pupilreactivity_m ,
  pupilreactivity_l ,
  pupilreactivity_r ,
  haemoglobin_unit ,
  icucons ,
  icucons_date ,
  icucons_time ,
  icucons_delay ,
  icucons_delaytime ,
  rehabassessedfirst24h ,
  m_haematocrit ,
  lastchdby_userid ,
  lastchdby_date ,
  lastchdby_time ,
  lastchgdby_usertmpstr STRING
from ', sourcedb,'.tbl_critical_care_ICNARC_observation src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "") 
tb26 <- bq_project_query(project_id, sql26)

sql27 <-paste('update ', targetdb,'.tbl_critical_care_ICNARC_observation
set tbl_critical_care_ICNARC_observation_end_date = tbl_critical_care_ICNARC_observation_start_date
where tbl_critical_care_ICNARC_observation_end_date is null and tbl_critical_care_ICNARC_observation_start_date is not null ; ', sep = "") 
tb27 <- bq_project_query(project_id, sql27)

print(' tbl_critical_care_ICNARC_observation done' ) 

 sql28 <-paste('drop table if exists ', targetdb,'.tbl_critical_care_adult; ', sep = "") 
tb28 <- bq_project_query(project_id, sql28)


sql29 <-paste('CREATE  TABLE ', targetdb,'.tbl_critical_care_adult
as 
select 
dem.person_id,
cast(left(critical_care_start_date_time,19) as datetime) as tbl_critical_care_adult_start_date,
cast(left(critical_care_end_date_time,19) as datetime)as tbl_critical_care_adult_end_date,
  critical_care_identifier ,
  episode_number ,
  src.digest ,
  age_on_admission ,
  person_stated_gender_code ,
  site_code ,
  critical_care_start_date_time ,
  critical_care_end_date_time ,
  critical_care_length_of_stay ,
  critical_care_length_of_stay_in_minutes ,
  cc_admission_type ,
  cc_unit_function ,
  treatment_function ,
  fce_hrg ,
  advanced_respiratory_support_days ,
  basic_respiratory_support_days ,
  advanced_cardiovascular_support_days ,
  basic_cardiovascular_support_days ,
  renal_support_days ,
  neurological_system_support_days ,
  dermatological_system_support_days ,
  gastro_intestinal_system_support_days ,
  liver_system_support_days ,
  organ_support_maximum ,
  critical_care_level_2_days ,
  critical_care_level_3_days ,
  provider ,
  critical_care_subset STRING
from ', sourcedb,'.tbl_critical_care_adult src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "") 
tb29 <- bq_project_query(project_id, sql29)


sql30 <-paste('update ', targetdb,'.tbl_critical_care_adult
set tbl_critical_care_adult_end_date = tbl_critical_care_adult_start_date
where tbl_critical_care_adult_end_date is null and tbl_critical_care_adult_start_date is not null ; ', sep = "") 
tb30 <- bq_project_query(project_id, sql30)

sql31 <-paste('drop table if exists ', targetdb,'.cb_PMH_MaternityDataset; ', sep = "") 
tb31 <- bq_project_query(project_id, sql31)

sql32 <-paste('CREATE  TABLE ', targetdb,'.cb_PMH_MaternityDataset
as 
SELECT * FROM ', sourcedb,'.tbl_PMH_MaternityDataset ; ', sep = "")
tb32 <- bq_project_query(project_id, sql32)

print('tbl_critical_care_adult done' ) 

sql33 <-paste('drop table if exists ', targetdb,'.tbl_critical_care_full_data_2015_2021; ', sep = "") 
tb33 <- bq_project_query(project_id, sql33)

sql34 <-paste('CREATE  TABLE ', targetdb,'.tbl_critical_care_full_data_2015_2021 as 
SELECT dem.person_id,
case when length(event_date) <9 then null else cast(substring(event_date,7,4) ||"-"||substring(event_date,4,2)||"-"||substring(event_date,4,2) || " " || event_time  as datetime) end as tbl_critical_care_full_data_2015_2021_start_date,
case when length(event_date) <9 then null else cast(substring(event_date,7,4) ||"-"||substring(event_date,4,2)||"-"||substring(event_date,4,2) || " " || event_time  as datetime) end as tbl_critical_care_full_data_2015_2021_end_date,
address_1,
adm_is_ver2_adm,
admstatus,
age_1,
age_decimal,
bed,
body_mass_index,
ccmds_type,
country,
county,
currently_or_recently_pregnant,
year_of_birth,
ethnicity,
dob_estimated,
exported_to_icnarc,
false_nhs_no,
health_authority,
first_name_1,
height,
height_estimate,
height_measured,
height_not_known,
hospital_number,
is_this_a_readmission,
marital_status,
middle_name,
missed_fields_icnarc_export,
month_component_for_age,
src.digest,
patient_cancelled,
patient_discharged,
patient_ever_admitted,
patient_in_unit,
patient_refused,
patients_information,
post_code_1,
religion,
sex,
surname_1,
title_1,
town_1,
uk_postcode,
unknown_post_code,
weight,
weight_estimate,
weight_measured,
weight_not_known,
actual_date_of_delivery,
assisted_conception,
expected_date_of_delivery,
gestation_of_current_pregnancy,
gestation_of_recent_pregnancy,
hysterectomy_recent_pregnancy,
molar_pregnancy,
no_of_babies_nicu_recent_preg,
no_of_live_births_or_stillbirth,
no_of_livebirths_recent_preg,
no_of_previous_caesarean,
no_of_stillbirths_recent_preg,
outcome_of_recent_pregnancy,
pregnancy_id,
admission_information,
admission_number,
admission_type_1,
admission_ward,
asa_score,
booked_unit_admission_date,
cpr_24h_prior_unit_admission,
booked_unit_admission_time,
critical_care_prior_to_adm,
date_1st_managed_by_unit_team,
date_of_last_critical_care,
delay_hrs,
episode_id,
hospital_admission_date,
hospital_housing_location_1,
housing_transient_location,
icnarc_comments,
icnarc_comments_v3,
location_1,
location_prior_to_adm_source,
managed_by_unit_team,
number_of_staffed_beds,
original_hosp_admission_date,
original_unit_admission_date,
other_intermediate_care_area_1,
outreach_1st_visit_date,
outreach_action_taken,
outreach_last_visit_date_1,
outreach_care_level,
outreach_last_visit_date,
outreach_last_visit_time,
outreach_mews,
outreach_scored_on_ward,
outreach_total_no_of_visits,
outreach_visited_prior_to_adm,
pik_id,
planned_admission,
presurgical_preparation,
prior_location,
prioradm_ward,
re_adm_reason,
reason_for_nonadmission,
residence_prior_to_admission,
sector,
source_of_unit_admission,
surgery_classification,
surgery_type,
tags_1,
time_1st_managed_by_unit_team,
timeliness_of_admission_to_your_unit,
transfer_on,
unit,
unit_admission_date,
unit_admission_time,
classification_in,
classification_out,
event_date,
event_time,
prior_transfer_in,
same_trust_1,
transfer_in_reason,
transfer_out_reason,
transfer_within_network_in,
transfer_within_network_out,
transferred_from,
transferred_to,
transfers_information,
type_adult_icu_in,
type_adult_icu_out,
ult_classification_out,
ult_hospital_transto,
ult_reasonfor_out,
ult_transfer_within_network_out,
ult_type_adult_icu_out,
unit_admission_number,
ult_unit_identifier_out,
unit_identifier_in,
unit_identifier_out,
burns_surface_area,
diagnosis_information,
inhalation_injury,
other_condition_1_code,
other_condition_1_condition,
other_condition_1_process,
other_condition_1_site,
other_condition_1_system,
other_condition_1_type,
other_condition_2_condition,
other_condition_2_code,
other_condition_2_process,
other_condition_2_system,
other_condition_2_site,
other_condition_2_type,
othreas_adm1_notes,
othreas_adm2_notes,
primary_reason_code,
primary_reason_condition,
primary_reason_process,
primary_reason_site,
primary_reason_system,
primary_reason_type,
reason_adm1_notes,
reason_adm2_notes,
reason_for_admission_to_unit_1,
reason_for_admission_to_unit_2,
reason_for_admission_to_unit_3,
reason_for_admission_to_unit_4,
secondary_reason_code,
secondary_reason_condition,
secondary_reason_process,
secondary_reason_site,
secondary_reason_system,
secondary_reason_type,
ultimate_reason_admission_code,
ultimate_reason_admission_condition,
ultimate_reason_admission_process,
ultimate_reason_admission_system,
ultimate_reason_admission_site,
ultimate_reason_admission_type,
ultreason_adm_notes,
active_1,
address_2,
address_3,
anaesthetist,
consultant_information,
date_unit_left_1,
first_name_2,
on_call,
postcode_1,
search_name_1,
signature_list_1,
speciality_1,
speciality_2,
surname_2,
telephone_1,
title_2,
coma_or_deep_stupor_mpm0,
coma_or_deep_stupor_mpm24,
continuous_iv_drug_for_1hrplusorminus,
date_extubated,
heart_rate,
infection_confirmed,
intracranial_mass_effect,
mpm_information,
systolic_bp_1,
time_extubated,
total_intubated,
acp_main_hosp_speciality,
antimicrobials_used_to_treat_unitacquired_infection,
assent_for_solid_organ,
bed_ready_date,
bed_ready_time,
brainstem_death_declared,
cause_of_death,
classification_of_surgery,
clostridium_difficile,
critical_care_post_discharge,
cvc_related_cdiff,
cvc_related_mrsa,
cvc_related_vre,
date_brainstem_death,
date_of_death,
date_of_first_critical_care,
death_outside_unit,
date_ult_unit_discharge,
demise,
destination_1,
discharge_delay,
discharge_ward,
hospital_housing_location,
length_of_ultimate_unit_stay,
length_of_unit_stay,
length_of_unit_stay_ready,
length_stay_days_decimal,
length_stay_days_decimal_ready,
length_stay_days_rounded,
length_stay_days_rounded_ready,
level_of_care_recd_at_discharge,
location_2,
mews_at_discharge,
main_organism_causing_first_unitacquired_infection_in_blood,
mouais,
mrsa,
nuais,
number_of_unitacquired_infections_present_in_blood,
organ_donor,
organ_donor_v3,
other_intermediate_care_area,
ready_for_discharge_date_1,
ready_for_discharge_time_1,
reason_for_delay,
reason_for_discharge,
reason_for_discharge_v3,
referred_to_transplant,
rehabilitation_prescription,
residence_post_discharge,
same_trust_2,
same_trust,
sector_of_other_hospital,
status_at_unit_discharge,
status_ult_unit_discharge,
surgery_up_to_one_week,
time_body_removed,
time_brainstem_death,
time_of_death,
timeliness_of_discharge,
treatment_withdrawn,
treatment_withdrawn_date,
treatment_withdrawn_time,
treatment_witheld_date,
treatment_withheld_time,
unit_discharge_date,
unit_discharge_time,
unit_outcome_information,
vre_present,
unit_remain_hours_till_ready,
date_hospital_discharge,
destination,
destination_post_discharge_v3,
expected_dependency_post_disch,
hospital_outcome_information,
length_hospital_stay_string,
length_of_hospital_stay,
length_of_ultimate_hosp_stay,
length_of_ultimate_hosp_stay_string,
status_hospital_discharge,
status_overall,
status_ult_hospital_discharge,
specialitydoctor_information,
address_4,
active_2,
date_unit_left_2,
date_unit_left_3,
doctor_information_1,
doctor_type_1,
first_name_3,
postcode_2,
search_name_2,
signature_list_2,
speciality_1a,
surname_3,
telephone_2,
title_3,
nhs_code,
old_item,
speciality_2a,
speciality_information,
address_5,
date_unit_left_4,
gp_information_1,
first_name_4,
gp_information,
nation_code,
post_code_4,
practice_code,
search_name,
surname_5,
telephone_3,
title_4,
acute_myelogenous_or_lymphocytic_leukaemia_or_multiple_myeloma,
aids,
chemotherapy,
chronic_renal_replacement_therapy,
chronic_myelogenous_or_lymphocytic_leukaemia,
congenital_immunohumoral_or_cellular_immune_deficiency_state,
evidence_to_assess_pmh,
hepatic_encephalopathy,
home_ventilation,
icnarc_pmh_information,
metastatic_disease,
other_condition,
other_condition_code,
other_condition_condition,
other_condition_notes,
other_condition_process,
other_condition_site,
other_condition_system,
other_condition_type,
pmh_present,
portal_hypertension,
radiotherapy,
severe_respiratory_disease,
steroid_treatment,
very_severe_cv_disease,
departmentdoctor_information,
active,
address_6,
date_unit_left,
doctor_information,
doctor_type,
first_name,
postcode,
signature_list,
speciality,
surname,
title,
department,
department_information,
admission_source,
admission_type,
advanced_cardiovascular_days,
advanced_respiratory_days,
basic_respiratory_days,
basic_cardiovascular_days,
bed_configuration,
dermatological_days,
discharge_date,
discharge_destination,
discharge_location_3,
discharge_location,
discharge_status,
discharge_time,
gastrointestinal_days,
hrg_code,
hrg_organ_support,
level_0_days,
level_1_days,
level_3_days,
liver_days,
max_organ_support,
neurological_days,
patient_admitted,
ready_for_discharge_date,
ready_for_discharge_time,
source_location,
start_date,
start_time,
treatment_speciality,
unit_function,
address,
fax,
hospital_information,
hospital_name,
icnarc_hospital_code,
post_code,
town,
acptotalorgsupp_1,
advanced_cardiovascular_1,
assoc_paco2_artbg_lpao2_1,
assoc_paco2_intuartbg_hfio2_1,
assoc_ph_hplus_artbg_lpao2_1,
assoc_ph_hplus_intuartbg_hfio2_1,
associated_eye_1,
associated_fio2_for_l_pao2_1,
associated_intubation_status_1,
associated_paco2_for_h_ph_h_1,
associated_paco2_for_l_ph_h_1,
associated_verbal_1,
basic_cardiovascular_1,
basic_respiratory_1,
blood_taken_1,
care_level_acp_1,
care_level_ccmds_1,
ccmds_total_organs_supported,
circulatory,
cpap_during_fst24hrs_1,
daily_assess_information,
date_1,
day_in_unit_1,
day_study_count_1,
dermatological_1,
evidence_available_to_abstract_physiology_data_1,
fio2_1,
flag_preadmission_blood_1,
flag_preadmission_creatanine_1,
flag_preadmission_potasium_1,
flag_preadmission_serum_1,
flag_preadmission_serum_sodium,
flag_preadmission_serum_urea_1,
flag_preadmission_sodium_1,
gcs_status_1,
higest_blood_lactate_1,
higest_ph_h_1,
highest_assoc_abs_neutrophil_cnt_1,
highest_central_temperature_1,
highest_diastolic_bp_1,
highest_haematocrit_1,
highest_haemoglobin_1,
highest_heart_rate_1,
highest_nonventilated_respiratory_rate_1,
highest_prothrombin_time_1,
highest_serum_albumin,
highest_serum_bicarbonate_1,
highest_serum_calcium_1,
highest_serum_gucose_1,
highest_serum_sodium_1,
highest_systolic_bp_1,
highest_ventilated_respiratory_rate_1,
liver_1,
lowest_assoc_abs_neutrophil_cnt_1,
lowest_central_temperature_1,
lowest_haematocrit_1,
lowest_haemoglobin_1,
lowest_heart_rate_1,
lowest_ionised_serum_calcium_1,
lowest_noncentral_temperature,
lowest_platelet_count_1,
lowest_serum_bicarbonate_1,
lowest_serum_calcium_1,
lowest_serum_glucose_1,
lowest_serum_potassium_1,
lowest_serum_sodium_1,
lowest_total_gcs_1,
lowest_ventilated_respiratory_rate_1,
lowest_white_blood_cell_count_1,
missing_blood_count_1,
missing_blood_lactate_1,
missing_haemoglobin_1,
missing_platelet_1,
missing_serum_bicarbonate_1,
missing_serum_potasium_1,
missing_serum_sodium_1,
missing_urine,
neurological_1,
neurological_2,
nurses_shift_1,
paired_diastolic_bp_for_highest_sistolic_bp_1,
paired_sistolic_bp_for_highest_diastolic_bp_1,
paired_systolic_bp_for_lowest_diastolic_bp,
pao2_1,
physio_completed_1,
plan_1,
preadmission_assoc_abs_neutrophil_cnt_1,
preadmission_blood_lactate_1,
preadmission_platelet_1,
preadmission_serum_glucose_1,
preadmission_serum_glucose_value_1,
preadmission_serum_urea_1,
presedation_gcs_1,
presedation_total_gcs_1,
pupil_reactivity_left_1,
pupil_reactivity_right_1,
rehabilitation_assessed_in_first_24h,
renal_1,
seen_by_icu_consultant_1,
SeenbyICUConsultant_1,
seen_by_icu_consultant_delay_string_1,
seen_by_icu_consultant_delay_time_1,
seen_by_icu_consultant_time_1,
sepsis_positive_result_1,
transaminase_alt_1,
transaminase_ast_1,
urine_output_1,
ward_round_summary_1,
worst_pupil_reactions_1,
apache_ii,
apache_ii_number,
apache_ii_probabilty,
cpis,
date_score_was_calculated,
day_in_unit_2,
groups_and_items,
icnarc_model_physiolology_percentage,
icnarc_model_physiolology_probability,
icnarc_no_calculation_reason_1,
icnarc_no_calculation_reason_2,
icnarc_no_calculation_reason,
icnarc_risk_prediction_model_probability_numeric_1,
icnarc_risk_prediction_model_probability_numeric,
lods,
mofs,
mpmii_0,
mpmii_24,
patient_information,
possum,
prism,
saps_ii,
saps_ii_probability,
sepsis,
sofa,
age,
end_date,
episode_number,
location,
number_of_organs_supported,
planned_indicator,
speciality_function,
date_2,
notes_3,
signed_by,
time_3,
type,
allocation_order,
dateto,
display_order,
status,
timeto,
bed_information,
bed_name,
date_removed,
funded,
src.notes,
comments,
date_3,
death_date,
time_n,
date_started,
intervention_days_info,
use_in,
advanced_cardiovascular_system,
advanced_respiratory_system,
basic_cardiovascular_system,
basic_respiratory_system,
default_care_level_ccmds,
defaulted,
dermatological_system,
description,
groups_and_items_info,
infusion,
liver_system,
not_deletable,
not_modifiable,
renal_system,
tags,
two_level2isl3,
id,
site,
acptotalorgsupp,
advanced_cardiovascular,
assoc_intub_status_total_gcs,
assoc_paco2_artbg_lpao2,
assoc_paco2_intuartbg_hfio2,
assoc_ph_hplus_intuartbg_hfio2,
associated_eye,
associated_fio2_for_l_pao2,
associated_intubation_status,
associated_motor,
associated_verbal,
basic_cardiovascular,
basic_respiratory,
blood_taken,
care_level_acp,
care_level_ccmds,
cpap_during_fst24hrs,
date_n,
day_study_count,
evidence_available_to_abstract_physiology_data,
fio2,
flag_preadmission_creatanine,
flag_preadmission_platelet,
flag_preadmission_potasium,
flag_preadmission_serum,
flag_preadmission_serum_urea,
flag_preadmission_sodium,
gastrointestinal,
higest_blood_lactate,
higest_ion_serum_calcium,
higest_ph_h_2,
highest_assoc_abs_neutrophil_cnt,
highest_diastolic_bp,
highest_haematocrit,
highest_haemoglobin,
highest_heart_rate,
highest_noncentral_temperature,
highest_nonventilated_respiratory_rate,
highest_prothrombin_time,
highest_serum_bicarbonate,
highest_serum_calcium,
highest_serum_creatinine,
highest_serum_potassium,
highest_serum_sodium,
highest_serum_urea,
highest_systolic_bp,
highest_ventilated_respiratory_rate,
highest_white_blood_cell_count,
liver,
lowest_assoc_abs_neutrophil_cnt,
lowest_diastolic_bp,
lowest_haemoglobin,
lowest_ionised_serum_calcium,
lowest_nonventilated_respiratory_rate,
lowest_platelet_count,
lowest_serum_bicarbonate,
lowest_serum_calcium,
lowest_serum_potassium,
lowest_serum_sodium,
lowest_total_gcs,
lowest_white_blood_cell_count,
missing_blood_count,
missing_blood_gases,
missing_creatinine,
missing_haemoglobin,
missing_serum_bicarbonate,
missing_serum_potasium,
missing_serum_sodium,
missing_urea,
morphology,
neurological,
nurses_shift,
paired_diastolic_bp_for_highest_sistolic_bp,
paired_diastolic_bp_for_systolic_bp,
pao2,
physio_completed,
pic_drop,
plan,
preadmission_assoc_abs_neutrophil_cnt,
preadmission_blood_lactate_value,
preadmission_haemoglobin,
preadmission_serum_bicarbonate,
preadmission_serum_glucose_value,
preadmission_serum_potasium,
preadmission_serum_urea,
presedation_total_gcs,
pupil_reactivity_left,
presedation_gcs,
pupil_reactivity_right,
renal,
sedated_paralysed_and_sedated,
seen_by_icu_consultant,
seen_by_icu_consultant_delay_time,
seen_by_icu_consultant_time,
sepsis_positive_result,
sepsis_screened,
urine_output,
worst_pupil_reactions,
 FROM ', sourcedb,'.tbl_critical_care_full_data_2015_2021 src
  left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "") 
tb34<- bq_project_query(project_id, sql34)




sql35 <-paste('update ', targetdb,'.tbl_critical_care_full_data_2015_2021
set tbl_critical_care_full_data_2015_2021_end_date = tbl_critical_care_full_data_2015_2021_start_date
where tbl_critical_care_full_data_2015_2021_end_date is null and tbl_critical_care_full_data_2015_2021_start_date is not null ; ', sep = "")
tb35 <- bq_project_query(project_id, sql35)

print(' tbl_critical_care_full_data_2015_2021 done') 

 sql36 <-paste('drop table if exists ', targetdb,'.tbl_critical_care_neonatal; ', sep = "") 
tb36 <- bq_project_query(project_id, sql36)

sql37 <-paste('CREATE  TABLE ', targetdb,'.tbl_critical_care_neonatal
as 
select 
dem.person_id,
cast(left(critical_care_start_date_time,19) as datetime) as tbl_critical_care_neonatal_start_date,
cast(left(critical_care_end_date_time,19) as datetime) as tbl_critical_care_neonatal_end_date,
  acp_refno ,
  episode_number ,
  src.digest ,
  age_on_admission ,
  person_stated_gender_code ,
  site_code ,
  critical_care_start_date_time ,
  critical_care_end_date_time ,
  critical_care_length_of_stay ,
  critical_care_length_of_stay_in_minutes ,
  cc_unit_function ,
  provider ,
  critical_care_subset 
from ', sourcedb,'.tbl_critical_care_neonatal  src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "") 
tb37 <- bq_project_query(project_id, sql37)

sql38 <-paste('update ', targetdb,'.tbl_critical_care_neonatal
set tbl_critical_care_neonatal_end_date = tbl_critical_care_neonatal_start_date
where tbl_critical_care_neonatal_end_date is null and tbl_critical_care_neonatal_start_date is not null ; ', sep = "") 
tb38 <- bq_project_query(project_id, sql38)

print(' tbl_critical_care_neonatal done') 

 sql39 <-paste('drop table if exists ', targetdb,'.tbl_critical_care_neonatal_daily; ', sep = "") 
tb39 <- bq_project_query(project_id, sql39)

sql40 <-paste('CREATE  TABLE ', targetdb,'.tbl_critical_care_neonatal_daily
as 
select 
cast(left(critical_care_activity_date_dt,19) as datetime) as tbl_critical_care_neonatal_daily_start_date,
cast(left(critical_care_activity_date_dt,19) as datetime) as tbl_critical_care_neonatal_daily_end_date,
  acp_refno ,
  cc_daily_uid ,
  hrg_code ,
  critical_care_activity_date_dt ,
  critical_care_person_weight ,
  ccac_01 ,
  ccac_02 ,
  ccac_03 ,
  ccac_04 ,
  ccac_05 ,
  ccac_06 ,
  ccac_07 ,
  ccac_08 ,
  ccac_09 ,
  ccac_10 ,
  ccac_11 ,
  ccac_12 ,
  ccac_13 ,
  ccac_14 ,
  ccac_15 ,
  ccac_16 ,
  ccac_17 ,
  ccac_18 ,
  ccac_19 ,
  ccac_20 
from ', sourcedb,'.tbl_critical_care_neonatal_daily  ; ', sep = "") 
tb40 <- bq_project_query(project_id, sql40)


sql41 <-paste('update ', targetdb,'.tbl_critical_care_neonatal_daily
set tbl_critical_care_neonatal_daily_end_date = tbl_critical_care_neonatal_daily_start_date
where tbl_critical_care_neonatal_daily_end_date is null and tbl_critical_care_neonatal_daily_start_date is not null ; ', sep = "") 
tb41 <- bq_project_query(project_id, sql41)


print('tbl_critical_care_neonatal_daily done ')
# Out:
# [1] " tbl_apc_finished_susplus done"
# [1] "tbl_autism_amalgamated_ptl_oct2022 done"
# [1] " tbl_critical_care_ICNARC_observation done"
# [1] "tbl_critical_care_adult done"
# [1] " tbl_critical_care_full_data_2015_2021 done"
# [1] " tbl_critical_care_neonatal done"
# [1] "tbl_critical_care_neonatal_daily done "

# %%
sql42 <-paste('drop table if exists ', targetdb,'.tbl_ec_backward_compatible_susplus; ', sep = "") 
tb42 <- bq_project_query(project_id, sql42)

sql43 <-paste('CREATE TABLE ', targetdb,'.tbl_ec_backward_compatible_susplus
as 
select 
dem.person_id,
cast((left(arrival_date,4) ||"-"|| substring(arrival_date,5,2) ||"-"||substring(arrival_date,7,2) ||" "|| arrival_time||":00" ) as datetime) as  tbl_ec_backward_compatible_susplus_start_date,
cast((left(aande_departure_date,4) ||"-"|| substring(aande_departure_date,5,2) ||"-"||substring(aande_departure_date,7,2) ||" "|| aande_departure_time  ) as datetime) as tbl_ec_backward_compatible_susplus_end_date,
  identifier ,
  src.digest ,
  generated_record_identifier ,
  reason_for_access ,
  cds_type ,
  protocol_identifier ,
  update_type ,
  bulk_replacement_cds_group ,
  test_indicator ,
  applicable_date_time ,
  census_date ,
  extract_date_time ,
  report_period_start_date ,
  report_period_end_date ,
  organisation_code_sender_of_transaction ,
  organisation_code_type_of_sender ,
  cds_interchange_id ,
  organisation_code_local_patient_identifier ,
  organisation_code_type_local_patient_identifier ,
  birth_year ,
  birth_month ,
  carer_support_indicator ,
  digest_number_trace_status ,
  withheld_identity_reason ,
  sex ,
  name_format_code ,
  address_format_code ,
  postcode ,
  organisation_code_residence_responsibility ,
  pct_of_residence ,
  organisation_code_type_pct_of_residence ,
  osv_classification_at_cds_activity_date ,
  general_medical_practitioner_code_of_registered_gmp ,
  practice_code_of_registered_gp ,
  organisation_code_type_of_registered_gp ,
  aande_attendance_number ,
  aande_arrival_mode ,
  aande_attendance_category ,
  aande_attendance_disposal ,
  aande_incident_location_type ,
  aande_patient_group ,
  source_of_referral_for_aande ,
  arrival_date ,
  arrival_time ,
  aande_attendance_conclusion_time ,
  aande_attendance_conclusion_date ,
  aande_departure_time ,
  aande_departure_date ,
  aande_initial_assessment_time_first_and_unplanned_followup_attendances_only ,
  aande_initial_assessment_date ,
  aande_time_seen_for_treatment ,
  site_code_of_treatment ,
  waiting_time_measurement_type ,
  ambulance_incident_number ,
  organisation_code_conveying_ambulance_trust ,
  commissioning_serial_number ,
  nhs_service_agreement_line_number ,
  provider_reference_number ,
  commissioner_reference_number ,
  organisation_code_code_of_provider ,
  organisation_code_type_of_provider ,
  organisation_code_code_of_commissioner ,
  organisation_code_type_of_commissioner ,
  aande_staff_member_code ,
  diagnosis_scheme_in_use ,
  accident_and_emergency_diagnosis_first ,
  accident_and_emergency_diagnosis_second ,
  accident_and_emergency_diagnosis_third ,
  accident_and_emergency_diagnosis_fourth ,
  accident_and_emergency_diagnosis_fifth ,
  accident_and_emergency_diagnosis_sixth ,
  accident_and_emergency_diagnosis_seventh ,
  accident_and_emergency_diagnosis_eighth ,
  accident_and_emergency_diagnosis_ninth ,
  accident_and_emergency_diagnosis_tenth ,
  accident_and_emergency_diagnosis_eleventh ,
  accident_and_emergency_diagnosis_twelfth ,
  accident_and_emergency_diagnosis_thirteenth ,
  accident_and_emergency_diagnosis_fourteenth ,
  accident_and_emergency_diagnosis_fifteenth ,
  accident_and_emergency_diagnosis_sixteenth ,
  accident_and_emergency_diagnosis_seventeenth ,
  accident_and_emergency_diagnosis_eighteenth ,
  accident_and_emergency_diagnosis_nineteenth ,
  accident_and_emergency_diagnosis_twentieth ,
  accident_and_emergency_diagnosis_twenty_first ,
  accident_and_emergency_diagnosis_twenty_second ,
  accident_and_emergency_diagnosis_twenty_third ,
  accident_and_emergency_diagnosis_twenty_fourth ,
  investigation_scheme_in_use ,
  accident_and_emergency_investigation_first ,
  accident_and_emergency_investigation_second ,
  accident_and_emergency_investigation_third ,
  accident_and_emergency_investigation_fourth ,
  accident_and_emergency_investigation_fifth ,
  accident_and_emergency_investigation_sixth ,
  accident_and_emergency_investigation_seventh ,
  accident_and_emergency_investigation_eighth ,
  accident_and_emergency_investigation_ninth ,
  accident_and_emergency_investigation_tenth ,
  accident_and_emergency_investigation_eleventh ,
  accident_and_emergency_investigation_twelfth ,
  accident_and_emergency_investigation_thirteenth ,
  accident_and_emergency_investigation_fourteenth ,
  accident_and_emergency_investigation_fifteenth ,
  accident_and_emergency_investigation_sixteenth ,
  accident_and_emergency_investigation_seventeenth ,
  accident_and_emergency_investigation_eighteenth ,
  accident_and_emergency_investigation_nineteenth ,
  accident_and_emergency_investigation_twentieth ,
  accident_and_emergency_investigation_twenty_first ,
  accident_and_emergency_investigation_twenty_second ,
  accident_and_emergency_investigation_twenty_third ,
  accident_and_emergency_investigation_twenty_fourth ,
  treatment_scheme_in_use ,
  accident_and_emergency_treatment_first ,
  accident_and_emergency_treatment_second ,
  accident_and_emergency_treatment_third ,
  accident_and_emergency_treatment_fourth ,
  accident_and_emergency_treatment_fifth ,
  accident_and_emergency_treatment_sixth ,
  accident_and_emergency_treatment_seventh ,
  accident_and_emergency_treatment_eighth ,
  accident_and_emergency_treatment_ninth ,
  accident_and_emergency_treatment_tenth ,
  accident_and_emergency_treatment_eleventh ,
  accident_and_emergency_treatment_twelfth ,
  accident_and_emergency_treatment_thirteenth ,
  accident_and_emergency_treatment_fourteenth ,
  accident_and_emergency_treatment_fifteenth ,
  accident_and_emergency_treatment_sixteenth ,
  accident_and_emergency_treatment_seventeenth ,
  accident_and_emergency_treatment_eighteenth ,
  accident_and_emergency_treatment_nineteenth ,
  accident_and_emergency_treatment_twentieth ,
  accident_and_emergency_treatment_twenty_first ,
  accident_and_emergency_treatment_twenty_second ,
  accident_and_emergency_treatment_twenty_third ,
  accident_and_emergency_treatment_twenty_fourth ,
  hrg_code ,
  hrg_version_number ,
  procedure_scheme_in_use ,
  dominant_grouping_variable_procedure ,
  fce_hrg ,
  spell_core_hrg_version_no ,
  pbr_generated_core_hrg_for_information ,
  pbr_generated_core_hrg_version_for_information ,
  unique_booking_reference_number_converted ,
  patient_pathway_identifier ,
  organisation_code_patient_pathway_identifier_issuer ,
  referral_to_treatment_period_status ,
  referral_to_treatment_period_start_date ,
  referral_to_treatment_period_end_date ,
  lead_care_activity_indicator ,
  nhs_service_agreement_change_date ,
  cds_activity_date ,
  aande_department_type ,
  xml_version ,
  referral_to_treatment_length_derived ,
  ae_assessment_wait_time ,
  ae_conclusion_wait_time ,
  ae_duration ,
  ae_treatment_wait ,
  area_code_derived_from_postcode_ ,
  cds_group ,
  finished_indicator ,
  pct_derived_from_gp ,
  pct_type_derived_from_gp ,
  gp_practice_derived ,
  pct_derived_from_derived_gp_practice ,
  sha_from_gp_practice ,
  sha_type_from_gp_practice ,
  month_of_birth ,
  electoral_ward_from_postcode ,
  pct_from_postcode ,
  pct_type_from_postcode ,
  sha_from_postcode ,
  sha_type_from_postcode ,
  area_code_from_provider_postcode ,
  year_of_birth ,
  a2001_census_area ,
  country ,
  county_code ,
  a1991_census_ed ,
  ed_district_code ,
  electoral_ward_code ,
  gor_code ,
  local_unitary_authority ,
  old_sha_code ,
  a1998_electoral_area ,
  prime_recipient ,
  copy_recipients 
from ', sourcedb,'.tbl_ec_backward_compatible_susplus  src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "") 
tb43 <- bq_project_query(project_id, sql43)
#print(sql43) 

sql44 <-paste('update ', targetdb,'.tbl_ec_backward_compatible_susplus
set tbl_ec_backward_compatible_susplus_end_date = tbl_ec_backward_compatible_susplus_start_date
where tbl_ec_backward_compatible_susplus_end_date is null and tbl_ec_backward_compatible_susplus_start_date is not null ; ', sep = "") 
tb44 <- bq_project_query(project_id, sql44)

print('tbl_ec_backward_compatible_susplus done')
# Out:
# [1] "tbl_ec_backward_compatible_susplus done"

# %%
sql45 <-paste('drop table if exists  ', targetdb,'.tbl_episode; ', sep = "") 
tb45 <- bq_project_query(project_id, sql45)

sql46 <-paste('CREATE  TABLE ', targetdb,'.tbl_episode
as 
select 
dem.person_id,
cast(left(episode_start_date_time,19) as datetime) as tbl_episode_start_date,
cast(left(episode_end_date_time,19) as datetime) as tbl_episode_end_date,
  episode_number ,
  spell_number ,
  episode_sequence ,
  src.digest ,
  gender ,
  birth_year ,
  birth_month ,
  death_year ,
  death_month ,
  practice ,
  episode_start_date_time ,
  episode_end_date_time ,
  episode_start_date ,
  episode_start_time ,
  episode_end_date ,
  episode_end_time ,
  episode_duration ,
  current_episode ,
  last_episode_in_spell ,
  operation_status ,
  start_ward ,
  end_ward ,
  start_treatment_function_local ,
  start_treatment_function ,
  end_treatment_function_local ,
  end_treatment_function ,
  consultant_specialty_local ,
  consultant_specialty ,
  start_site_local ,
  start_site ,
  end_site_local ,
  end_site ,
  provider ,
  purchaser ,
  diagnoses ,
  diagnosis_1 ,
  diagnosis_2 ,
  diagnosis_3 ,
  diagnosis_4 ,
  diagnosis_5 ,
  diagnosis_6 ,
  diagnosis_7 ,
  diagnosis_8 ,
  diagnosis_9 ,
  diagnosis_10 ,
  diagnosis_11 ,
  diagnosis_12 ,
  diagnosis_13 ,
  diagnosis_14 ,
  diagnosis_15 ,
  diagnosis_16 ,
  diagnosis_17 ,
  diagnosis_18 ,
  diagnosis_19 ,
  diagnosis_20 ,
  diagnosis_21 ,
  diagnosis_22 ,
  diagnosis_23 ,
  diagnosis_24 ,
  diagnosis_25 ,
  diagnosis_26 ,
  diagnosis_27 ,
  diagnosis_28 ,
  diagnosis_29 ,
  diagnosis_30 ,
  procedures ,
  procedure_1 ,
  procedure_1_date ,
  procedure_2 ,
  procedure_2_date ,
  procedure_3 ,
  procedure_3_date ,
  procedure_4 ,
  procedure_4_date ,
  procedure_5 ,
  procedure_5_date ,
  procedure_6 ,
  procedure_6_date ,
  procedure_7 ,
  procedure_7_date ,
  procedure_8 ,
  procedure_8_date ,
  procedure_9 ,
  procedure_9_date ,
  procedure_10 ,
  procedure_10_date ,
  procedure_11 ,
  procedure_11_date ,
  procedure_12 ,
  procedure_12_date ,
  procedure_13 ,
  procedure_13_date ,
  procedure_14 ,
  procedure_14_date ,
  procedure_15 ,
  procedure_15_date ,
  procedure_16 ,
  procedure_16_date ,
  procedure_17 ,
  procedure_17_date ,
  procedure_18 ,
  procedure_18_date ,
  procedure_19 ,
  procedure_19_date ,
  procedure_20 ,
  procedure_20_date ,
  procedure_21 ,
  procedure_21_date ,
  procedure_22 ,
  procedure_22_date ,
  procedure_23 ,
  procedure_23_date ,
  procedure_24 ,
  procedure_24_date ,
  procedure_25 ,
  procedure_25_date ,
  procedure_26 ,
  procedure_26_date ,
  procedure_27 ,
  procedure_27_date ,
  procedure_28 ,
  procedure_28_date ,
  procedure_29 ,
  procedure_29_date ,
  procedure_30 ,
  procedure_30_date ,
  consultant_local ,
  consultant ,
  neonatal_level_of_care_local ,
  neonatal_level_of_care ,
  pathway_id ,
  booking_reference_number ,
  pathway_id_issuer ,
  rtt_period_status ,
  commissioning_serial_number ,
  hrg_code_episode ,
  hrg_code_spell ,
  pss_fce_npoc ,
  pss_service_line ,
  pss_spell_service_line ,
  pss_commissioner_code 
from ', sourcedb,'.tbl_episode  src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "") 
tb46 <- bq_project_query(project_id, sql46)

sql47 <-paste('update ', targetdb,'.tbl_episode
set tbl_episode_end_date = tbl_episode_start_date
where tbl_episode_end_date is null and tbl_episode_start_date is not null ; ', sep = "") 
tb47 <- bq_project_query(project_id, sql47)

print(' tbl_episode done') 

sql48 <-paste('drop table if exists ', targetdb,'.cb_episode_diagnosis; ', sep = "") 
tb48 <- bq_project_query(project_id, sql48)

sql49 <-paste('CREATE  TABLE ', targetdb,'.cb_episode_diagnosis
as
select 
cast(episode_start_date as datetime) as cb_episode_diagnosis_start_date,
cast(episode_end_date as datetime)  as cb_episode_diagnosis_end_date,
  episode_serial ,
  spell_number ,
  episode_start_date ,
  episode_end_date ,
  diagnosis ,
  diagnosis_description ,
  sort_order ,
  fk_consultant_episode STRING
from ', sourcedb,'.cb_episode_diagnosis  src; ', sep = "") 
tb49 <- bq_project_query(project_id, sql49)


sql50 <-paste('update ', targetdb,'.cb_episode_diagnosis
set cb_episode_diagnosis_end_date = cb_episode_diagnosis_start_date
where cb_episode_diagnosis_end_date is null and cb_episode_diagnosis_start_date is not null ; ', sep = "") 
tb50 <- bq_project_query(project_id, sql50)

print('cb_episode_diagnosis done') 

sql51 <-paste('drop table if exists ', targetdb,'.cb_episode_procedure; ', sep = "") 
tb51 <- bq_project_query(project_id, sql51)


sql52 <-paste('CREATE  TABLE ', targetdb,'.cb_episode_procedure
as select 
cast(episode_start_date as datetime) as cb_episode_procedure_start_date,
cast(episode_end_date as datetime) as cb_episode_procedure_end_date,
  episode_serial ,
  spell_number ,
  episode_start_date ,
  episode_end_date ,
  procedure_code ,
  procedure_description ,
  sort_order ,
  procedure_date ,
  fk_consultant_episode STRING
from ', sourcedb,'.cb_episode_procedure; ', sep = "") 
tb52 <- bq_project_query(project_id, sql52)



sql60 <-paste('update ', targetdb,'.cb_episode_procedure
set cb_episode_procedure_end_date = cb_episode_procedure_start_date
where cb_episode_procedure_end_date is null and cb_episode_procedure_start_date is not null ; ', sep = "") 
tb60 <- bq_project_query(project_id, sql60)

print('cb_episode_procedure done') 


sql61 <-paste('drop table if exists ', targetdb,'.tbl_maternity_birth; ', sep = "") 
tb61 <- bq_project_query(project_id, sql61)

sql62 <-paste('CREATE  TABLE ', targetdb,'.tbl_maternity_birth
as
select 
dem.person_id,
cast(left(date_of_pregnancy_outcome_current_fetus,19) as datetime) as tbl_maternity_birth_start_date,
cast(left(date_of_pregnancy_outcome_current_fetus,19) as datetime) as tbl_maternity_birth_end_date,
  birth_serial ,
  delivery_serial ,
  sequence_num ,
  records ,
  apgar_score_05_minutes ,
  artificial_rupture_of_membranes_reason ,
  artificial_rupture_of_membranes_reason_desc ,
  babydigest ,
  month_nhs_number_salt_pseudonym as monthdigest ,
  baby_year_of_birth ,
  baby_month_of_birth ,
  baby_time_of_birth ,
  baby_breast_milk_status_at_discharge_from_hospital ,
  baby_breast_milk_status_at_discharge_from_hospital_desc ,
  baby_first_feed_breast_milk_status ,
  baby_first_feed_breast_milk_status_desc ,
  baby_first_feed_date ,
  baby_first_feed_time ,
  birth_order_maternity_services ,
  birth_weight_in_grams ,
  date_of_pregnancy_outcome_current_fetus ,
  delivered_in_water_indicator ,
  delivery_method_current_baby ,
  delivery_place_type_code_actual ,
  delivery_place_type_code_actual_desc ,
  delivery_place_type_actual_midwifery_unit_type ,
  delivery_place_type_actual_midwifery_unit_type_desc ,
  exclude_cds ,
  exclude_msds ,
  fk_consultant_episode ,
  episode_serial ,
  hospital_provider_spell_number ,
  episode_number ,
  spell_episode_los ,
  live_or_still_birth ,
  registerable_birth ,
  fetal_order_fetus_outcome ,
  pregnancy_outcome_current_fetus ,
  pregnancy_outcome_current_fetus_desc ,
  provider ,
  purchaser ,
  fk_outpatient_act ,
  presentation_at_onset_of_labour ,
  presentation_at_onset_of_labour_desc ,
  rupture_of_membranes_date ,
  rupture_of_membranes_time ,
  rupture_of_membranes_method ,
  rupture_of_membranes_method_desc ,
  skin_to_skin_contact_within_one_hour ,
  site_code_of_actual_place_of_delivery ,
  site_code_of_actual_place_of_delivery_desc ,
  status_of_person_conducting_delivery_code ,
  status_of_person_conducting_delivery_code_desc ,
  resuscitation_method ,
  resuscitation_method_desc ,
  fed_1_hour ,
  breast_milk_48_hrs 
from ', sourcedb,'.tbl_maternity_birth
 src
 left join  ', demodb,' dem
on src.babydigest = dem.digest; ', sep = "") 
tb62 <- bq_project_query(project_id, sql62)

sql63 <-paste('update ', targetdb,'.tbl_maternity_birth
set tbl_maternity_birth_end_date = tbl_maternity_birth_start_date
where tbl_maternity_birth_end_date is null and tbl_maternity_birth_start_date is not null ; ', sep = "") 
tb63 <- bq_project_query(project_id, sql63)

print('tbl_maternity-birth done') 

sql64 <-paste('drop table if exists ', targetdb,'.tbl_maternity_care_plan; ', sep = "") 
tb64 <- bq_project_query(project_id, sql64)

sql65 <-paste('CREATE  TABLE ', targetdb,'.tbl_maternity_care_plan
as 
select 
dem.person_id,
cast(left(maternity_care_plan_date,19) as datetime) as tbl_maternity_care_plan_start_date,
cast(left(maternity_care_plan_date,19) as datetime)  as tbl_maternity_care_plan_end_date,
  pk_obs_fact_maternity_care_plan ,
  maternity_care_plan_serial ,
  src.digest ,
  pregnancy_identifier ,
  maternity_care_plan_date ,
  maternity_care_plan_type ,
  maternity_care_plan_type_desc ,
  maternity_personalised_care_plan_indicator ,
  continuity_of_carer_pathway_indicator ,
  maternity_care_setting_of_planned_delivery ,
  maternity_care_setting_of_planned_delivery_desc ,
  planned_delivery_setting_change_reason_antenatal ,
  planned_delivery_setting_change_reason_antenatal_desc ,
  exclude_msds  from ', sourcedb,'.tbl_maternity_care_plan src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "") 
tb65 <- bq_project_query(project_id, sql65)

sql66 <-paste('update ', targetdb,'.tbl_maternity_care_plan
set tbl_maternity_care_plan_end_date = tbl_maternity_care_plan_start_date
where tbl_maternity_care_plan_end_date is null and tbl_maternity_care_plan_start_date is not null ; ', sep = "") 
tb66 <- bq_project_query(project_id, sql66)

print('tbl_maternity_care_plan done') 

sql67 <-paste('drop table if exists  ', targetdb,'.cb_maternity_delivery; ', sep = "") 
tb67 <- bq_project_query(project_id, sql67)

sql68 <-paste('CREATE  TABLE ', targetdb,'.cb_maternity_delivery
as 
select 
dem.person_id,
  delivery_serial ,
  deliveryminutes ,
  abnormality_detected_dating_ultrasound_scan ,
  activity_date_antenatal_appointment ,
  activity_not_offered_reason_code_for_maternity_dating_ultrasound_scan ,
  activity_not_offered_reason_code_for_maternity_dating_ultrasound_scan_desc ,
  activity_offer_date_dating_ultrasound_scan ,
  anaesthesia_given_during_labour_or_delivery ,
  anaesthesia_given_during_labour_or_delivery_desc ,
  anaesthesia_given_post_labour_or_delivery ,
  anaesthesia_given_post_labour_or_delivery_desc ,
  appointment_date_formal_antenatal_booking ,
  cigarettes_per_day_mother_at_booking ,
  commissioning_serial_number ,
  complex_social_factors_indicator_mother_at_booking ,
  contract_serial ,
  date_of_decision_to_deliver ,
  time_of_decision_to_deliver ,
  delivery_time ,
  delivery_of_placenta_method ,
  delivery_of_placenta_method_desc ,
  discharge_date_mother_maternity_services ,
  discharge_time_mother_maternity_services ,
  employment_status_mother_at_booking ,
  employment_status_mother_at_booking_desc ,
  employment_status_partner_at_booking ,
  employment_status_partner_at_booking_desc ,
  end_of_third_stage_of_labour_time ,
  episiotomy_performed_reason ,
  estimated_date_of_delivery_method_agreed ,
  estimated_date_of_delivery_method_agreed_desc ,
  exclude_cds ,
  exclude_msds ,
  exclude_pbr ,
  expected_delivery_date ,
  expected_delivery_time ,
  general_medical_practitioner_antenatal_care ,
  gestation_length_in_days_dating_ultrasound_scan ,
  gestation_length_in_weeks_at_assessment ,
  gestation_length_in_weeks_labour_onset ,
  labour_or_delivery_onset_method_code ,
  labour_or_delivery_onset_method_code_desc ,
  last_menstrual_period_date ,
  mental_health_prediction_and_detection_indicator_mother_at_booking ,
  src.digest ,
  nhs_service_agreement_line_number ,
  number_of_fetuses_dating_ultrasound_scan ,
  onset_of_established_labour_time ,
  #onset_of_second_stage_of_labour_date ,
  onset_of_second_stage_of_labour_time ,
  organisation_code_postnatal_pathway_lead_provider ,
  patient_classification_code ,
  patient_classification_code_desc ,
  person_height_in_meters_mother_at_booking ,
  person_weight_in_kilograms_mother_at_booking ,
  physical_disability_code_mother_at_booking ,
  physical_disability_status_indicator_mother_at_booking ,
  place_of_delivery_intended ,
  place_of_delivery_intended_desc ,
  pregnancy_first_contact_date ,
  pregnancy_first_contact_time ,
  pregnancy_previous_caesarean_sections ,
  pregnancy_total_previous_live_births ,
  pregnancy_total_previous_losses_less_than_24_weeks ,
  pregnancy_total_previous_neonatal_deaths ,
  pregnancy_total_previous_pregnancies ,
  pregnancy_total_previous_stillbirths ,
  procedure_date_dating_ultrasound_scan ,
  procedure_time_dating_ultrasound_scan ,
  procedure_date_caesarean_section ,
  procedure_time_caesarean_section ,
  provider ,
  provider_reference_number ,
  provider_reference ,
  purchaser ,
  referrer ,
  responsible_pco ,
  rtt_period_no ,
  rtt_period_status ,
  smoking_status_mother_at_booking ,
  smoking_status_mother_at_booking_desc ,
  smoking_status_mother_at_end_of_pregnancy ,
  smoking_status_mother_at_end_of_pregnancy_desc ,
  status_of_folic_acid_supplement_mother_at_booking ,
  status_of_folic_acid_supplement_mother_at_booking_desc ,
  substance_use_status_mother_at_booking ,
  substance_use_status_mother_at_booking_desc ,
  support_status_mother_at_booking ,
  weekly_alcohol_units_mother_at_booking ,
  artificial_rupture_of_membranes_reason ,
  artificial_rupture_of_membranes_reason_desc ,
  #rupture_of_membranes_date ,
  rupture_of_membranes_time ,
  rupture_of_membranes_method ,
  rupture_of_membranes_method_desc ,
  #datetime_of_decision_to_deliver ,
  number_of_babies STRING
from ', sourcedb,'.tbl_maternity_delivery  src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "") 
tb68 <- bq_project_query(project_id, sql68)

print('tbl_maternity_delivery done') 

sql69 <-paste('drop table if exists ', targetdb,'.tbl_maternity_pathway_antenatal; ', sep = "") 
tb69 <- bq_project_query(project_id, sql69)

sql70 <-paste('CREATE  TABLE ', targetdb,'.tbl_maternity_pathway_antenatal
as 
select 
dem.person_id,
cast(left(date_of_booking,19) as datetime) as tbl_maternity_pathway_antenatal_start_date,
cast(left(date_of_booking,19) as datetime) as tbl_maternity_pathway_antenatal_end_date,
  src.digest ,
  gp ,
  practice_code ,
  gp_code ,
  date_of_booking ,
  pregnancy_number ,
  pathway_category ,
  booking ,
  multiple ,
  intensive ,
  med_intensive ,
  intermediate ,
  med_intermediate ,
  ccg ,
  identifier
from ', sourcedb,'.tbl_maternity_pathway_antenatal  src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "") 
tb70 <- bq_project_query(project_id, sql70)

sql71 <-paste('update ', targetdb,'.tbl_maternity_pathway_antenatal
set tbl_maternity_pathway_antenatal_end_date = tbl_maternity_pathway_antenatal_start_date
where tbl_maternity_pathway_antenatal_end_date is null and tbl_maternity_pathway_antenatal_start_date is not null ; ', sep = "") 
tb71 <- bq_project_query(project_id, sql71)

print('tbl_maternity_pathway_antenatal done') 

sql72 <-paste('drop table if exists ', targetdb,'.cb_maternity_pathway_postnatal; ', sep = "") 
tb72 <- bq_project_query(project_id, sql72)

sql73 <-paste('CREATE  TABLE ', targetdb,'.cb_maternity_pathway_postnatal
as 
select 
dem.person_id,
planned_delivery_time_minutes ,
  src.digest ,
  #delivery_date_time ,
  place_of_birth ,
  practice ,
  practice_name ,
  inpatient_location ,
  #date_of_discharge_planned ,
  type_of_assessment ,
  postnatal_day ,
  location_of_assessment ,
  pbr_delivery_pathway ,
  pbr_delivery_pathway_items_checked_and_complete ,
  postnatal_pathway_category ,
  maternity_lead_provider_1 ,
  maternity_lead_provider_2 ,
  outcome_of_pregnancy ,
  key_events_date_of_clinical_discharge ,
  date_of_discharge_or_transfer ,
  home_birth ,
  termination_or_miscarriage ,
  hospital_delivery ,
  final_ccg_code ,
  postnataltariff ,
  comments ,
  identifier 
from ', sourcedb,'.tbl_maternity_pathway_postnatal src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "") 
tb73 <- bq_project_query(project_id, sql73)


print('tbl_maternity_pathway_postnatal done') 


sql74 <-paste('drop table if exists ', targetdb,'.tbl_maternity_pregnancy_and_booking_details; ', sep = "") 
tb74 <- bq_project_query(project_id, sql74)

sql75 <-paste('CREATE  TABLE ', targetdb,'.tbl_maternity_pregnancy_and_booking_details
as 
select 
dem.person_id,
cast(left(antenatal_appointment_date,19) as datetime) as tbl_maternity_pregnancy_and_booking_details_start_date,
cast(left(antenatal_appointment_date,19) as datetime) as tbl_maternity_pregnancy_and_booking_details_end_date,
  pregnancy_identifier ,
  src.digest ,
  antenatal_appointment_date ,
  source_of_referral_for_maternity ,
  source_of_referral_for_maternity_desc ,
  late_antenatal_booking_appointment_reason ,
  late_antenatal_booking_appointment_reason_desc ,
  pregnancy_first_contact_date ,
  last_menstrual_period_date ,
  estimated_date_of_delivery_agreed_date2 ,
  estimated_date_of_delivery_method_agreed ,
  estimated_date_of_delivery_method_agreed_desc ,
  status_of_folic_acid_supplement_mother_at_booking ,
  status_of_folic_acid_supplement_mother_at_booking_desc ,
  employment_status_mother_at_booking ,
  employment_status_mother_at_booking_desc ,
  support_status_mother_at_booking ,
  support_status_mother_at_booking_desc ,
  partner_status_mother_at_booking ,
  partner_status_mother_at_booking_desc ,
  physical_disability_status_indicator_mother_at_booking ,
  mental_health_prediction_and_detection_indicator_mother_at_booking ,
  complex_social_factors_indicator_mother_at_booking ,
  pregnancy_previous_caesarean_sections ,
  pregnancy_total_previous_live_births ,
  pregnancy_total_previous_stillbirths ,
  pregnancy_total_previous_losses_less_than_24_weeks ,
  primary_discharge_reason_mother_maternity_services ,
  discharge_date_mother_maternity_services ,
  primary_discharge_reason_mother_maternity_services_desc ,
  exclude_msds 
from ', sourcedb,'.tbl_maternity_pregnancy_and_booking_details  src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "") 
tb75 <- bq_project_query(project_id, sql75)

sql76 <-paste('update ', targetdb,'.tbl_maternity_pregnancy_and_booking_details
set tbl_maternity_pregnancy_and_booking_details_end_date = tbl_maternity_pregnancy_and_booking_details_start_date
where tbl_maternity_pregnancy_and_booking_details_end_date is null and tbl_maternity_pregnancy_and_booking_details_start_date is not null ; ', sep = "") 
tb76 <- bq_project_query(project_id, sql76)


print('tbl_maternity_pregnancy_and_booking_details done') 
#Note this is a derived table so doesn not follow normal convention
#therefore prefixed with cb

sql77 <-paste('drop table if exists ', targetdb,'.cb_mother_child_relationship; ', sep = "") 
tb77 <- bq_project_query(project_id, sql77)

sql78 <-paste('CREATE  TABLE ', targetdb,'.cb_mother_child_relationship
as select 
mother_person_id ,
baby_person_id ,
date_of_decision_to_deliver
from  ', sourcedb,'.tbl_mother_child_relationship  src; ', sep = "") 
tb78 <- bq_project_query(project_id, sql78)

print('cb_mother_child_relationship done ') 



sql79 <-paste('drop table if exists ', targetdb,'.tbl_outpatient; ', sep = "") 
tb79 <- bq_project_query(project_id, sql79)

sql80 <-paste('CREATE  TABLE ', targetdb,'.tbl_outpatient
as
 select 
dem.person_id,
cast(attendance_date ||" "|| attendance_time as datetime) as tbl_outpatient_start_date,
cast(attendance_date ||" "|| attendance_time as datetime) as tbl_outpatient_end_date,
  appointment_serial ,
  src.digest ,
  practice ,
  practice_name ,
  postcode ,
  birth_year ,
  birth_month ,
  death_year ,
  death_month ,
  gender ,
  clinic_session_code ,
  clinic_session_name ,
  raw_appointment_type ,
  attendance_date_time ,
  attendance_date ,
  attendance_time ,
  start_age ,
  source_of_referral_local ,
  source_of_referral ,
  source_of_referral_description ,
  referral_request_received_date ,
  site_local ,
  site ,
  site_local_description ,
  consultant_specialty_local ,
  consultant_specialty ,
  consultant_specialty_description ,
  attended_didnot_attend_local ,
  attended_didnot_attend ,
  attended_didnot_attend_description ,
  clinic ,
  treatment_function ,
  treatment_function_description ,
  treatment_function_local ,
  clinician ,
  clinician_name ,
  consultant_local ,
  consultant_name ,
  administrative_category_local ,
  administrative_category ,
  administrative_category_description ,
  first_attendance_local ,
  first_attendance ,
  first_attendance_description ,
  medical_staff_type_local ,
  medical_staff_type_local_description ,
  procedure_no ,
  diagnosis_no ,
  investigation_no ,
  procedure_1 ,
  procedure_1_description ,
  procedure_2 ,
  procedure_2_description ,
  procedure_3 ,
  procedure_3_description ,
  procedure_4 ,
  procedure_4_description ,
  procedure_5 ,
  procedure_5_description ,
  procedure_6 ,
  procedure_6_description ,
  procedure_7 ,
  procedure_7_description ,
  procedure_8 ,
  procedure_8_description ,
  procedure_9 ,
  procedure_9_description ,
  procedure_10 ,
  procedure_10_description ,
  procedure_11 ,
  procedure_11_description ,
  procedure_12 ,
  procedure_12_description ,
  op_referral_request_type_local ,
  op_referral_request_type ,
  op_location_type_local ,
  op_location_type ,
  location_type_local_description ,
  type_of_referrer_local ,
  operation_status_local ,
  operation_status ,
  op_priority_local ,
  op_priority ,
  op_priority_description ,
  provider ,
  provider_name ,
  purchaser ,
  purchaser_name ,
  contract_serial ,
  attendance_outcome_local ,
  attendance_outcome ,
  attendance_outcome_description ,
  pathway_id ,
  booking_reference_number ,
  rtt_period_status ,
  pathway_id_issuer ,
  hrg_code ,
  hrg_description ,
  hrg_version ,
  pss_service_line ,
  referral_serial STRING
from ', sourcedb,'.tbl_outpatient  src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "")
tb80 <- bq_project_query(project_id, sql80)

sql81 <-paste('update ', targetdb,'.tbl_outpatient
set tbl_outpatient_end_date = tbl_outpatient_start_date
where tbl_outpatient_end_date is null and tbl_outpatient_start_date is not null ; ', sep = "") 
tb81 <- bq_project_query(project_id, sql81)


print('tbl_outpatient done') 

sql82 <-paste('drop TABLE IF EXISTS  ', targetdb,'.tbl_outpatients_susplus; ', sep = "") 
tb82 <- bq_project_query(project_id, sql82)

sql83 <-paste('CREATE  TABLE ', targetdb,'.tbl_outpatients_susplus
as 
select 
dem.person_id,
cast(left(appointment_date,4) ||"-"||substring(appointment_date,5,2) ||"-"||substring(appointment_date,1,2) ||" "|| appointment_time ||":00" as datetime) as tbl_outpatients_susplus_start_date,
cast(left(appointment_date,4) ||"-"||substring(appointment_date,5,2) ||"-"||substring(appointment_date,1,2) ||" "|| appointment_time ||":00" as datetime) as tbl_outpatients_susplus_end_date,
  identifier ,
  src.digest ,
  generated_record_identifier ,
  reason_for_access ,
  cds_type ,
  protocol_identifier ,
  sus_generated_spell_id ,
  update_type ,
  bulk_replacement_cds_group ,
  test_indicator ,
  applicable_date_time ,
  census_date ,
  extract_date_time ,
  report_period_start_date ,
  report_period_end_date ,
  organisation_code_sender_of_transaction ,
  organisation_code_type_of_sender ,
  submission_date ,
  cds_interchange_id ,
  organisation_code_local_patient_identifier ,
  organisation_code_type_local_patient_identifier ,
  birth_year ,
  birth_month ,
  carer_support_indicator ,
  digest_number_trace_status ,
  withheld_identity_reason ,
  sex ,
  name_format_code ,
  address_format_code ,
  postcode ,
  organisation_code_residence_responsibility ,
  pct_of_residence ,
  organisation_code_type_pct_of_residence ,
  osv_classification_at_cds_activity_date ,
  consultant_code ,
  main_specialty_code ,
  treatment_function_code ,
  local_sub_specialty_code ,
  multiprofessional_or_multidisciplinary_ind_code ,
  rehabilitation_assessment_team_type ,
  diagnosis_scheme_in_use_icd ,
  diagnosis_primary_icd ,
  present_on_admission_indicator_diag_1 ,
  diagnosis_1st_secondary_icd ,
  present_on_admission_indicator_diag_2 ,
  diagnosis_2nd_secondary_icd ,
  present_on_admission_indicator_diag_3 ,
  diagnosis_3rd_secondary_icd ,
  present_on_admission_indicator_diag_4 ,
  diagnosis_4th_secondary_icd ,
  present_on_admission_indicator_diag_5 ,
  diagnosis_5th_secondary_icd ,
  present_on_admission_indicator_diag_6 ,
  diagnosis_6th_secondary_icd ,
  present_on_admission_indicator_diag_7 ,
  diagnosis_7th_secondary_icd ,
  present_on_admission_indicator_diag_8 ,
  diagnosis_8th_secondary_icd ,
  present_on_admission_indicator_diag_9 ,
  diagnosis_9th_secondary_icd ,
  present_on_admission_indicator_diag_10 ,
  diagnosis_10th_secondary_icd ,
  present_on_admission_indicator_diag_11 ,
  diagnosis_11th_secondary_icd ,
  present_on_admission_indicator_diag_12 ,
  diagnosis_12th_secondary_icd ,
  present_on_admission_indicator_diag_13 ,
  diagnosis_13th_secondary_icd ,
  present_on_admission_indicator_diag_14 ,
  diagnosis_14th_secondary_icd ,
  present_on_admission_indicator_diag_15 ,
  diagnosis_15th_secondary_icd ,
  present_on_admission_indicator_diag_16 ,
  diagnosis_16th_secondary_icd ,
  present_on_admission_indicator_diag_17 ,
  diagnosis_17th_secondary_icd ,
  present_on_admission_indicator_diag_18 ,
  diagnosis_18th_secondary_icd ,
  present_on_admission_indicator_diag_19 ,
  diagnosis_19th_secondary_icd ,
  present_on_admission_indicator_diag_20 ,
  diagnosis_20th_secondary_icd ,
  present_on_admission_indicator_diag_21 ,
  diagnosis_21st_secondary_icd ,
  present_on_admission_indicator_diag_22 ,
  diagnosis_22nd_secondary_icd ,
  present_on_admission_indicator_diag_23 ,
  diagnosis_23rd_secondary_icd ,
  present_on_admission_indicator_diag_24 ,
  diagnosis_scheme_in_use_read ,
  diagnosis_primary_read ,
  diagnosis_1st_secondary_read ,
  diagnosis_2nd_secondary_read ,
  diagnosis_3rd_secondary_read ,
  diagnosis_4th_secondary_read ,
  diagnosis_5th_secondary_read ,
  diagnosis_6th_secondary_read ,
  diagnosis_7th_secondary_read ,
  diagnosis_8th_secondary_read ,
  diagnosis_9th_secondary_read ,
  diagnosis_10th_secondary_read ,
  diagnosis_11th_secondary_read ,
  diagnosis_12th_secondary_read ,
  diagnosis_13th_secondary_read ,
  diagnosis_14th_secondary_read ,
  diagnosis_15th_secondary_read ,
  diagnosis_16th_secondary_read ,
  diagnosis_17th_secondary_read ,
  diagnosis_18th_secondary_read ,
  diagnosis_19th_secondary_read ,
  diagnosis_20th_secondary_read ,
  diagnosis_21st_secondary_read ,
  diagnosis_22nd_secondary_read ,
  diagnosis_23rd_secondary_read ,
  attendance_identifier ,
  administrative_category ,
  attended_or_did_not_attend ,
  first_attendance ,
  medical_staff_type_seeing_patient ,
  operation_status_per_attendance ,
  outcome_of_attendance ,
  appointment_date ,
  appointment_time ,
  expected_duration_of_appointment ,
  consultation_medium_used ,
  waiting_time_measurement_type ,
  activity_location_type_code ,
  earliest_clinically_appropriate_date ,
  clinic_code ,
  commissioning_serial_number ,
  nhs_service_agreement_line_number ,
  provider_reference_number ,
  commissioner_reference_number ,
  organisation_code_code_of_provider ,
  organisation_code_type_code_of_provider ,
  organisation_code_code_of_commissioner ,
  organisation_code_type_code_of_commissioner ,
  procedure_scheme_in_use_opcs ,
  primary_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_1 ,
  professional_registration_issuer_code_opcs_1 ,
  responsible_anaesthetist_code_opcs_1 ,
  responsible_anaesthetist_reg_body_opcs_1 ,
  a2nd_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_2 ,
  professional_registration_issuer_code_opcs_2 ,
  responsible_anaesthetist_code_opcs_2 ,
  responsible_anaesthetist_reg_body_opcs_2 ,
  a3rd_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_3 ,
  professional_registration_issuer_code_opcs_3 ,
  responsible_anaesthetist_code_opcs_3 ,
  responsible_anaesthetist_reg_body_opcs_3 ,
  a4th_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_4 ,
  professional_registration_issuer_code_opcs_4 ,
  responsible_anaesthetist_code_opcs_4 ,
  responsible_anaesthetist_reg_body_opcs_4 ,
  a5th_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_5 ,
  professional_registration_issuer_code_opcs_5 ,
  responsible_anaesthetist_code_opcs_5 ,
  responsible_anaesthetist_reg_body_opcs_5 ,
  a6th_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_6 ,
  professional_registration_issuer_code_opcs_6 ,
  responsible_anaesthetist_code_opcs_6 ,
  responsible_anaesthetist_reg_body_opcs_6 ,
  a7th_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_7 ,
  professional_registration_issuer_code_opcs_7 ,
  responsible_anaesthetist_code_opcs_7 ,
  responsible_anaesthetist_reg_body_opcs_7 ,
  a8th_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_8 ,
  professional_registration_issuer_code_opcs_8 ,
  responsible_anaesthetist_code_opcs_8 ,
  responsible_anaesthetist_reg_body_opcs_8 ,
  a9th_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_9 ,
  professional_registration_issuer_code_opcs_9 ,
  responsible_anaesthetist_code_opcs_9 ,
  responsible_anaesthetist_reg_body_opcs_9 ,
  a10th_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_10 ,
  professional_registration_issuer_code_opcs_10 ,
  responsible_anaesthetist_code_opcs_10 ,
  responsible_anaesthetist_reg_body_opcs_10 ,
  a11th_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_11 ,
  professional_registration_issuer_code_opcs_11 ,
  responsible_anaesthetist_code_opcs_11 ,
  responsible_anaesthetist_reg_body_opcs_11 ,
  a12th_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_12 ,
  professional_registration_issuer_code_opcs_12 ,
  responsible_anaesthetist_code_opcs_12 ,
  responsible_anaesthetist_reg_body_opcs_12 ,
  a13th_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_13 ,
  professional_registration_issuer_code_opcs_13 ,
  responsible_anaesthetist_code_opcs_13 ,
  responsible_anaesthetist_reg_body_opcs_13 ,
  a14th_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_14 ,
  professional_registration_issuer_code_opcs_14 ,
  responsible_anaesthetist_code_opcs_14 ,
  responsible_anaesthetist_reg_body_opcs_14 ,
  a15th_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_15 ,
  professional_registration_issuer_code_opcs_15 ,
  responsible_anaesthetist_code_opcs_15 ,
  responsible_anaesthetist_reg_body_opcs_15 ,
  a16th_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_16 ,
  professional_registration_issuer_code_opcs_16 ,
  responsible_anaesthetist_code_opcs_16 ,
  responsible_anaesthetist_reg_body_opcs_16 ,
  a17th_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_17 ,
  professional_registration_issuer_code_opcs_17 ,
  responsible_anaesthetist_code_opcs_17 ,
  responsible_anaesthetist_reg_body_opcs_17 ,
  a18th_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_18 ,
  professional_registration_issuer_code_opcs_18 ,
  responsible_anaesthetist_code_opcs_18 ,
  responsible_anaesthetist_reg_body_opcs_18 ,
  a19th_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_19 ,
  professional_registration_issuer_code_opcs_19 ,
  responsible_anaesthetist_code_opcs_19 ,
  responsible_anaesthetist_reg_body_opcs_19 ,
  a20th_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_20 ,
  professional_registration_issuer_code_opcs_20 ,
  responsible_anaesthetist_code_opcs_20 ,
  responsible_anaesthetist_reg_body_opcs_20 ,
  a21st_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_21 ,
  professional_registration_issuer_code_opcs_21 ,
  responsible_anaesthetist_code_opcs_21 ,
  responsible_anaesthetist_reg_body_opcs_21 ,
  a22nd_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_22 ,
  professional_registration_issuer_code_opcs_22 ,
  responsible_anaesthetist_code_opcs_22 ,
  responsible_anaesthetist_reg_body_opcs_22 ,
  a23rd_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_23 ,
  professional_registration_issuer_code_opcs_23 ,
  responsible_anaesthetist_code_opcs_23 ,
  responsible_anaesthetist_reg_body_opcs_23 ,
  a24th_procedure_opcs ,
  main_operating_healthcare_professional_code_opcs_24 ,
  professional_registration_issuer_code_opcs_24 ,
  responsible_anaesthetist_code_opcs_24 ,
  responsible_anaesthetist_reg_body_opcs_24 ,
  procedure_scheme_in_use_read ,
  primary_procedure_read ,
  a2nd_procedure_read ,
  a3rd_procedure_read ,
  a4th_procedure_read ,
  a5th_procedure_read ,
  a6th_procedure_read ,
  a7th_procedure_read ,
  a8th_procedure_read ,
  a9th_procedure_read ,
  a10th_procedure_read ,
  a11th_procedure_read ,
  a12th_procedure_read ,
  a13th_procedure_read ,
  a14th_procedure_read ,
  a15th_procedure_read ,
  a16th_procedure_read ,
  a17th_procedure_read ,
  a18th_procedure_read ,
  a19th_procedure_read ,
  a20th_procedure_read ,
  a21st_procedure_read ,
  a22nd_procedure_read ,
  a23rd_procedure_read ,
  a24th_procedure_read ,
  location_class_at_attendance ,
  site_code_of_treatment ,
  organisation_code_type_site_code_of_treatment_at_attendance ,
  general_medical_practitioner_code_of_registered_gmp ,
  practice_code_of_registered_gp ,
  organisation_code_type_of_registered_gp ,
  priority_type ,
  service_type_requested ,
  source_of_referral_for_outpatients ,
  referral_request_received_date ,
  direct_access_referral_indicator ,
  referrer_code ,
  referring_organisation_code ,
  organisation_code_type_of_referrer ,
  last_dna_or_patient_cancelled_date ,
  hrg_code ,
  hrg_version_number ,
  procedure_scheme_in_use ,
  dominant_grouping_variable_procedure ,
  core_hrg ,
  hrg_version_calculated ,
  sus_hrg ,
  unique_booking_reference_number_converted ,
  patient_pathway_identifier ,
  organisation_code_patient_pathway_identifier_issuer ,
  referral_to_treatment_period_status ,
  referral_to_treatment_period_start_date ,
  referral_to_treatment_period_end_date ,
  lead_care_activity_indicator ,
  nhs_service_agreement_change_date ,
  cds_activity_date ,
  earliest_reasonable_offered_date ,
  location_type ,
  xml_version ,
  referral_to_treatment_length_derived ,
  age_range_patient_derived_from_dob ,
  area_code_derived_from_postcode ,
  attender_type_derived ,
  cds_group ,
  finished_indicator ,
  pct_derived_from_gp ,
  pct_type_derived_from_gp ,
  gp_practice_derived ,
  pct_derived_from_derived_gp_practice ,
  sha_from_gp_practice ,
  sha_type_from_gp_practice ,
  month_of_birth ,
  electoral_ward_from_postcode ,
  pct_from_postcode ,
  pct_type_from_postcode ,
  sha_from_postcode ,
  sha_type_from_postcode ,
  area_code_from_provider_postcode ,
  year_of_birth ,
  a2001_census_area ,
  country ,
  county_code ,
  a1991_census_ed ,
  ed_district_code ,
  electoral_ward_code ,
  gor_code ,
  local_unitary_authority ,
  old_sha_code ,
  a1998_electoral_area ,
  prime_recipient ,
  copy_recipients ,
  is_valid_ubrn ,
  ubrn_occurrence_count 
from ', sourcedb,'.tbl_op_susplus  src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "")
tb83 <- bq_project_query(project_id, sql83)

sql84 <-paste('update ', targetdb,'.tbl_outpatients_susplus
set tbl_outpatients_susplus_end_date = tbl_outpatients_susplus_start_date
where tbl_outpatients_susplus_end_date is null and tbl_outpatients_susplus_start_date is not null ; ', sep = "") 
tb84 <- bq_project_query(project_id, sql84)


print('tbl_outpatients_susplus done') 


sql85 <-paste('drop TABLE IF EXISTS ', targetdb,'.cb_patient; ', sep = "") 
tb85 <- bq_project_query(project_id, sql85)

sql86 <-paste('CREATE  TABLE ', targetdb,'.cb_patient
as 
select 
dem.person_id,
  src.digest ,
  date_of_birth ,
  postcode ,
  marital_status ,
  sex_local ,
  sex ,
  title ,
  religion ,
  dentist_local ,
  dentist ,
  ethnic_origin ,
  gp ,
  practice_local ,
  practice ,
  date_of_death ,
  patient_deceased ,
  remarks ,
  trace_status ,
  overseas_visitor ,
  residence_ccg ,
  fk_patient ,
  ethnic_origin_local ,
  gp_name 
from ', sourcedb,'.tbl_patient  src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "") 
tb86 <- bq_project_query(project_id, sql86)


print(' tbl_patient done')

sql87 <-paste('drop TABLE IF EXISTS ', targetdb,'.tbl_pharmacy; ', sep = "") 
tb87 <- bq_project_query(project_id, sql87)

sql88 <-paste('CREATE  TABLE ', targetdb,'.tbl_pharmacy
as 
select 
dem.person_id,
cast(left(issue_date_dt,19) as datetime)   as tbl_pharmacy_start_date,
cast(left(issue_date_dt,19) as datetime)  as tbl_pharmacy_end_date,
  unique_pharmacy_number ,
  src.digest ,
  prescription_number ,
  consultant_local ,
  consultant_name ,
  consultant ,
  issue_source ,
  issue_source_description ,
  issue_type ,
  issue_type_description ,
  issue_date_dt ,
  issue_location ,
  issue_location_description ,
  cost_centre ,
  cost_centre_description ,
  specialty ,
  specialty_description ,
  drug ,
  drug_description ,
  drug_dose_unit ,
  drug_dose_unit_description ,
  drug_strength ,
  drug_form ,
  drug_form_description ,
  drug_quantity ,
  drug_instructions ,
  patient_type_description ,
  latest_price_paid ,
  prescription_value 
from  ', sourcedb,'.tbl_pharmacy  src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "") 
tb88 <- bq_project_query(project_id, sql88)

sql89 <-paste('update ', targetdb,'.tbl_pharmacy
set tbl_pharmacy_end_date = tbl_pharmacy_start_date
where tbl_pharmacy_end_date is null and tbl_pharmacy_start_date is not null ; ', sep = "") 
tb89 <- bq_project_query(project_id, sql89)


print(' tbl_pharmacy done') 


sql90 <-paste('drop TABLE IF EXISTS ', targetdb,'.tbl_radiology; ', sep = "") 
tb93 <- bq_project_query(project_id, sql90)

sql91 <-paste('CREATE  TABLE ', targetdb,'.tbl_radiology
as 
select 
dem.person_id,
cast(left(exam_date,19) as datetime) as tbl_radiology_start_date,
cast(left(exam_date,19) as datetime) as tbl_radiology_end_date,
  identifier ,
  accession_number ,
  attendance_number ,
  request_date ,
  exam_date ,
  src.digest ,
  postcode ,
  exam_code ,
  exam_description ,
  treatment_function ,
  treatment_function_description ,
  modality ,
  patient_type ,
  patient_type_description ,
  reported_date ,
  reported_time ,
  reported_date_dt ,
  inpatient_episode_serial ,
  outpatient_appointment_serial ,
  ae_attendance_number ,
  attendance_status ,
  status_description ,
  urgency ,
  referrer_code ,
  referrer_specialty ,
  patient_age ,
  refering_location STRING
from ', sourcedb,'.tbl_radiology  src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "")
tb91 <- bq_project_query(project_id, sql91)

sql92 <-paste('update ', targetdb,'.tbl_radiology
set tbl_radiology_end_date = tbl_radiology_start_date
where tbl_radiology_end_date is null and tbl_radiology_start_date is not null ; ', sep = "") 
tb92 <- bq_project_query(project_id, sql92)


print(' tbl_radiology done') 


sql93 <-paste('drop TABLE IF EXISTS ', targetdb,'.tbl_spell; ', sep = "") 
tb93 <- bq_project_query(project_id, sql93)

sql94 <-paste('CREATE  TABLE ', targetdb,'.tbl_spell
as 
select 
dem.person_id,
cast(left(admission_date_time,19) as datetime ) as tbl_spell_start_date,
cast(left(discharge_date_time,19) as datetime ) as tbl_spell_end_date,
  spell_number ,
  src.digest ,
  postcode ,
  gender ,
  birth_year ,
  birth_month ,
  death_year ,
  death_month ,
  patient_age ,
  decision_to_admit_date_time ,
  admission_date_time ,
  admission_date ,
  admission_time ,
  practice ,
  practice_desc ,
  practice_address ,
  clinician ,
  admission_clinician_fullname ,
  admission_source ,
  admission_source_local_desc ,
  admission_method ,
  admission_method_local_desc ,
  intended_management_local ,
  intended_management ,
  intended_management_local_desc ,
  patient_classification_local ,
  patient_classification ,
  patient_classification_local_desc ,
  administrative_category_local ,
  administrative_category ,
  administrative_category_local_desc ,
  site_local ,
  site ,
  site_local_desc ,
  provider ,
  pathway_id ,
  booking_reference_number ,
  rtt_period_status ,
  discharge_date_time ,
  discharge_date ,
  discharge_time ,
  discharge_destination_local ,
  discharge_destination ,
  discharge_destination_local_desc ,
  discharge_method_local ,
  discharge_method ,
  discharge_method_local_desc ,
  commissioning_serial_number ,
  hrg_code_spell ,
  hrg_code_spell_desc ,
  length_of_provider_spell 
from ', sourcedb,'.tbl_spell  src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "") 
tb94 <- bq_project_query(project_id, sql94)

sql95 <-paste('update ', targetdb,'.tbl_spell
set tbl_spell_end_date = tbl_spell_start_date
where tbl_spell_end_date is null and tbl_spell_start_date is not null ; ', sep = "") 
tb95 <- bq_project_query(project_id, sql95)


print('tbl_spell done') 

sql96 <-paste('drop TABLE IF EXISTS ', targetdb,'.tbl_theatre; ', sep = "") 
tb96 <- bq_project_query(project_id, sql96)

sql97 <-paste('CREATE  TABLE ', targetdb,'.tbl_theatre
as 
select 
dem.person_id,
cast(left(anaesthetic_start_date,11)|| anaesthetic_start_time as datetime) as tbl_theatre_start_date,
cast(left(operation_end_date,11)|| operation_end_time as datetime) as  tbl_theatre_end_date,
  src.digest ,
  postcode ,
  patient_age ,
  operation_number ,
  session_number ,
  session_number_unique ,
  surgery_date_time ,
  practice ,
  provider ,
  site ,
  episode_serial ,
  spell_number ,
  src.ward ,
  ward_name ,
  urgency ,
  urgency_description ,
  admitting_consultant ,
  admitting_consultant_name ,
  session_consultant ,
  session_consultant_name ,
  session_specialty ,
  session_specialty_description ,
  sent_for_time ,
  porter_time ,
  in_date ,
  in_time ,
  anaesthetic_start_date ,
  anaesthetic_start_time ,
  induced_time ,
  into_theatre_time ,
  incision_time ,
  closure_time ,
  operation_end_date ,
  operation_end_time ,
  operation_start_date ,
  operation_start_time ,
  recovery_date ,
  recovery_time ,
  anaesthetic_handover_time ,
  out_of_recovery_time ,
  theatre ,
  actual_duration ,
  emergency_booked_time ,
  emergency_requested_time ,
  session_date ,
  session_start_time_planned ,
  session_start_time_actual ,
  session_end_time_planned ,
  session_end_time_actual ,
  planned_procedure_1 ,
  planned_procedure_2 ,
  planned_procedure_3 ,
  planned_procedure_4 ,
  planned_procedure_5 ,
  planned_procedure_6 ,
  planned_procedure_7 ,
  planned_procedure_8 ,
  planned_procedure_9 ,
  planned_procedure_10 ,
  planned_procedure_11 ,
  planned_procedure_12 ,
  actual_procedure_1 ,
  actual_procedure_2 ,
  actual_procedure_3 ,
  actual_procedure_4 ,
  actual_procedure_5 ,
  actual_procedure_6 ,
  actual_procedure_7 ,
  actual_procedure_8 ,
  actual_procedure_9 ,
  actual_procedure_10 ,
  actual_procedure_11 ,
  actual_procedure_12 ,
  planned_anatomical_site_1 ,
  planned_anatomical_site_2 ,
  planned_anatomical_site_3 ,
  planned_anatomical_site_4 ,
  planned_anatomical_site_5 ,
  planned_anatomical_site_6 ,
  planned_anatomical_site_7 ,
  planned_anatomical_site_8 ,
  planned_anatomical_site_9 ,
  planned_anatomical_site_10 ,
  planned_anatomical_site_11 ,
  planned_anatomical_site_12 ,
  actual_anatomical_site_1 ,
  actual_anatomical_site_2 ,
  actual_anatomical_site_3 ,
  actual_anatomical_site_4 ,
  actual_anatomical_site_5 ,
  actual_anatomical_site_6 ,
  actual_anatomical_site_7 ,
  actual_anatomical_site_8 ,
  actual_anatomical_site_9 ,
  actual_anatomical_site_10 ,
  actual_anatomical_site_11 ,
  actual_anatomical_site_12 ,
  planned_anatomical_side_1 ,
  planned_anatomical_side_2 ,
  planned_anatomical_side_3 ,
  planned_anatomical_side_4 ,
  planned_anatomical_side_5 ,
  planned_anatomical_side_6 ,
  planned_anatomical_side_7 ,
  planned_anatomical_side_8 ,
  planned_anatomical_side_9 ,
  planned_anatomical_side_10 ,
  planned_anatomical_side_11 ,
  planned_anatomical_side_12 ,
  actual_anatomical_side_1 ,
  actual_anatomical_side_2 ,
  actual_anatomical_side_3 ,
  actual_anatomical_side_4 ,
  actual_anatomical_side_5 ,
  actual_anatomical_side_6 ,
  actual_anatomical_side_7 ,
  actual_anatomical_side_8 ,
  actual_anatomical_side_9 ,
  actual_anatomical_side_10 ,
  actual_anatomical_side_11 ,
  actual_anatomical_side_12 ,
  patient_cancel_reason_1 ,
  patient_cancel_reason_2 ,
  patient_cancel_reason_3 ,
  session_cancel_reason_1 ,
  session_cancel_reason_2 ,
  session_cancel_reason_3 ,
  surgeon_1 ,
  surgeon_2 ,
  surgeon_3 ,
  surgeon_4 ,
  anaesthetist_1 ,
  anaesthetist_2 ,
  anaesthetist_3 ,
  asa ,
  destination ,
  incident ,
  patient_delay_10 ,
  patient_delay_20 ,
  patient_delay_30 ,
  general_anaesthestic ,
  local_anaesthestic ,
  circulating_person_1 ,
  circulating_person_2 ,
  circulating_person_3 ,
  circulating_person_4 ,
  circulating_person_5 ,
  anaesthetic_assistant_1 ,
  anaesthetic_assistant_2 ,
  anaesthetic_assistant_3 ,
  anaesthetic_assistant_4 ,
  recovery_nurse_1 ,
  recovery_nurse_2 ,
  recovery_nurse_3 ,
  recovery_nurse_4 ,
  scrub_nurse_1 ,
  scrub_nurse_2 ,
  scrub_nurse_3 ,
  transit_nurse_1 ,
  transit_nurse_2 ,
  nurse_as_first_assistant ,
  opthalmic_nurse_practitioner ,
  surgical_care_practitioner ,
  other_anaesthetic_procedures ,
  session_theatre ,
  session_start_early_reason ,
  ses_start_late_reason ,
  session_finish_early_reason ,
  ses_finish_late_reason 
from ', sourcedb,'.tbl_theatre src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "") 
tb97 <- bq_project_query(project_id, sql97)

sql98 <-paste('update ', targetdb,'.tbl_theatre
set tbl_theatre_end_date = tbl_theatre_start_date
where tbl_theatre_end_date is null and tbl_theatre_start_date is not null ; ', sep = "") 
tb98 <- bq_project_query(project_id, sql98)



print('tbl_theatre done') 


sql99 <-paste('drop TABLE IF EXISTS  ', targetdb,'.lookup_ward; ', sep = "") 
tb99 <- bq_project_query(project_id, sql99)

sql100 <-paste('CREATE  TABLE ', targetdb,'.lookup_ward
as 
select 
  ward_code ,
  ward_name ,
  hospital_name 
from ', sourcedb,'.tbl_ward_lkp; ', sep = "") 
tb100 <- bq_project_query(project_id, sql100)

sql101 <-paste('drop TABLE IF EXISTS ', targetdb,'.tbl_ward_stay; ', sep = "") 
tb101 <- bq_project_query(project_id, sql101)

sql102 <-paste('CREATE  TABLE ', targetdb,'.tbl_ward_stay
as 
select 
dem.person_id,
cast(left(stay_start_date_time,19) as datetime) as  tbl_ward_stay_start_date,
cast(left(stay_end_date_time,19) as datetime) as  tbl_ward_stay_end_date,
  stay_number ,
  spell_number ,
  stay_sequence ,
  src.digest ,
  gender ,
  birth_year ,
  birth_month ,
  death_year ,
  death_month ,
  practice ,
  stay_start_date_time ,
  stay_start_date ,
  stay_start_time ,
  src.ward ,
  provider ,current_stay ,
  last_stay_in_spell ,
  length_of_stay ,
  nights_on_ward ,
  stay_end_date_time ,
  stay_end_date ,
  stay_end_time ,
  pathway_id ,
  booking_reference_number ,
  rtt_period_status 
from  ', sourcedb,'.tbl_ward_stay src
 left join  ', demodb,' dem
on src.digest = dem.digest; ', sep = "") 
tb102 <- bq_project_query(project_id, sql102)

sql103 <-paste('update ', targetdb,'.tbl_ward_stay
set tbl_ward_stay_end_date = tbl_ward_stay_start_date
where tbl_ward_stay_end_date is null and tbl_ward_stay_start_date is not null ; ', sep = "") 
tb103 <- bq_project_query(project_id, sql103)



print('tbl_ward_stay done')
# Out:
# [1] " tbl_episode done"
# [1] "cb_episode_diagnosis done"
# [1] "cb_episode_procedure done"
# [1] "tbl_maternity-birth done"
# [1] "tbl_maternity_care_plan done"
# [1] "tbl_maternity_delivery done"
# [1] "tbl_maternity_pathway_antenatal done"
# [1] "tbl_maternity_pathway_postnatal done"
# [1] "tbl_maternity_pregnancy_and_booking_details done"
# [1] "cb_mother_child_relationship done "
# [1] "tbl_outpatient done"
# [1] "tbl_outpatients_susplus done"
# [1] " tbl_patient done"
# [1] " tbl_pharmacy done"
# [1] " tbl_radiology done"
# [1] "tbl_spell done"
# [1] "tbl_theatre done"
# [1] "tbl_ward_stay done"

# %%
sql104 <-paste('drop table if exists ', targetdb,'.cb_PMH_MaternityDataset; ', sep = "") 
tb104 <- bq_project_query(project_id, sql104)


sql105 <-paste('CREATE  TABLE ', targetdb,'.cb_PMH_MaternityDataset
as select
digest,
postnatal_year,
pmh_Indication,
imd_Quintile,
 FROM ', sourcedb,'.tbl_PMH_MaternityDataset src; ', sep = "") 
 tb105 <- bq_project_query(project_id, sql105)

print('cb_PMH_MaternityDataset done ')


sql106 <-paste('drop table if exists ', targetdb,'.cb_ward_lkp ; ', sep = "") 
tb106 <- bq_project_query(project_id, sql106)


sql107 <-paste('CREATE  TABLE ', targetdb,'.cb_ward_lkp 
as select
ward_code, 
ward_name,
hospital_name, 
FROM ', sourcedb,'.tbl_ward_lkp src; ', sep = "") 
 tb107 <- bq_project_query(project_id, sql107)

print (' cb_lookup_ward done ')
# Out:
# [1] "cb_PMH_MaternityDataset done "
# [1] " cb_lookup_ward done "
