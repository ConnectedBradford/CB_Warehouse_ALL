# %%
from google.cloud import bigquery
from google.cloud.bigquery import LoadJobConfig
from google.cloud.bigquery import SchemaField

client = bigquery.Client()
dataset_ref = client.dataset('CB_MYSPACE_JDB')
# Out:
# /opt/conda/lib/python3.7/site-packages/google/auth/_default.py:78: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /opt/conda/lib/python3.7/site-packages/google/auth/_default.py:78: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
## create table tbl_ae_investigation_nautilus
schema = [
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('order_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('encntr_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('person_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('investigation_cd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('investigation_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('investigation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('investigation_type_cd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('investigation_type_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('orig_order_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('order_status_cd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('order_status_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('order_mnemonic', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('synonym_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('current_start_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('projected_stop_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hna_order_mnemonic', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('valid_dose_dt_tm', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_ae_investigation_nautilus')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for tbl_ae_investigation_nautilus

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_ae_investigation_nautilus.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

 

#create table tbl_ae_nautilus
schema = [
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('encntr_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('person_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_year', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_month', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('death_year', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('death_month', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('fin_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('source_of_referral_cd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('source_of_referral_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('source_of_referral', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referring_organisation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attendance_category_cd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attendance_category_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attendance_category', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accomodation_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('overseas_visitor_status_cd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('overseas_visitor_status_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('overseas_visitor_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('arrival_mode_cd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('arrival_mode_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('arrival_mode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('incident_type_cd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('incident_type_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('incident_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dept_type_cd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dept_type_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dept_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_cd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reg_stream', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('department_or_ward_cd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('presentation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('incident_location_cd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('incident_location_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('incident_location', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ambulance_geo_cd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ambulance_call_sign_cd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ambulance_call_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('road_traffic_acc_addr_txt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('road_traffic_acc_police_ident', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('active_status_cd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('encntr_status_cd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_method', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_method_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('outcome', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('last_location_cd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('last_location_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('last_location', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('org_alias', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccg_name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccg_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ec_discharge_follow_up', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_method_snmd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('outcome_snmd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('acuity_level', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_information_given', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_function_cd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_function_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_fucntion', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('injury_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('injury_lattitude', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('injury_longitude', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('injury_intent', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('injury_activity_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('injury_activity_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('injury_mechanism', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('alcohol_drug_involvement', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('tracking_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('tracking_locator_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('max_tracking_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('max_tracking_locator_id', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_ae_nautilus')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for tbl_ae_nautilus 
#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="^"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_ae_nautilus.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_ae_timings_nautilus
schema = [
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('encntr_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('arrival_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('triage_start_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('triage_end_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assessment_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('clinician_assign_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('clinician_seen_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referred_to_service_referral_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referred_to_service_seen_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('decision_to_admit_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ready_to_transfer_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('clinically_ready_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('expected_treatment_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_allocation_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_seen_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('checkout_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('conclusion_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('departure_dt_tm', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_ae_timings_nautilus')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for tbl_ae_timings_nautilus 
#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_ae_timings_nautilus.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_ae_treatment_nautilus
schema = [
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('encntr_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('person_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('clinical_event_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('event_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('parent_event_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('event_title_text', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('event_tag', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_cd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_sequence_nbr', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('performed_prsnl_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('performed_by_person', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('performed_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('valid_from_dt_tm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('valid_until_dt_tm', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_ae_treatment_nautilus')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for   tbl_ae_treatment_nautilus

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_ae_treatment_nautilus.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_ae
schema = [
bigquery.SchemaField('identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nhs_number_status_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_of_provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gender', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_year', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_month', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('death_year', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('death_month', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_at_attendance_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_in_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('language_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('language_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_group_ae', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_group_ae_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('arrival_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('departure_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('visit_duration', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('arrival_mode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('arrival_mode_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('initial_assessment_triage_category', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('department_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attendance_disposal', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attendance_disposal_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('source_of_referral', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('source_of_referral_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('purchaser', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('activity_treatment_function_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('investigation_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('investigation_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('investigation_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('investigation_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('investigation_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('investigation_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('investigation_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('investigation_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('investigation_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('investigation_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('investigation_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('investigation_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_12', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_ae')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for   tbl_ae

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_ae.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_apc_finished_susplus
schema = [
bigquery.SchemaField('identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('generated_record_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pbr_spell_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reason_for_access', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cds_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('protocol_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('update_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bulk_replacement_cds_group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('test_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('applicable_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('census_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('extract_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('report_period_start_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('report_period_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_sender_of_transaction', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_of_sender', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('submission_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cds_interchange_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_local_patient_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_local_patient_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_year', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_month', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_weight', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('live_or_still_birth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('carer_support_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('legal_status_classification_on_admission_psychiatric_census_only', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('marital_status_psychiatric_census_only', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest_number_trace_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('withheld_identity_reason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sex', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pregnancy_total_previous_pregnancies', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_residence_responsibility', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pct_of_residence', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_pct_of_residence', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('osv_classification_at_cds_activity_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('overseas_visitor_status_classification_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('overseas_visitor_status_start_date_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('overseas_visitor_status_end_date_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('overseas_visitor_status_classification_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('overseas_visitor_status_start_date_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('overseas_visitor_status_end_date_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('overseas_visitor_status_classification_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('overseas_visitor_status_start_date_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('overseas_visitor_status_end_date_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('overseas_visitor_status_classification_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('overseas_visitor_status_start_date_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('overseas_visitor_status_end_date_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('overseas_visitor_status_classification_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('overseas_visitor_status_start_date_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('overseas_visitor_status_end_date_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hospital_provider_spell_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('administrative_category', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_classification', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admission_method_hospital_provider_spell', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_destination_hospital_provider_spell', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_method_hospital_provider_spell', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('source_of_admission_hospital_provider_spell', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_hospital_provider_spell', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_hospital_provider_spell', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_date_from_hospital_provider_spell', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_time_hospital_provider_spell', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_to_hospital_at_home_service_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('first_regular_day_night_admission', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('last_episode_in_spell_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('neonatal_level_of_care', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('operation_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('psychiatric_patient_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_consultant_episode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_episode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_consultant_episode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_episode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('length_of_stay_adjustment_rehabilitation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('length_of_stay_adjustment_specialist_palliative_care', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('commissioning_serial_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nhs_service_agreement_line_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('provider_reference_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('commissioner_reference_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_code_of_provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_of_provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_code_of_commissioner', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_of_commissioner', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('consultant_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_specialty_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_function_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('local_sub_specialty_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('multiprofessional_or_multidisciplinary_ind_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rehabilitation_assessment_team_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_scheme_in_use_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_primary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_1st_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_2nd_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_3rd_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_4th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_5th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_6th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_7th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_8th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_9th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_10th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_11th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_12th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_13th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_14th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_15th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_16th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_17th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_18th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_19th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_20th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_21st_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_22nd_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_23rd_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_scheme_in_use_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_primary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_1st_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_2nd_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_3rd_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_4th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_5th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_6th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_7th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_8th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_9th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_10th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_11th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_12th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_13th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_14th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_15th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_16th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_17th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_18th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_19th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_20th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_21st_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_22nd_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_23rd_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_scheme_in_use_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('primary_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('primary_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a2nd_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a2nd_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a3rd_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a3rd_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a4th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a4th_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a5th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a5th_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a6th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a6th_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a7th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a7th_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a8th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a8th_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a9th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a9th_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a10th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a10th_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a11th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a11th_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a12th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a12th_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a13th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a13th_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a14th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a14th_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a15th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a15th_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a16th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a16th_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a17th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a17th_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a18th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a18th_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a19th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a19th_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a20th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a20th_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a21st_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a21st_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a22nd_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a22nd_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a23rd_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a23rd_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a24th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a24th_procedure_date_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_scheme_in_use_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('primary_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('primary_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a2nd_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a2nd_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a3rd_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a3rd_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a4th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a4th_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a5th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a5th_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a6th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a6th_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a7th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a7th_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a8th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a8th_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a9th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a9th_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a10th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a10th_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a11th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a11th_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a12th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a12th_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a13th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a13th_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a14th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a14th_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a15th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a15th_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a16th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a16th_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a17th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a17th_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a18th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a18th_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a19th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a19th_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a20th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a20th_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a21st_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a21st_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a22nd_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a22nd_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a23rd_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a23rd_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a24th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a24th_procedure_date_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_at_episode_start_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_at_episode_start_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_at_episode_start_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_at_episode_start_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_at_start_of_episode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensityat_start_of_episode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time_ward_stay_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_time_ward_stay_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_code_at_episode_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_security_level_at_episode_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_at_episode_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment_at_episode_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_at_episode_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_clinical_care_intensity_at_episode_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_group_intended_at_episode_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_day_period_availability_at_episode_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_night_period_availability_at_episode_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('general_medical_practitioner_code_of_registered_gmp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('practice_code_of_registered_gp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_of_registered_gp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referrer_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referring_organisation_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_of_referrer', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('direct_access_referral_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ambulance_incident_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_conveying_ambulance_trust', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('duration_of_elective_wait', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_management', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('decided_to_admit_date_for_this_provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('waiting_time_measurement_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_type_code_at_start_of_episode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_version_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_scheme_in_use', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dominant_grouping_variable_procedure', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('fce_hrg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_hrg_version_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('spell_core_hrg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('spell_hrg_version_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('number_of_babies', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('first_antenatal_assessment_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gmp_code_of_gmp_responsible_for_antenatal_care', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('code_of_gp_practice_registered_gmp_antenatal_care', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_gp_practice_registered_gmp_antenatal_care', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_of_delivery_place_intended', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_type_of_delivery_place_intended', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_place_change_reason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_place_type_intended', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anaesthetic_given_during_labour_delivery', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anaesthetic_given_post_delivery', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation_length_labour_onset', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('labour_delivery_onset_method', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_order_baby_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_method_baby_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation_length_assessment_baby_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('resuscitation_method_baby_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_of_person_conducting_delivery_baby_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_local_patient_id_baby_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest_number_status_indicator_baby_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_weight_baby_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('live_or_still_birth_baby_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sex_baby_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_location_type_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_delivery_place_actual_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_place_type_actual_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_order_baby_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_method_baby_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation_length_assessment_baby_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('resuscitation_method_baby_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_of_person_conducting_delivery_baby_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_local_patient_id_baby_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_local_patient_id_baby_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest_number_status_indicator_baby_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_weight_baby_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('live_or_still_birth_baby_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sex_baby_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_location_type_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_delivery_place_actual_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_place_type_actual_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_order_baby_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_method_baby_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation_length_assessment_baby_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('resuscitation_method_baby_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_of_person_conducting_delivery_baby_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_local_patient_id_baby_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_local_patient_id_baby_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest_number_status_indicator_baby_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_weight_baby_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('live_or_still_birth_baby_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_location_type_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_delivery_place_actual_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_place_type_actual_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_order_baby_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_method_baby_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation_length_assessment_baby_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('resuscitation_method_baby_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_of_person_conducting_delivery_baby_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_local_patient_id_baby_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_local_patient_id_baby_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest_number_status_indicator_baby_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_weight_baby_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('live_or_still_birth_baby_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_location_type_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_delivery_place_actual_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_place_type_actual_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_order_baby_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_method_baby_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation_length_assessment_baby_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('resuscitation_method_baby_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_of_person_conducting_delivery_baby_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_local_patient_id_baby_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_local_patient_id_baby_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest_number_status_indicator_baby_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_weight_baby_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('live_or_still_birth_baby_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_location_type_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_delivery_place_actual_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_place_type_actual_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_order_baby_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_method_baby_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation_length_assessment_baby_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('resuscitation_method_baby_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_of_person_conducting_delivery_baby_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_local_patient_id_baby_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_local_patient_id_baby_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest_number_status_indicator_baby_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_weight_baby_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('live_or_still_birth_baby_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_location_type_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_delivery_place_actual_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_place_type_actual_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_order_baby_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_method_baby_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation_length_assessment_baby_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('resuscitation_method_baby_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_of_person_conducting_delivery_baby_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_local_patient_id_baby_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_local_patient_id_baby_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest_number_status_indicator_baby_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_weight_baby_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('live_or_still_birth_baby_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_location_type_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_delivery_place_actual_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_place_type_actual_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_order_baby_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_method_baby_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation_length_assessment_baby_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('resuscitation_method_baby_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_of_person_conducting_delivery_baby_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_local_patient_id_baby_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_local_patient_id_baby_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest_number_status_indicator_baby_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_weight_baby_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('live_or_still_birth_baby_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_location_type_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_delivery_place_actual_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_place_type_actual_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_order_baby_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_method_baby_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation_length_assessment_baby_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('resuscitation_method_baby_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_of_person_conducting_delivery_baby_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_local_patient_id_baby_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_local_patient_id_baby_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest_number_status_indicator_baby_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_weight_baby_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('live_or_still_birth_baby_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_location_type_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_delivery_place_actual_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_place_type_actual_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation_length_assessment_baby', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_local_patient_identifier_mother', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_mother', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest_number_status_indicator_mother', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postcode_of_mother', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_pct_of_residence_mother', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_pct_of_residence_mother', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('unique_booking_reference_number_converted', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_pathway_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_patient_pathway_identifier_issuer', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referral_to_treatment_period_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referral_to_treatment_period_start_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referral_to_treatment_period_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lead_care_activity_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nhs_service_agreement_change_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cds_activity_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admin_category_at_start', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hospital_provider_spell_discharge_ready_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('xml_version', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referral_to_treatment_length_derived', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_range_patient_derived_from_dob', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_range_mother_derived_from_dob', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('area_code_derived_from_postcode_', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cds_group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('finished_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pct_derived_from_gp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pct_type_derived_from_gp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gp_practice_derived', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gp_practice_mother_derived', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pct_derived_from_derived_gp_practice', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pct_mother_derived_from_derived_gp_practice', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sha_from_gp_practice', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sha_type_from_gp_practice', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hospital_spell_duration', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('month_of_birth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('home_birth_or_delivery', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('electoral_ward_from_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pct_from_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pct_type_from_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sha_from_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sha_type_from_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('area_code_from_provider_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('year_of_birth_mother', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('month_of_birth_mother', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a2001_census_area', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('country', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('county_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a1991_census_ed', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ed_district_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('electoral_ward_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gor_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('local_unitary_authority', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('old_sha_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a1998_electoral_area', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('prime_recipient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('copy_recipients', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('critical_care_local_identifier_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('critical_care_start_date_1', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_apc_finished_susplus')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for   tbl_apc_finished_susplus

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_apc_finished_susplus.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_autism_amalgamated_ptl_oct2022
schema = [
bigquery.SchemaField('date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('trust', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('department', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gender_assigned_at_birth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('year_of_birth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('month_of_birth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_will_update_automatically', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ethnicity', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pathway_allocated', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('asd_adhd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lac', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ehcp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('started_assessment', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('started_october_2022', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('first_contact_autism_assessment_dd_mm_yyyy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('school_info_dd_mm_yyyy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('school_obs_dd_mm_yyyy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ados_dd_mm_yyyy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('salt_dd_mm_yyyy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('qb_dd_mm_yyyy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cognitive_assessment', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mdt_dd_mm_yyyy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('feedback_given_dd_mm_yyyy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('jac_report_circulated_dd_mm_yyyy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referral_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referral_source', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('breach_date_13_weeks_to_first_contact', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('weeks_waiting_until_case_closed_will_update_automatically', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_closed_dd_mm_yyyy_when_closed_from_neuro', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('outsourced_yn', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_autism_amalgamated_ptl_oct2022')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for  tbl_autism_amalgamated_ptl_oct2022 

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_autism_amalgamated_ptl_oct2022.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_critical_care_adult
schema = [
bigquery.SchemaField('critical_care_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_on_admission', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('person_stated_gender_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('critical_care_start_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('critical_care_end_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('critical_care_length_of_stay', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('critical_care_length_of_stay_in_minutes', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cc_admission_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cc_unit_function', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_function', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('fce_hrg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('advanced_respiratory_support_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('basic_respiratory_support_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('advanced_cardiovascular_support_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('basic_cardiovascular_support_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('renal_support_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('neurological_system_support_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dermatological_system_support_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gastro_intestinal_system_support_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('liver_system_support_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organ_support_maximum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('critical_care_level_2_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('critical_care_level_3_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('critical_care_subset', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_critical_care_adult')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for  tbl_critical_care_adult 

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_critical_care_adult.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))


#create table tbl_critical_care_ICNARC_observation
schema = [
    bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_central_temp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_central_temp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_noncentral_temp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_noncentral_temp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_systolic_bp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('p_diastolic_bp_for_lsysbp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_systolic_bp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('p_diastolic_bp_for_hsysbp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_diastolic_bp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('p_systolic_bp_for_ldiabp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_diastolic_bp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('p_systolic_bp_for_hdiabp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_heart_rate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_heart_rate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_nonvent_resprate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_nonvent_resprate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_vent_resprate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_vent_resprate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pao2_artbg_lpao2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_fio2_artbg_lpao2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_paco2_artbg_lpao2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_ph_hplus_artbg_lpao2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_intustat_artbg_lpao2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('fio2_intubartbg_hfio2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_pao2_intuartbg_hfio2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_paco2_intuartbg_hfio2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_ph_hplus_intuartbg_hfio2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ph_hplus_artbg_lph_hplus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_paco2_artbg_lph_hplus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ph_hplus_artbg_hph_hplus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_paco2_artbg_hph_hplus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cpap_during_fst24hrs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_serum_bicarbonate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_serum_bicarbonate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_serum_sodium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_serum_sodium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_serum_potassium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_serum_potassium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_serum_urea', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_serum_creatinine', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_serum_creatinine', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('urine_output', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_serum_glucose', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_serum_glucose', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_serum_bilirubin', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('transaminase_ast', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_serum_calcium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_serum_calcium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_ionserum_calcium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_ionserum_calcium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_serum_albumin', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_serum_albumin', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_haematocrit', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_haematocrit', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_haemoglobin', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_haemoglobin', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_white_blood_cellcount', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_white_blood_cellcount', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_platelet_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_prothrombin_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_partial_thromboplastin_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('morphology', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pupillary_reactions', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sedatorparalysedandsedat_fst24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('presedation_gcs_docum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('presedation_total_gcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('expected_neurological_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('l_total_gcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_eye_ltotalgcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_motor_ltotalgcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_verbal_ltotalgcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_intubstatus_ltotalgcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mean_arterial_bp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_daily', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('day_study_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('transaminase_alt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('day_in_unit', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('physio_completed', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('blood_taken', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bed_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('carelevel_acp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('advance_resp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('basic_resp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('circulatory', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('neurological', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('renal', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('acptotalorgsupp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nurseshift', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('day_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ain_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sco_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('plan', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_round_summary', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sepsis_screened', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sepsis_positiveresult', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('advcardio', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('basiccardio', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('derma', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('liver', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gastrointest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccmdstotalorgsupp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ephys', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('p_serum_bicarbonate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('m_serum_bicarbonate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pre_serum_yes', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('p_serum_sodium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('m_serum_sodium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pre_sodium_yes', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('p_serum_potasium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('m_serum_potasium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pre_potasium_yes', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bicarbonate_data', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sodium_data', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('potasium_data', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('m_blood_gases', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_blood_lactate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('p_blood_lactate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('m_blood_lactate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pre_blood_lactate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('p_urea', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('m_urea', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pre_urea', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('h_urea', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pre_serum_creat', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('m_creat', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('p_creat', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('m_urine', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pre_haemoglobin', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('m_haemoglobin', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('p_haemoglobin', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pre_platelet', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('p_platelet', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('m_platelet', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pre_bloodcount', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('p_bloodcount', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('m_bloodcount', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mrsa', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cdiff', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('amuai', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nuaib', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mouaib', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('carelevel_ccmds', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ephys_4_superquery', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('missing_gcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('m_glucose', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('p_serum_glucose', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pre_serum_glucose', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anclwbc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anchwbc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ancpwbc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pupilreactivity_m', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pupilreactivity_l', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pupilreactivity_r', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('haemoglobin_unit', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('icucons', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('icucons_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('icucons_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('icucons_delay', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('icucons_delaytime', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rehabassessedfirst24h', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('m_haematocrit', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lastchdby_userid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lastchdby_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lastchdby_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lastchgdby_usertmpstr', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_critical_care_ICNARC_observation')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for   tbl_critical_care_ICNARC_observation

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_critical_care_ICNARC_observation.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_critical_care_neonatal_daily
schema = [
bigquery.SchemaField('acp_refno', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cc_daily_uid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('critical_care_activity_date_dt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('critical_care_person_weight', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_01', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_02', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_03', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_04', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_05', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_06', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_07', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_08', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_09', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccac_20', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_critical_care_neonatal_daily')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for   tbl_critical_care_neonatal_daily

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_critical_care_neonatal_daily.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_critical_care_neonatal
schema = [
bigquery.SchemaField('acp_refno', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_on_admission', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('person_stated_gender_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('critical_care_start_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('critical_care_end_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('critical_care_length_of_stay', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('critical_care_length_of_stay_in_minutes', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cc_unit_function', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('critical_care_subset', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_critical_care_neonatal')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for tbl_critical_care_neonatal   

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_critical_care_neonatal.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_ec_backward_compatible_susplus
schema = [
bigquery.SchemaField('identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('generated_record_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reason_for_access', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cds_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('protocol_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('update_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bulk_replacement_cds_group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('test_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('applicable_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('census_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('extract_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('report_period_start_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('report_period_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_sender_of_transaction', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_of_sender', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cds_interchange_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_local_patient_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_local_patient_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_year', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_month', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('carer_support_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest_number_trace_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('withheld_identity_reason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sex', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('name_format_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('address_format_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_residence_responsibility', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pct_of_residence', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_pct_of_residence', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('osv_classification_at_cds_activity_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('general_medical_practitioner_code_of_registered_gmp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('practice_code_of_registered_gp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_of_registered_gp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('aande_attendance_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('aande_arrival_mode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('aande_attendance_category', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('aande_attendance_disposal', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('aande_incident_location_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('aande_patient_group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('source_of_referral_for_aande', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('arrival_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('arrival_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('aande_attendance_conclusion_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('aande_attendance_conclusion_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('aande_departure_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('aande_departure_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('aande_initial_assessment_time_first_and_unplanned_followup_attendances_only', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('aande_initial_assessment_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('aande_time_seen_for_treatment', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('waiting_time_measurement_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ambulance_incident_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_conveying_ambulance_trust', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('commissioning_serial_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nhs_service_agreement_line_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('provider_reference_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('commissioner_reference_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_code_of_provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_of_provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_code_of_commissioner', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_of_commissioner', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('aande_staff_member_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_scheme_in_use', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_first', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_second', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_third', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_fourth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_fifth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_sixth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_seventh', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_eighth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_ninth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_tenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_eleventh', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_twelfth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_thirteenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_fourteenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_fifteenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_sixteenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_seventeenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_eighteenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_nineteenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_twentieth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_twenty_first', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_twenty_second', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_twenty_third', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_diagnosis_twenty_fourth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('investigation_scheme_in_use', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_first', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_second', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_third', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_fourth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_fifth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_sixth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_seventh', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_eighth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_ninth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_tenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_eleventh', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_twelfth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_thirteenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_fourteenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_fifteenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_sixteenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_seventeenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_eighteenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_nineteenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_twentieth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_twenty_first', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_twenty_second', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_twenty_third', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_investigation_twenty_fourth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_scheme_in_use', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_first', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_second', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_third', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_fourth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_fifth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_sixth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_seventh', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_eighth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_ninth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_tenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_eleventh', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_twelfth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_thirteenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_fourteenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_fifteenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_sixteenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_seventeenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_eighteenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_nineteenth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_twentieth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_twenty_first', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_twenty_second', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_twenty_third', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accident_and_emergency_treatment_twenty_fourth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_version_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_scheme_in_use', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dominant_grouping_variable_procedure', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('fce_hrg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('spell_core_hrg_version_no', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pbr_generated_core_hrg_for_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pbr_generated_core_hrg_version_for_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('unique_booking_reference_number_converted', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_pathway_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_patient_pathway_identifier_issuer', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referral_to_treatment_period_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referral_to_treatment_period_start_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referral_to_treatment_period_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lead_care_activity_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nhs_service_agreement_change_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cds_activity_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('aande_department_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('xml_version', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referral_to_treatment_length_derived', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ae_assessment_wait_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ae_conclusion_wait_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ae_duration', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ae_treatment_wait', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('area_code_derived_from_postcode_', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cds_group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('finished_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pct_derived_from_gp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pct_type_derived_from_gp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gp_practice_derived', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pct_derived_from_derived_gp_practice', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sha_from_gp_practice', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sha_type_from_gp_practice', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('month_of_birth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('electoral_ward_from_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pct_from_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pct_type_from_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sha_from_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sha_type_from_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('area_code_from_provider_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('year_of_birth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a2001_census_area', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('country', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('county_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a1991_census_ed', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ed_district_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('electoral_ward_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gor_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('local_unitary_authority', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('old_sha_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a1998_electoral_area', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('prime_recipient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('copy_recipients', 'STRING', mode='NULLABLE'),
    ]

table_ref = dataset_ref.table('tbl_ec_backward_compatible_susplus')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for tbl_ec_backward_compatible_susplus

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_ec_backward_compatible_susplus.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table cb_episode_procedure
schema = [
bigquery.SchemaField('episode_serial', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('spell_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_start_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sort_order', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('fk_consultant_episode', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('cb_episode_procedure')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for   tbl_episode_procedure

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_episode_procedure.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_episode
schema = [
bigquery.SchemaField('episode_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('spell_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_sequence', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gender', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_year', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_month', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('death_year', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('death_month', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('practice', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_start_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_end_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_start_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_start_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_end_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_duration', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('current_episode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('last_episode_in_spell', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('operation_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_ward', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_ward', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_treatment_function_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_treatment_function', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_treatment_function_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_treatment_function', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('consultant_specialty_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('consultant_specialty', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_site_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_site', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_site_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_site', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('purchaser', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnoses', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_25', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_26', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_27', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_28', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_29', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_30', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedures', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_1_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_2_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_3_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_4_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_5_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_6_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_7_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_8_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_9_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_10_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_11_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_12_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_13_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_14_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_15_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_16_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_17_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_18_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_19_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_20_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_21_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_22_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_23_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_24_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_25', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_25_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_26', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_26_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_27', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_27_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_28', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_28_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_29', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_29_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_30', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_30_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('consultant_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('consultant', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('neonatal_level_of_care_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('neonatal_level_of_care', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pathway_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('booking_reference_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pathway_id_issuer', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rtt_period_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('commissioning_serial_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_code_episode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_code_spell', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pss_fce_npoc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pss_service_line', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pss_spell_service_line', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pss_commissioner_code', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_episode')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for   tbl_episode

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_episode.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_maternity_birth
schema = [
bigquery.SchemaField('birth_Serial', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_serial', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sequence_num', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('records', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('apgar_score_05_minutes', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('artificial_rupture_of_membranes_reason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('artificial_rupture_of_membranes_reason_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('babydigest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('month_nhs_number_salt_pseudonym', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('baby_year_of_birth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('baby_month_of_birth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('baby_time_of_birth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('baby_breast_milk_status_at_discharge_from_hospital', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('baby_breast_milk_status_at_discharge_from_hospital_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('baby_first_feed_breast_milk_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('baby_first_feed_breast_milk_status_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('baby_first_feed_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('baby_first_feed_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_order_maternity_services', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_weight_in_grams', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_of_pregnancy_outcome_current_fetus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivered_in_water_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_method_current_baby', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_place_type_code_actual', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_place_type_code_actual_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_place_type_actual_midwifery_unit_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_place_type_actual_midwifery_unit_type_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('exclude_cds', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('exclude_msds', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('fk_consultant_episode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_serial', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hospital_provider_spell_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('spell_episode_los', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('live_or_still_birth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('registerable_birth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('fetal_order_fetus_outcome', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pregnancy_outcome_current_fetus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pregnancy_outcome_current_fetus_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('purchaser', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('fk_outpatient_act', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('presentation_at_onset_of_labour', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('presentation_at_onset_of_labour_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rupture_of_membranes_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rupture_of_membranes_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rupture_of_membranes_method', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rupture_of_membranes_method_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('skin_to_skin_contact_within_one_hour', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_actual_place_of_delivery', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_actual_place_of_delivery_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_of_person_conducting_delivery_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_of_person_conducting_delivery_code_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('resuscitation_method', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('resuscitation_method_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('fed_1_hour', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('breast_milk_48_hrs', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_maternity_birth')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for   tbl_maternity_birth

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_maternity_birth.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_maternity_care_plan
schema = [
bigquery.SchemaField('pk_obs_fact_maternity_care_plan', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('maternity_care_plan_serial', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pregnancy_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('maternity_care_plan_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('maternity_care_plan_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('maternity_care_plan_type_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('maternity_personalised_care_plan_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('continuity_of_carer_pathway_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('maternity_care_setting_of_planned_delivery', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('maternity_care_setting_of_planned_delivery_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_delivery_setting_change_reason_antenatal', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_delivery_setting_change_reason_antenatal_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('exclude_msds', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_maternity_care_plan')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for tbl_maternity_care_plan   

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_maternity_care_plan.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_maternity_delivery
schema = [
bigquery.SchemaField('delivery_serial', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('deliveryminutes', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('abnormality_detected_dating_ultrasound_scan', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('activity_date_antenatal_appointment', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('activity_not_offered_reason_code_for_maternity_dating_ultrasound_scan', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('activity_not_offered_reason_code_for_maternity_dating_ultrasound_scan_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('activity_offer_date_dating_ultrasound_scan', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anaesthesia_given_during_labour_or_delivery', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anaesthesia_given_during_labour_or_delivery_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anaesthesia_given_post_labour_or_delivery', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anaesthesia_given_post_labour_or_delivery_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('appointment_date_formal_antenatal_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cigarettes_per_day_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('commissioning_serial_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('complex_social_factors_indicator_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('contract_serial', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_of_decision_to_deliver', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('time_of_decision_to_deliver', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_of_placenta_method', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delivery_of_placenta_method_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_date_mother_maternity_services', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_time_mother_maternity_services', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('employment_status_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('employment_status_mother_at_booking_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('employment_status_partner_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('employment_status_partner_at_booking_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_of_third_stage_of_labour_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episiotomy_performed_reason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('estimated_date_of_delivery_method_agreed', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('estimated_date_of_delivery_method_agreed_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('exclude_cds', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('exclude_msds', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('exclude_pbr', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('expected_delivery_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('expected_delivery_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('general_medical_practitioner_antenatal_care', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation_length_in_days_dating_ultrasound_scan', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation_length_in_weeks_at_assessment', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation_length_in_weeks_labour_onset', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('labour_or_delivery_onset_method_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('labour_or_delivery_onset_method_code_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('last_menstrual_period_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mental_health_prediction_and_detection_indicator_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nhs_service_agreement_line_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('number_of_fetuses_dating_ultrasound_scan', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('onset_of_established_labour_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('onset_of_second_stage_of_labour_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_postnatal_pathway_lead_provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_classification_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_classification_code_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('person_height_in_meters_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('person_weight_in_kilograms_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('physical_disability_code_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('physical_disability_status_indicator_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('place_of_delivery_intended', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('place_of_delivery_intended_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pregnancy_first_contact_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pregnancy_first_contact_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pregnancy_previous_caesarean_sections', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pregnancy_total_previous_live_births', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pregnancy_total_previous_losses_less_than_24_weeks', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pregnancy_total_previous_neonatal_deaths', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pregnancy_total_previous_pregnancies', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pregnancy_total_previous_stillbirths', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_date_dating_ultrasound_scan', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_time_dating_ultrasound_scan', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_date_caesarean_section', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_time_caesarean_section', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('provider_reference_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('provider_reference', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('purchaser', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referrer', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_pco', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rtt_period_no', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rtt_period_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('smoking_status_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('smoking_status_mother_at_booking_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('smoking_status_mother_at_end_of_pregnancy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('smoking_status_mother_at_end_of_pregnancy_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_of_folic_acid_supplement_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_of_folic_acid_supplement_mother_at_booking_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('substance_use_status_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('substance_use_status_mother_at_booking_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('support_status_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('weekly_alcohol_units_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('artificial_rupture_of_membranes_reason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('artificial_rupture_of_membranes_reason_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rupture_of_membranes_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rupture_of_membranes_method', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rupture_of_membranes_method_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('number_of_babies', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_maternity_delivery')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for   tbl_maternity_delivery

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_maternity_delivery.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_maternity_pathway_antenatal
schema = [
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('practice_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gp_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_of_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pregnancy_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pathway_category', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('multiple', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intensive', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('med_intensive', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intermediate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('med_intermediate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('identifier', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_maternity_pathway_antenatal')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for   tbl_maternity_pathway_antenatal

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_maternity_pathway_antenatal.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_maternity_pathway_postnatal
schema = [
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_delivery_time_minutes', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('place_of_birth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('practice', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('practice_name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('inpatient_location', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('type_of_assessment', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postnatal_day', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_of_assessment', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pbr_delivery_pathway', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pbr_delivery_pathway_items_checked_and_complete', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postnatal_pathway_category', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('maternity_lead_provider_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('maternity_lead_provider_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('outcome_of_pregnancy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('key_events_date_of_clinical_discharge', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_of_discharge_or_transfer', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('home_birth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('termination_or_miscarriage', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hospital_delivery', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('final_ccg_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postnataltariff', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('comments', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('identifier', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_maternity_pathway_postnatal')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for tbl_maternity_pathway_postnatal   

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_maternity_pathway_postnatal.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_maternity_pregnancy_and_booking_details
schema = [
bigquery.SchemaField('pregnancy_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('antenatal_appointment_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('source_of_referral_for_maternity', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('source_of_referral_for_maternity_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('late_antenatal_booking_appointment_reason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('late_antenatal_booking_appointment_reason_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pregnancy_first_contact_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('last_menstrual_period_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('estimated_date_of_delivery_agreed_date2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('estimated_date_of_delivery_method_agreed', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('estimated_date_of_delivery_method_agreed_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_of_folic_acid_supplement_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_of_folic_acid_supplement_mother_at_booking_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('employment_status_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('employment_status_mother_at_booking_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('support_status_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('support_status_mother_at_booking_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('partner_status_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('partner_status_mother_at_booking_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('physical_disability_status_indicator_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mental_health_prediction_and_detection_indicator_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('complex_social_factors_indicator_mother_at_booking', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pregnancy_previous_caesarean_sections', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pregnancy_total_previous_live_births', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pregnancy_total_previous_stillbirths', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pregnancy_total_previous_losses_less_than_24_weeks', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('primary_discharge_reason_mother_maternity_services', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_date_mother_maternity_services', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('primary_discharge_reason_mother_maternity_services_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('exclude_msds', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_maternity_pregnancy_and_booking_details')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for tbl_maternity_pregnancy_and_booking_details  

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_maternity_pregnancy_and_booking_details.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_mother_child_rel
schema = [
bigquery.SchemaField('mother_person_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('baby_person_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_of_decision_to_deliver', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_mother_child_relationship')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for   tbl_mother_child_rel

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_mother_child_rel.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_op_susplus
schema = [
bigquery.SchemaField('identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('generated_record_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reason_for_access', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cds_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('protocol_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sus_generated_spell_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('update_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bulk_replacement_cds_group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('test_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('applicable_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('census_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('extract_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('report_period_start_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('report_period_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_sender_of_transaction', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_of_sender', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('submission_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cds_interchange_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_local_patient_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_local_patient_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_year', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_month', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('carer_support_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest_number_trace_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('withheld_identity_reason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sex', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('name_format_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('address_format_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_residence_responsibility', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pct_of_residence', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_pct_of_residence', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('osv_classification_at_cds_activity_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('consultant_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_specialty_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_function_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('local_sub_specialty_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('multiprofessional_or_multidisciplinary_ind_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rehabilitation_assessment_team_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_scheme_in_use_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_primary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_1st_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_2nd_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_3rd_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_4th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_5th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_6th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_7th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_8th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_9th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_10th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_11th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_12th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_13th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_14th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_15th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_16th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_17th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_18th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_19th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_20th_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_21st_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_22nd_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_23rd_secondary_icd', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('present_on_admission_indicator_diag_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_scheme_in_use_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_primary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_1st_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_2nd_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_3rd_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_4th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_5th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_6th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_7th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_8th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_9th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_10th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_11th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_12th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_13th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_14th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_15th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_16th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_17th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_18th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_19th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_20th_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_21st_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_22nd_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_23rd_secondary_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attendance_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('administrative_category', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attended_or_did_not_attend', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('first_attendance', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('medical_staff_type_seeing_patient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('operation_status_per_attendance', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('outcome_of_attendance', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('appointment_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('appointment_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('expected_duration_of_appointment', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('consultation_medium_used', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('waiting_time_measurement_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('activity_location_type_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('earliest_clinically_appropriate_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('clinic_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('commissioning_serial_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nhs_service_agreement_line_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('provider_reference_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('commissioner_reference_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_code_of_provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_code_of_provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_code_of_commissioner', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_code_of_commissioner', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_scheme_in_use_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('primary_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a2nd_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a3rd_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a4th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a5th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a6th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a7th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a8th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a9th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a10th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a11th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a12th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a13th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_13', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a14th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_14', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a15th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_15', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a16th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_16', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a17th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_17', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a18th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_18', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a19th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_19', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a20th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a21st_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_21', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a22nd_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_22', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a23rd_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_23', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a24th_procedure_opcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_operating_healthcare_professional_code_opcs_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('professional_registration_issuer_code_opcs_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_code_opcs_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('responsible_anaesthetist_reg_body_opcs_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_scheme_in_use_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('primary_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a2nd_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a3rd_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a4th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a5th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a6th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a7th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a8th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a9th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a10th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a11th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a12th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a13th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a14th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a15th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a16th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a17th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a18th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a19th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a20th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a21st_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a22nd_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a23rd_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a24th_procedure_read', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_class_at_attendance', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_code_of_treatment', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_site_code_of_treatment_at_attendance', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('general_medical_practitioner_code_of_registered_gmp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('practice_code_of_registered_gp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_of_registered_gp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('priority_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('service_type_requested', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('source_of_referral_for_outpatients', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referral_request_received_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('direct_access_referral_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referrer_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referring_organisation_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_type_of_referrer', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('last_dna_or_patient_cancelled_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_version_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_scheme_in_use', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dominant_grouping_variable_procedure', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('core_hrg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_version_calculated', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sus_hrg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('unique_booking_reference_number_converted', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_pathway_identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organisation_code_patient_pathway_identifier_issuer', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referral_to_treatment_period_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referral_to_treatment_period_start_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referral_to_treatment_period_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lead_care_activity_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nhs_service_agreement_change_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cds_activity_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('earliest_reasonable_offered_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('xml_version', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referral_to_treatment_length_derived', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_range_patient_derived_from_dob', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('area_code_derived_from_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attender_type_derived', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cds_group', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('finished_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pct_derived_from_gp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pct_type_derived_from_gp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gp_practice_derived', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pct_derived_from_derived_gp_practice', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sha_from_gp_practice', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sha_type_from_gp_practice', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('month_of_birth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('electoral_ward_from_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pct_from_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pct_type_from_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sha_from_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sha_type_from_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('area_code_from_provider_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('year_of_birth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a2001_census_area', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('country', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('county_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a1991_census_ed', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ed_district_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('electoral_ward_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gor_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('local_unitary_authority', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('old_sha_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('a1998_electoral_area', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('prime_recipient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('copy_recipients', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('is_valid_ubrn', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ubrn_occurrence_count', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_op_susplus')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for  tbl_op_susplus 

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_op_susplus.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_outpatient
schema = [
bigquery.SchemaField('appointment_serial', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('practice', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('practice_name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_year', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_month', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('death_year', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('death_month', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gender', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('clinic_session_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('clinic_session_name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('raw_appointment_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attendance_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attendance_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attendance_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_age', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('source_of_referral_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('source_of_referral', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('source_of_referral_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referral_request_received_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_local_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('consultant_specialty_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('consultant_specialty', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('consultant_specialty_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attended_didnot_attend_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attended_didnot_attend', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attended_didnot_attend_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('clinic', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_function', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_function_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_function_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('clinician', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('clinician_name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('consultant_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('consultant_name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('administrative_category_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('administrative_category', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('administrative_category_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('first_attendance_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('first_attendance', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('first_attendance_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('medical_staff_type_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('medical_staff_type_local_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_no', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_no', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('investigation_no', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_1_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_2_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_3_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_4_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_5_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_6_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_7_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_8_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_9_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_10_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_11_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('procedure_12_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op_referral_request_type_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op_referral_request_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op_location_type_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op_location_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_type_local_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('type_of_referrer_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('operation_status_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('operation_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op_priority_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op_priority', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('op_priority_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('provider_name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('purchaser', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('purchaser_name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('contract_serial', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attendance_outcome_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attendance_outcome', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attendance_outcome_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pathway_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('booking_reference_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rtt_period_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pathway_id_issuer', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_version', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pss_service_line', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referral_serial', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_outpatient')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for   tbl_outpatient

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_outpatient.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_patient
schema = [
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_of_birth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('marital_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sex_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sex', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('title', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('religion', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dentist_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dentist', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ethnic_origin', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('practice_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('practice', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_of_death', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_deceased', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('remarks', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('trace_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('overseas_visitor', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('residence_ccg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('fk_patient', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ethnic_origin_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gp_name', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_patient')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for   tbl_patient

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_patient.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_pharmacy
schema = [
bigquery.SchemaField('unique_pharmacy_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('prescription_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('consultant_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('consultant_name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('consultant', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('issue_source', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('issue_source_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('issue_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('issue_type_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('issue_Date_Dt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('issue_location', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('issue_location_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cost_centre', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cost_centre_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('specialty', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('specialty_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('drug', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Drug_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('drug_dose_unit', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('drug_dose_unit_Description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('drug_strength', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('drug_form', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('drug_form_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('drug_quantity', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('drug_instructions', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_type_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('latest_price_paid', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('prescription_value', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_pharmacy')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for   tbl_pharmacy

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_pharmacy.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_PMH_MaternityDataset
schema = [
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postnatal_year', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pmh_Indication', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('imd_Quintile', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_PMH_MaternityDataset')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for   tbl_PMH_MaternityDataset

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_PMH_MaternityDataset.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_radiology
schema = [
bigquery.SchemaField('identifier', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('accession_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attendance_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('request_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('exam_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('exam_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('exam_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_function', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_function_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('modality', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_type_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reported_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reported_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reported_date_dt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('inpatient_episode_serial', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('outpatient_appointment_serial', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ae_attendance_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('attendance_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('urgency', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referrer_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referrer_specialty', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_age', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('refering_location', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_radiology')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for  tbl_radiology

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_radiology.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_spell
schema = [
bigquery.SchemaField('spell_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gender', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_year', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_month', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('death_year', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('death_month', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_age', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('decision_to_admit_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admission_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admission_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admission_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('practice', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('practice_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('practice_address', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('clinician', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admission_clinician_fullname', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admission_source', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admission_source_local_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admission_method', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admission_method_local_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_management_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_management', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intended_management_local_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_classification_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_classification', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_classification_local_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('administrative_category_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('administrative_category', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('administrative_category_local_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site_local_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pathway_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('booking_reference_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rtt_period_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_destination_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_destination', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_destination_local_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_method_local', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_method', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_method_local_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('commissioning_serial_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_code_spell', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_code_spell_desc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('length_of_provider_spell', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_spell')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for   tbl_spell

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_spell.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_theatre
schema = [
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_age', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('operation_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('session_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('session_number_unique', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('surgery_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('practice', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_serial', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('spell_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('urgency', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('urgency_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admitting_consultant', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admitting_consultant_name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('session_consultant', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('session_consultant_name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('session_specialty', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('session_specialty_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sent_for_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('porter_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('in_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('in_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anaesthetic_start_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anaesthetic_start_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('induced_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('into_theatre_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('incision_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('closure_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('operation_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('operation_end_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('operation_start_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('operation_start_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('recovery_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('recovery_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anaesthetic_handover_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('out_of_recovery_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('theatre', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_duration', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('emergency_booked_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('emergency_requested_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('session_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('session_start_time_planned', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('session_start_time_actual', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('session_end_time_planned', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('session_end_time_actual', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_procedure_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_procedure_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_procedure_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_procedure_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_procedure_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_procedure_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_procedure_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_procedure_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_procedure_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_procedure_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_procedure_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_procedure_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_procedure_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_procedure_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_procedure_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_procedure_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_procedure_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_procedure_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_procedure_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_procedure_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_procedure_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_procedure_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_procedure_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_procedure_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_site_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_site_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_site_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_site_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_site_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_site_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_site_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_site_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_site_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_site_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_site_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_site_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_site_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_site_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_site_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_site_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_site_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_site_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_site_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_site_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_site_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_site_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_site_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_site_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_side_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_side_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_side_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_side_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_side_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_side_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_side_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_side_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_side_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_side_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_side_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_anatomical_side_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_side_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_side_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_side_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_side_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_side_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_side_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_side_7', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_side_8', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_side_9', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_side_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_side_11', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_anatomical_side_12', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_cancel_reason_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_cancel_reason_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_cancel_reason_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('session_cancel_reason_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('session_cancel_reason_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('session_cancel_reason_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('surgeon_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('surgeon_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('surgeon_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('surgeon_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anaesthetist_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anaesthetist_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anaesthetist_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('asa', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('destination', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('incident', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_delay_10', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_delay_20', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_delay_30', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('general_anaesthestic', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('local_anaesthestic', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('circulating_person_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('circulating_person_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('circulating_person_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('circulating_person_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('circulating_person_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anaesthetic_assistant_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anaesthetic_assistant_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anaesthetic_assistant_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anaesthetic_assistant_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('recovery_nurse_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('recovery_nurse_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('recovery_nurse_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('recovery_nurse_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('scrub_nurse_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('scrub_nurse_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('scrub_nurse_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('transit_nurse_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('transit_nurse_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nurse_as_first_assistant', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('opthalmic_nurse_practitioner', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('surgical_care_practitioner', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_anaesthetic_procedures', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('session_theatre', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('session_start_early_reason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ses_start_late_reason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('session_finish_early_reason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ses_finish_late_reason', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_theatre')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for   tbl_theatre

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_theatre.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))



#create table tbl_critical_care_full_data_2015_2021
schema = [
bigquery.SchemaField('address_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('adm_is_ver2_adm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admstatus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age_decimal', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bed', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('body_mass_index', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccmds_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('country', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('county', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('currently_or_recently_pregnant', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('year_of_birth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ethnicity', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dob_estimated', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('exported_to_icnarc', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('false_nhs_no', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('health_authority', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('first_name_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('height', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('height_estimate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('height_measured', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('height_not_known', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hospital_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('is_this_a_readmission', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('marital_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('middle_name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('missed_fields_icnarc_export', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('month_component_for_age', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_cancelled', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_discharged', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_ever_admitted', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_in_unit', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_refused', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patients_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('post_code_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('religion', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sex', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('surname_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('title_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('town_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('uk_postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('unknown_post_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('weight', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('weight_estimate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('weight_measured', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('weight_not_known', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('actual_date_of_delivery', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assisted_conception', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('expected_date_of_delivery', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation_of_current_pregnancy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gestation_of_recent_pregnancy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hysterectomy_recent_pregnancy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('molar_pregnancy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('no_of_babies_nicu_recent_preg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('no_of_live_births_or_stillbirth', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('no_of_livebirths_recent_preg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('no_of_previous_caesarean', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('no_of_stillbirths_recent_preg', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('outcome_of_recent_pregnancy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pregnancy_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admission_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admission_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admission_type_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admission_ward', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('asa_score', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('booked_unit_admission_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cpr_24h_prior_unit_admission', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('booked_unit_admission_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('critical_care_prior_to_adm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_1st_managed_by_unit_team', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_of_last_critical_care', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('delay_hrs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hospital_admission_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hospital_housing_location_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('housing_transient_location', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('icnarc_comments', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('icnarc_comments_v3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_prior_to_adm_source', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('managed_by_unit_team', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('number_of_staffed_beds', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('original_hosp_admission_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('original_unit_admission_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_intermediate_care_area_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('outreach_1st_visit_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('outreach_action_taken', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('outreach_last_visit_date_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('outreach_care_level', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('outreach_last_visit_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('outreach_last_visit_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('outreach_mews', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('outreach_scored_on_ward', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('outreach_total_no_of_visits', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('outreach_visited_prior_to_adm', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pik_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_admission', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('presurgical_preparation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('prior_location', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('prioradm_ward', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('re_adm_reason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reason_for_nonadmission', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('residence_prior_to_admission', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sector', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('source_of_unit_admission', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('surgery_classification', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('surgery_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('tags_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('time_1st_managed_by_unit_team', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('timeliness_of_admission_to_your_unit', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('transfer_on', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('unit', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('unit_admission_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('unit_admission_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('classification_in', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('classification_out', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('event_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('event_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('prior_transfer_in', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('same_trust_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('transfer_in_reason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('transfer_out_reason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('transfer_within_network_in', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('transfer_within_network_out', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('transferred_from', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('transferred_to', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('transfers_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('type_adult_icu_in', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('type_adult_icu_out', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ult_classification_out', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ult_hospital_transto', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ult_reasonfor_out', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ult_transfer_within_network_out', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ult_type_adult_icu_out', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('unit_admission_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ult_unit_identifier_out', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('unit_identifier_in', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('unit_identifier_out', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('burns_surface_area', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('inhalation_injury', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition_1_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition_1_condition', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition_1_process', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition_1_site', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition_1_system', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition_1_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition_2_condition', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition_2_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition_2_process', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition_2_system', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition_2_site', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition_2_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('othreas_adm1_notes', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('othreas_adm2_notes', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('primary_reason_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('primary_reason_condition', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('primary_reason_process', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('primary_reason_site', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('primary_reason_system', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('primary_reason_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reason_adm1_notes', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reason_adm2_notes', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reason_for_admission_to_unit_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reason_for_admission_to_unit_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reason_for_admission_to_unit_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reason_for_admission_to_unit_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secondary_reason_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secondary_reason_condition', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secondary_reason_process', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secondary_reason_site', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secondary_reason_system', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('secondary_reason_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ultimate_reason_admission_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ultimate_reason_admission_condition', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ultimate_reason_admission_process', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ultimate_reason_admission_system', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ultimate_reason_admission_site', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ultimate_reason_admission_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ultreason_adm_notes', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('active_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('address_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('address_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('anaesthetist', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('consultant_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_unit_left_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('first_name_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('on_call', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postcode_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('search_name_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('signature_list_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('speciality_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('speciality_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('surname_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('telephone_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('title_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('coma_or_deep_stupor_mpm0', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('coma_or_deep_stupor_mpm24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('continuous_iv_drug_for_1hrplusorminus', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_extubated', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('heart_rate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('infection_confirmed', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intracranial_mass_effect', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mpm_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('systolic_bp_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('time_extubated', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('total_intubated', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('acp_main_hosp_speciality', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('antimicrobials_used_to_treat_unitacquired_infection', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assent_for_solid_organ', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bed_ready_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bed_ready_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('brainstem_death_declared', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cause_of_death', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('classification_of_surgery', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('clostridium_difficile', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('critical_care_post_discharge', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cvc_related_cdiff', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cvc_related_mrsa', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cvc_related_vre', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_brainstem_death', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_of_death', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_of_first_critical_care', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('death_outside_unit', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_ult_unit_discharge', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('demise', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('destination_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_delay', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_ward', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hospital_housing_location', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('length_of_ultimate_unit_stay', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('length_of_unit_stay', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('length_of_unit_stay_ready', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('length_stay_days_decimal', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('length_stay_days_decimal_ready', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('length_stay_days_rounded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('length_stay_days_rounded_ready', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('level_of_care_recd_at_discharge', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mews_at_discharge', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('main_organism_causing_first_unitacquired_infection_in_blood', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mouais', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mrsa', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nuais', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('number_of_unitacquired_infections_present_in_blood', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organ_donor', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('organ_donor_v3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_intermediate_care_area', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ready_for_discharge_date_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ready_for_discharge_time_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reason_for_delay', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reason_for_discharge', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('reason_for_discharge_v3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('referred_to_transplant', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rehabilitation_prescription', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('residence_post_discharge', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('same_trust_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('same_trust', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sector_of_other_hospital', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_at_unit_discharge', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_ult_unit_discharge', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('surgery_up_to_one_week', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('time_body_removed', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('time_brainstem_death', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('time_of_death', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('timeliness_of_discharge', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_withdrawn', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_withdrawn_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_withdrawn_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_witheld_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_withheld_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('unit_discharge_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('unit_discharge_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('unit_outcome_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('vre_present', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('unit_remain_hours_till_ready', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_hospital_discharge', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('destination', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('destination_post_discharge_v3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('expected_dependency_post_disch', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hospital_outcome_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('length_hospital_stay_string', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('length_of_hospital_stay', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('length_of_ultimate_hosp_stay', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('length_of_ultimate_hosp_stay_string', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_hospital_discharge', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_overall', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status_ult_hospital_discharge', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('specialitydoctor_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('address_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('active_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_unit_left_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_unit_left_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('doctor_information_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('doctor_type_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('first_name_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postcode_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('search_name_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('signature_list_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('speciality_1a', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('surname_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('telephone_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('title_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nhs_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('old_item', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('speciality_2a', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('speciality_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('address_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_unit_left_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gp_information_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('first_name_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gp_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nation_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('post_code_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('practice_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('search_name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('surname_5', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('telephone_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('title_4', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('acute_myelogenous_or_lymphocytic_leukaemia_or_multiple_myeloma', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('aids', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('chemotherapy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('chronic_renal_replacement_therapy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('chronic_myelogenous_or_lymphocytic_leukaemia', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('congenital_immunohumoral_or_cellular_immune_deficiency_state', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('evidence_to_assess_pmh', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hepatic_encephalopathy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('home_ventilation', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('icnarc_pmh_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('metastatic_disease', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition_condition', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition_notes', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition_process', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition_site', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition_system', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('other_condition_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pmh_present', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('portal_hypertension', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('radiotherapy', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('severe_respiratory_disease', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('steroid_treatment', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('very_severe_cv_disease', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('departmentdoctor_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('active', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('address_6', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_unit_left', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('doctor_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('doctor_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('first_name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('postcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('signature_list', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('speciality', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('surname', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('title', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('department', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('department_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admission_source', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('admission_type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('advanced_cardiovascular_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('advanced_respiratory_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('basic_respiratory_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('basic_cardiovascular_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bed_configuration', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dermatological_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_destination', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_location_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_location', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('discharge_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gastrointestinal_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hrg_organ_support', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('level_0_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('level_1_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('level_3_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('liver_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('max_organ_support', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('neurological_days', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_admitted', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ready_for_discharge_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ready_for_discharge_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('source_location', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('start_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('treatment_speciality', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('unit_function', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('address', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('fax', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hospital_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hospital_name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('icnarc_hospital_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('post_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('town', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('acptotalorgsupp_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('advanced_cardiovascular_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_paco2_artbg_lpao2_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_paco2_intuartbg_hfio2_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_ph_hplus_artbg_lpao2_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_ph_hplus_intuartbg_hfio2_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('associated_eye_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('associated_fio2_for_l_pao2_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('associated_intubation_status_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('associated_paco2_for_h_ph_h_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('associated_paco2_for_l_ph_h_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('associated_verbal_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('basic_cardiovascular_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('basic_respiratory_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('blood_taken_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('care_level_acp_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('care_level_ccmds_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ccmds_total_organs_supported', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('circulatory', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cpap_during_fst24hrs_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('daily_assess_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('day_in_unit_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('day_study_count_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dermatological_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('evidence_available_to_abstract_physiology_data_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('fio2_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('flag_preadmission_blood_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('flag_preadmission_creatanine_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('flag_preadmission_potasium_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('flag_preadmission_serum_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('flag_preadmission_serum_sodium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('flag_preadmission_serum_urea_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('flag_preadmission_sodium_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gcs_status_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('higest_blood_lactate_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('higest_ph_h_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_assoc_abs_neutrophil_cnt_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_central_temperature_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_diastolic_bp_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_haematocrit_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_haemoglobin_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_heart_rate_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_nonventilated_respiratory_rate_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_prothrombin_time_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_serum_albumin', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_serum_bicarbonate_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_serum_calcium_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_serum_gucose_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_serum_sodium_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_systolic_bp_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_ventilated_respiratory_rate_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('liver_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_assoc_abs_neutrophil_cnt_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_central_temperature_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_haematocrit_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_haemoglobin_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_heart_rate_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_ionised_serum_calcium_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_noncentral_temperature', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_platelet_count_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_serum_bicarbonate_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_serum_calcium_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_serum_glucose_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_serum_potassium_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_serum_sodium_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_total_gcs_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_ventilated_respiratory_rate_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_white_blood_cell_count_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('missing_blood_count_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('missing_blood_lactate_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('missing_haemoglobin_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('missing_platelet_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('missing_serum_bicarbonate_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('missing_serum_potasium_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('missing_serum_sodium_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('missing_urine', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('neurological_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('neurological_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nurses_shift_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('paired_diastolic_bp_for_highest_sistolic_bp_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('paired_sistolic_bp_for_highest_diastolic_bp_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('paired_systolic_bp_for_lowest_diastolic_bp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pao2_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('physio_completed_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('plan_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('preadmission_assoc_abs_neutrophil_cnt_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('preadmission_blood_lactate_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('preadmission_platelet_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('preadmission_serum_glucose_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('preadmission_serum_glucose_value_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('preadmission_serum_urea_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('presedation_gcs_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('presedation_total_gcs_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pupil_reactivity_left_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pupil_reactivity_right_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rehabilitation_assessed_in_first_24h', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('renal_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('seen_by_icu_consultant_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('SeenbyICUConsultant_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('seen_by_icu_consultant_delay_string_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('seen_by_icu_consultant_delay_time_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('seen_by_icu_consultant_time_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sepsis_positive_result_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('transaminase_alt_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('transaminase_ast_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('urine_output_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_round_summary_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('worst_pupil_reactions_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('apache_ii', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('apache_ii_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('apache_ii_probabilty', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cpis', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_score_was_calculated', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('day_in_unit_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('groups_and_items', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('icnarc_model_physiolology_percentage', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('icnarc_model_physiolology_probability', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('icnarc_no_calculation_reason_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('icnarc_no_calculation_reason_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('icnarc_no_calculation_reason', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('icnarc_risk_prediction_model_probability_numeric_1', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('icnarc_risk_prediction_model_probability_numeric', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lods', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mofs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mpmii_0', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('mpmii_24', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('patient_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('possum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('prism', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('saps_ii', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('saps_ii_probability', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sepsis', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sofa', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('age', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('location', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('number_of_organs_supported', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('planned_indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('speciality_function', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('notes_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('signed_by', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('time_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('type', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('allocation_order', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dateto', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('display_order', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('timeto', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bed_information', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('bed_name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_removed', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('funded', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('notes', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('comments', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('death_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('time_n', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_started', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('intervention_days_info', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('use_in', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('advanced_cardiovascular_system', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('advanced_respiratory_system', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('basic_cardiovascular_system', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('basic_respiratory_system', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('default_care_level_ccmds', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('defaulted', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('dermatological_system', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('groups_and_items_info', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('infusion', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('liver_system', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('not_deletable', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('not_modifiable', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('renal_system', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('tags', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('two_level2isl3', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('site', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('acptotalorgsupp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('advanced_cardiovascular', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_intub_status_total_gcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_paco2_artbg_lpao2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_paco2_intuartbg_hfio2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('assoc_ph_hplus_intuartbg_hfio2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('associated_eye', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('associated_fio2_for_l_pao2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('associated_intubation_status', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('associated_motor', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('associated_verbal', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('basic_cardiovascular', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('basic_respiratory', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('blood_taken', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('care_level_acp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('care_level_ccmds', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('cpap_during_fst24hrs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('date_n', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('day_study_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('evidence_available_to_abstract_physiology_data', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('fio2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('flag_preadmission_creatanine', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('flag_preadmission_platelet', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('flag_preadmission_potasium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('flag_preadmission_serum', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('flag_preadmission_serum_urea', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('flag_preadmission_sodium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gastrointestinal', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('higest_blood_lactate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('higest_ion_serum_calcium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('higest_ph_h_2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_assoc_abs_neutrophil_cnt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_diastolic_bp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_haematocrit', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_haemoglobin', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_heart_rate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_noncentral_temperature', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_nonventilated_respiratory_rate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_prothrombin_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_serum_bicarbonate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_serum_calcium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_serum_creatinine', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_serum_potassium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_serum_sodium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_serum_urea', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_systolic_bp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_ventilated_respiratory_rate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('highest_white_blood_cell_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('liver', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_assoc_abs_neutrophil_cnt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_diastolic_bp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_haemoglobin', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_ionised_serum_calcium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_nonventilated_respiratory_rate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_platelet_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_serum_bicarbonate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_serum_calcium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_serum_potassium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_serum_sodium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_total_gcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('lowest_white_blood_cell_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('missing_blood_count', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('missing_blood_gases', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('missing_creatinine', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('missing_haemoglobin', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('missing_serum_bicarbonate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('missing_serum_potasium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('missing_serum_sodium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('missing_urea', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('morphology', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('neurological', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nurses_shift', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('paired_diastolic_bp_for_highest_sistolic_bp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('paired_diastolic_bp_for_systolic_bp', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pao2', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('physio_completed', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pic_drop', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('plan', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('preadmission_assoc_abs_neutrophil_cnt', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('preadmission_blood_lactate_value', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('preadmission_haemoglobin', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('preadmission_serum_bicarbonate', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('preadmission_serum_glucose_value', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('preadmission_serum_potasium', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('preadmission_serum_urea', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('presedation_total_gcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pupil_reactivity_left', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('presedation_gcs', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pupil_reactivity_right', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('renal', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sedated_paralysed_and_sedated', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('seen_by_icu_consultant', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('seen_by_icu_consultant_delay_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('seen_by_icu_consultant_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sepsis_positive_result', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sepsis_screened', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('urine_output', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('worst_pupil_reactions', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_critical_care_full_data_2015_2021')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for tbl_critical_care_full_data_2015_2021  

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_critical_care_full_data_2015_2021.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))


#create table tbl_ward_lkp
schema = [
bigquery.SchemaField('ward_code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward_name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('hospital_name', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_ward_lkp')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for  tbl_ward_lkp

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_ward_lkp.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table tbl_ward_stay
schema = [
bigquery.SchemaField('stay_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('spell_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('stay_sequence', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('digest', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('gender', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_year', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('birth_month', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('death_year', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('death_month', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('practice', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('stay_start_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('stay_start_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('stay_start_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ward', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('provider', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('current_stay', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('last_stay_in_spell', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('length_of_stay', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('nights_on_ward', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('stay_end_date_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('stay_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('stay_end_time', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('pathway_id', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('booking_reference_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('rtt_period_status', 'STRING', mode='NULLABLE'),
]

table_ref = dataset_ref.table('tbl_ward_stay')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for tbl_ward_stay 

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_ward_stay.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))

#create table cb_episode_diagnosis
schema = [
bigquery.SchemaField('episode_serial', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('spell_number', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_start_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('episode_end_date', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('diagnosis_description', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('sort_order', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('fk_consultant_episode', 'STRING', mode='NULLABLE'),

]

table_ref = dataset_ref.table('cb_episode_diagnosis')
table = bigquery.Table(table_ref, schema=schema)
#table = client.delete_table(table) 
table = client.create_table(table)  # API request

## Loading data for tbl_episode_diagnosis

#table_ref = client.dataset('dataset_name').table('table_name')

load_config = LoadJobConfig()
load_config.skip_leading_rows = 2
load_config.field_delimiter="|"
write_disposition="WRITE_APPEND"
load_config.schema = schema
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/tbl_episode_diagnosis.csv'

load_job = client.load_table_from_uri(
    uri,
    table_ref,
    job_config=load_config)

load_job.result()

destination_table = client.get_table(table_ref)
print('Loaded {} rows.'.format(destination_table.num_rows))
# Out:
# Loaded 7101470 rows.
# Loaded 721130 rows.
# Loaded 789354 rows.
# Loaded 1030143 rows.
# Loaded 1845170 rows.
# Loaded 282228 rows.
# Loaded 6405 rows.
# Loaded 20809 rows.
# Loaded 19776 rows.
# Loaded 77871 rows.
# Loaded 5810 rows.
# Loaded 266786 rows.
# Loaded 2800085 rows.
# Loaded 1890842 rows.
# Loaded 40780 rows.
# Loaded 35748 rows.
# Loaded 40572 rows.
# Loaded 31473 rows.
# Loaded 26756 rows.
# Loaded 14111 rows.
# Loaded 37453 rows.
# Loaded 1191220 rows.
# Loaded 8466722 rows.
# Loaded 1215535 rows.
# Loaded 2053656 rows.
# Loaded 6093 rows.
# Loaded 3917271 rows.
# Loaded 1631478 rows.
# Loaded 132747 rows.
# Loaded 13697 rows.
# Loaded 5626 rows.
# Loaded 2784811 rows.
# Loaded 9087793 rows.
