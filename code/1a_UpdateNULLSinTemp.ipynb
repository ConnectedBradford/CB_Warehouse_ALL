# %%
library(bigrquery)
library(lubridate) 

# Store the project ID
project_id = "yhcr-prd-phm-bia-core"

sourcedb <-"yhcr-prd-phm-bia-core.CB_MYSPACE_JDB"
# Out:
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union

# %%
#Using a loop to make the text nuill into actual nulls
#Your loop references this table
#You run this to load the list of tables into the dataframe "table"

sql3 <-paste('select table_name, column_name  from ' ,sourcedb,'.INFORMATION_SCHEMA.COLUMNS where data_type = "STRING" 
and (column_name like "%date%" or column_name like "%dt%" or column_name like "%time%")  ;', sep = "")
tb3 <- bq_project_query(project_id, sql3)

table <- bq_table_download(tb3)
table 

#This then loops through the data frame until the end
# uses the two variables table[[i, 1]] and table[[i, 2]]
# in the query

for(i in 2:nrow(table)) 
{
# for-loop over columns
#    print(paste0("Table: ", table[[i, 1]]))
#    print(paste0("Table: ", table[[i, 2]]))
    temp_sql_query  <-paste('update ' ,sourcedb,'.',table[[i, 1]] ,' set ', table[[i, 2]] ,' = null where ', table[[i, 2]] , ' = "NULL"'  , sep = "") 
    #print (temp_sql_query)    
    temp_queried_table <- bq_project_query(project_id, temp_sql_query)
    #section below just brings this back to R 
    #temp_table <- bq_table_download(temp_queried_table)

    #Prints out a confirmation message for each update
    #print(paste0("Done: ", table[[1, 1]],' ', table[[1, 2]]))
    #cat("\n")
}


fred <-paste('Done all nulls ' ,Sys.time() + hours(1), sep = "")
print (fred)

print("Now open BigQuery and run Make_Staging_Database_Warehouse_FDM_Format")
print("Once complete you can then run 2_Make_Warehouse_FDM_FULL_V1.0.ipynb
# Out:
#     table_name
# 1   tbl_maternity_care_plan
# 2   tbl_mother_child_relationship
# 3   tbl_ae_investigation_nautilus
# 4   tbl_ae_investigation_nautilus
# 5   tbl_ae_investigation_nautilus
# 6   tbl_ae_investigation_nautilus
# 7   tbl_maternity_pathway_antenatal
# 8   tbl_critical_care_ICNARC_observation
# 9   tbl_critical_care_ICNARC_observation
# 10  tbl_critical_care_ICNARC_observation
# 11  tbl_critical_care_ICNARC_observation
# 12  tbl_critical_care_ICNARC_observation
# 13  tbl_critical_care_ICNARC_observation
# 14  tbl_critical_care_ICNARC_observation
# 15  tbl_critical_care_ICNARC_observation
# 16  tbl_maternity_pathway_postnatal
# 17  tbl_maternity_pathway_postnatal
# 18  tbl_maternity_pathway_postnatal
# 19  tbl_critical_care_neonatal
# 20  tbl_critical_care_neonatal
# 21  tbl_op_susplus
# 22  tbl_op_susplus
# 23  tbl_op_susplus
# 24  tbl_op_susplus
# 25  tbl_op_susplus
# 26  tbl_op_susplus
# 27  tbl_op_susplus
# 28  tbl_op_susplus
# 29  tbl_op_susplus
# 30  tbl_op_susplus
# ⋮   ⋮
# 458 tbl_apc_finished_susplus
# 459 tbl_apc_finished_susplus
# 460 tbl_apc_finished_susplus
# 461 tbl_apc_finished_susplus
# 462 tbl_apc_finished_susplus
# 463 tbl_apc_finished_susplus
# 464 tbl_apc_finished_susplus
# 465 tbl_apc_finished_susplus
# 466 tbl_apc_finished_susplus
# 467 tbl_apc_finished_susplus
# 468 tbl_apc_finished_susplus
# 469 tbl_apc_finished_susplus
# 470 tbl_apc_finished_susplus
# 471 tbl_apc_finished_susplus
# 472 tbl_apc_finished_susplus
# 473 tbl_apc_finished_susplus
# 474 tbl_apc_finished_susplus
# 475 tbl_apc_finished_susplus
# 476 tbl_apc_finished_susplus
# 477 tbl_apc_finished_susplus
# 478 tbl_apc_finished_susplus
# 479 tbl_apc_finished_susplus
# 480 tbl_apc_finished_susplus
# 481 tbl_apc_finished_susplus
# 482 tbl_apc_finished_susplus
# 483 tbl_apc_finished_susplus
# 484 tbl_apc_finished_susplus
# 485 tbl_apc_finished_susplus
# 486 tbl_patient
# 487 tbl_patient
#     column_name
# 1   maternity_care_plan_date
# 2   date_of_decision_to_deliver
# 3   orig_order_dt_tm
# 4   current_start_dt_tm
# 5   projected_stop_dt_tm
# 6   valid_dose_dt_tm
# 7   date_of_booking
# 8   h_prothrombin_time
# 9   h_partial_thromboplastin_time
# 10  date_daily
# 11  icucons_date
# 12  icucons_time
# 13  icucons_delaytime
# 14  lastchdby_date
# 15  lastchdby_time
# 16  planned_delivery_time_minutes
# 17  key_events_date_of_clinical_discharge
# 18  date_of_discharge_or_transfer
# 19  critical_care_start_date_time
# 20  critical_care_end_date_time
# 21  update_type
# 22  applicable_date_time
# 23  census_date
# 24  extract_date_time
# 25  report_period_start_date
# 26  report_period_end_date
# 27  submission_date
# 28  osv_classification_at_cds_activity_date
# 29  appointment_date
# 30  appointment_time
# ⋮   ⋮
# 458 end_time_ward_stay_22
# 459 start_date_23
# 460 start_time_ward_stay_23
# 461 end_date_23
# 462 end_time_ward_stay_23
# 463 start_date_24
# 464 start_time_ward_stay_24
# 465 end_date_24
# 466 end_time_ward_stay_24
# 467 ward_code_at_episode_end_date
# 468 ward_security_level_at_episode_end_date
# 469 location_class_at_episode_end_date
# 470 site_code_of_treatment_at_episode_end_date
# 471 organisation_code_type_site_code_of_treatment_at_episode_end_date
# 472 intended_clinical_care_intensity_at_episode_end_date
# 473 age_group_intended_at_episode_end_date
# 474 ward_day_period_availability_at_episode_end_date
# 475 ward_night_period_availability_at_episode_end_date
# 476 decided_to_admit_date_for_this_provider
# 477 waiting_time_measurement_type
# 478 first_antenatal_assessment_date
# 479 delivery_date
# 480 referral_to_treatment_period_start_date
# 481 referral_to_treatment_period_end_date
# 482 nhs_service_agreement_change_date
# 483 cds_activity_date
# 484 hospital_provider_spell_discharge_ready_date
# 485 critical_care_start_date_1
# 486 date_of_birth
# 487 date_of_death
# [1] "Done all nulls 2023-08-07 16:28:42.696752"
# [1] "Now open BigQuery and run Make_Staging_Database_Warehouse_FDM_Format"
